# %%
pip install pygame
# Out:
# Collecting pygame
#   Downloading pygame-2.6.1-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.6.1-cp310-cp310-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/10.6 MB 12.6 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/10.6 MB 16.0 MB/s eta 0:00:01
#    ------------------------------------- -- 10.0/10.6 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 16.6 MB/s eta 0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# filepath: d:\IaaC\TERM 2\AI IN ROBOTICS\Code\Reinforced Learning_Day02\Wood Carving.ipynb
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pygame
import math

class CutSquareEnv(gym.Env):
    def __init__(self, grid_size=50, square_top=10, square_bottom=40, square_left=10, square_right=40):
        super().__init__()
        self.grid_size = grid_size
        # Grid: 1 = cell present, 0 = removed
        self.observation_space = spaces.Box(low=0, high=1, shape=(grid_size, grid_size), dtype=np.int32)
        # Action: choose a cell coordinate to remove
        self.action_space = spaces.MultiDiscrete([grid_size, grid_size])
        
        # Parameters for the square and ideal circle
        self.square_top = square_top
        self.square_bottom = square_bottom
        self.square_left = square_left
        self.square_right = square_right
        self.center = ((square_left + square_right) / 2, (square_top + square_bottom) / 2)
        # Define circle radius as half the side length of the square
        self.circle_radius = (square_right - square_left) / 2
        
        # pygame display parameters
        pygame.init()
        self.cell_size = 10  # each grid cell drawn as a 10x10 block
        self.screen = pygame.display.set_mode((grid_size * self.cell_size, grid_size * self.cell_size))
        pygame.display.set_caption("Cut Square Environment")
        self.clock = pygame.time.Clock()
        
        self.reset()

    def reset(self, seed=None, options=None):
        # Create an empty grid and fill the square region with 1's.
        self.grid = np.zeros((self.grid_size, self.grid_size), dtype=np.int32)
        self.grid[self.square_top:self.square_bottom, self.square_left:self.square_right] = 1
        self.steps = 0
        return self.grid.copy(), {}
    

    def step(self, action):
        x, y = action
        reward = 0
        info = {}

        if self.grid[y, x] == 0:
            reward = -5  # Larger penalty for removing an already-removed cell
        else:
            # Only allow removal if it is on the edge
            if self._is_edge(x, y):
                self.grid[y, x] = 0  # Remove the cell
                reward += 2  # Reward for correctly removing an edge pixel

                # Distance check: Removing outermost pixels is better
                dist = math.hypot(x - self.center[0], y - self.center[1])
                if dist >= self.circle_radius:
                    reward += 3  # Extra reward for shaping towards the ideal circle
                else:
                    reward -= 3  # Penalty if it removes inside the circle too early
            else:
                reward -= 4  # Heavy penalty if removing an internal pixel

        self.steps += 1
        done = (np.sum(self.grid) == 0) or (self.steps >= 500)
        return self.grid.copy(), reward, done, False, info
    

    def _is_edge(self, x, y):
        if self.grid[y, x] == 0:
            return False  # Already removed, not an edge

        # Edge condition: At least one neighbor is outside the square OR removed
        for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
            nx, ny = x + dx, y + dy
            if not (self.square_left <= nx < self.square_right and self.square_top <= ny < self.square_bottom):
                return True  # Near the square boundary
            if self.grid[ny, nx] == 0:
                return True  # Neighbor is removed
        
        return False  # Otherwise, it's an internal pixel

    def render(self):
        # Draw the grid; filled cells are white, removed ones are black.
        self.screen.fill((0, 0, 0))
        for y in range(self.grid_size):
            for x in range(self.grid_size):
                if self.grid[y, x] == 1:
                    rect = pygame.Rect(x * self.cell_size, y * self.cell_size, self.cell_size, self.cell_size)
                    pygame.draw.rect(self.screen, (255, 255, 255), rect)
        pygame.display.flip()
        self.clock.tick(100)

    def _no_more_removals(self):
        indices = np.indices(self.grid.shape)
        xs, ys = indices[1], indices[0]

        # Consider only the original square region
        mask = (self.grid == 1) & (self.square_left <= xs) & (xs < self.square_right) & (self.square_top <= ys) & (ys < self.square_bottom)

        # Compute Euclidean distance from center
        dists = np.sqrt((xs - self.center[0])**2 + (ys - self.center[1])**2)

        # Stop only when all remaining square pixels are inside the inscribed circle
        return not np.any(mask & (dists > self.circle_radius))        

    def close(self):
        pygame.quit()

# Create the environment
env = CutSquareEnv()

# Training loop (without visualization)
for episode in range(500):
    state, _ = env.reset()
    done = False
    total_reward = 0
    while not done:
        # For training, pick a random cell to remove
        action = env.action_space.sample()
        next_state, reward, done, _, _ = env.step(action)
        total_reward += reward
        state = next_state
    print(f"Episode {episode+1} complete. Total reward: {total_reward}")

print("Training complete! Now visualizing a final episode...")

# Final episode visualization after training
state, _ = env.reset()
done = False
while not done:
    action = env.action_space.sample()
    state, reward, done, _, _ = env.step(action)
    env.render()
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            done = True

env.close()
# Out:
# Episode 1 complete. Total reward: -2166
# Episode 2 complete. Total reward: -2151
# Episode 3 complete. Total reward: -2146
# Episode 4 complete. Total reward: -2112
# Episode 5 complete. Total reward: -2191
# Episode 6 complete. Total reward: -2212
# Episode 7 complete. Total reward: -2116
# Episode 8 complete. Total reward: -2124
# Episode 9 complete. Total reward: -2106
# Episode 10 complete. Total reward: -2176
# Episode 11 complete. Total reward: -2180
# Episode 12 complete. Total reward: -2182
# Episode 13 complete. Total reward: -2145
# Episode 14 complete. Total reward: -2142
# Episode 15 complete. Total reward: -2048
# Episode 16 complete. Total reward: -2175
# Episode 17 complete. Total reward: -2118
# Episode 18 complete. Total reward: -2153
# Episode 19 complete. Total reward: -2218
# Episode 20 complete. Total reward: -2206
# Episode 21 complete. Total reward: -2210
# Episode 22 complete. Total reward: -2137
# Episode 23 complete. Total reward: -2075
# Episode 24 complete. Total reward: -2122
# Episode 25 complete. Total reward: -2171
# Episode 26 complete. Total reward: -2161
# Episode 27 complete. Total reward: -2207
# Episode 28 complete. Total reward: -2167
# Episode 29 complete. Total reward: -2143
# Episode 30 complete. Total reward: -2150
# Episode 31 complete. Total reward: -2098
# Episode 32 complete. Total reward: -2188
# Episode 33 complete. Total reward: -2142
# Episode 34 complete. Total reward: -2170
# Episode 35 complete. Total reward: -2134
# Episode 36 complete. Total reward: -2096
# Episode 37 complete. Total reward: -2127
# Episode 38 complete. Total reward: -2125
# Episode 39 complete. Total reward: -2100
# Episode 40 complete. Total reward: -2216
# Episode 41 complete. Total reward: -2160
# Episode 42 complete. Total reward: -2160
# Episode 43 complete. Total reward: -2178
# Episode 44 complete. Total reward: -2101
# Episode 45 complete. Total reward: -2090
# Episode 46 complete. Total reward: -2143
# Episode 47 complete. Total reward: -2079
# Episode 48 complete. Total reward: -2279
# Episode 49 complete. Total reward: -2185
# Episode 50 complete. Total reward: -2190
# Episode 51 complete. Total reward: -2176
# Episode 52 complete. Total reward: -2150
# Episode 53 complete. Total reward: -2145
# Episode 54 complete. Total reward: -2151
# Episode 55 complete. Total reward: -2106
# Episode 56 complete. Total reward: -2065
# Episode 57 complete. Total reward: -2079
# Episode 58 complete. Total reward: -2155
# Episode 59 complete. Total reward: -2189
# Episode 60 complete. Total reward: -2122
# Episode 61 complete. Total reward: -2148
# Episode 62 complete. Total reward: -2138
# Episode 63 complete. Total reward: -2117
# Episode 64 complete. Total reward: -2078
# Episode 65 complete. Total reward: -2108
# Episode 66 complete. Total reward: -2113
# Episode 67 complete. Total reward: -2067
# Episode 68 complete. Total reward: -2079
# Episode 69 complete. Total reward: -2140
# Episode 70 complete. Total reward: -2114
# Episode 71 complete. Total reward: -2143
# Episode 72 complete. Total reward: -2185
# Episode 73 complete. Total reward: -2167
# Episode 74 complete. Total reward: -2076
# Episode 75 complete. Total reward: -2081
# Episode 76 complete. Total reward: -2176
# Episode 77 complete. Total reward: -2167
# Episode 78 complete. Total reward: -2153
# Episode 79 complete. Total reward: -2154
# Episode 80 complete. Total reward: -2115
# Episode 81 complete. Total reward: -2156
# Episode 82 complete. Total reward: -2091
# Episode 83 complete. Total reward: -2174
# Episode 84 complete. Total reward: -2168
# Episode 85 complete. Total reward: -2133
# Episode 86 complete. Total reward: -2097
# Episode 87 complete. Total reward: -2130
# Episode 88 complete. Total reward: -2143
# Episode 89 complete. Total reward: -2086
# Episode 90 complete. Total reward: -2207
# Episode 91 complete. Total reward: -2124
# Episode 92 complete. Total reward: -2149
# Episode 93 complete. Total reward: -2144
# Episode 94 complete. Total reward: -2163
# Episode 95 complete. Total reward: -2147
# Episode 96 complete. Total reward: -2160
# Episode 97 complete. Total reward: -2134
# Episode 98 complete. Total reward: -2080
# Episode 99 complete. Total reward: -2179
# Episode 100 complete. Total reward: -2167
# Episode 101 complete. Total reward: -2144
# Episode 102 complete. Total reward: -2176
# Episode 103 complete. Total reward: -2119
# Episode 104 complete. Total reward: -2157
# Episode 105 complete. Total reward: -2088
# Episode 106 complete. Total reward: -2135
# Episode 107 complete. Total reward: -2106
# Episode 108 complete. Total reward: -2166
# Episode 109 complete. Total reward: -2100
# Episode 110 complete. Total reward: -2216
# Episode 111 complete. Total reward: -2161
# Episode 112 complete. Total reward: -2118
# Episode 113 complete. Total reward: -2129
# Episode 114 complete. Total reward: -2135
# Episode 115 complete. Total reward: -2131
# Episode 116 complete. Total reward: -2154
# Episode 117 complete. Total reward: -2193
# Episode 118 complete. Total reward: -2125
# Episode 119 complete. Total reward: -2229
# Episode 120 complete. Total reward: -2079
# Episode 121 complete. Total reward: -2142
# Episode 122 complete. Total reward: -2132
# Episode 123 complete. Total reward: -2182
# Episode 124 complete. Total reward: -2109
# Episode 125 complete. Total reward: -2123
# Episode 126 complete. Total reward: -2125
# Episode 127 complete. Total reward: -2140
# Episode 128 complete. Total reward: -2094
# Episode 129 complete. Total reward: -2168
# Episode 130 complete. Total reward: -2195
# Episode 131 complete. Total reward: -2165
# Episode 132 complete. Total reward: -2108
# Episode 133 complete. Total reward: -2163
# Episode 134 complete. Total reward: -2128
# Episode 135 complete. Total reward: -2103
# Episode 136 complete. Total reward: -2031
# Episode 137 complete. Total reward: -2164
# Episode 138 complete. Total reward: -2148
# Episode 139 complete. Total reward: -2165
# Episode 140 complete. Total reward: -2123
# Episode 141 complete. Total reward: -2207
# Episode 142 complete. Total reward: -2102
# Episode 143 complete. Total reward: -2175
# Episode 144 complete. Total reward: -2161
# Episode 145 complete. Total reward: -2135
# Episode 146 complete. Total reward: -2177
# Episode 147 complete. Total reward: -2165
# Episode 148 complete. Total reward: -2140
# Episode 149 complete. Total reward: -2169
# Episode 150 complete. Total reward: -2154
# Episode 151 complete. Total reward: -2156
# Episode 152 complete. Total reward: -2184
# Episode 153 complete. Total reward: -2136
# Episode 154 complete. Total reward: -2203
# Episode 155 complete. Total reward: -2213
# Episode 156 complete. Total reward: -2110
# Episode 157 complete. Total reward: -2105
# Episode 158 complete. Total reward: -2212
# Episode 159 complete. Total reward: -2160
# Episode 160 complete. Total reward: -2091
# Episode 161 complete. Total reward: -2182
# Episode 162 complete. Total reward: -2164
# Episode 163 complete. Total reward: -2124
# Episode 164 complete. Total reward: -2152
# Episode 165 complete. Total reward: -2195
# Episode 166 complete. Total reward: -2155
# Episode 167 complete. Total reward: -2147
# Episode 168 complete. Total reward: -2103
# Episode 169 complete. Total reward: -2157
# Episode 170 complete. Total reward: -2088
# Episode 171 complete. Total reward: -2196
# Episode 172 complete. Total reward: -2134
# Episode 173 complete. Total reward: -2118
# Episode 174 complete. Total reward: -2146
# Episode 175 complete. Total reward: -2166
# Episode 176 complete. Total reward: -2113
# Episode 177 complete. Total reward: -2146
# Episode 178 complete. Total reward: -2082
# Episode 179 complete. Total reward: -2108
# Episode 180 complete. Total reward: -2124
# Episode 181 complete. Total reward: -2110
# Episode 182 complete. Total reward: -2140
# Episode 183 complete. Total reward: -2191
# Episode 184 complete. Total reward: -2213
# Episode 185 complete. Total reward: -2052
# Episode 186 complete. Total reward: -2222
# Episode 187 complete. Total reward: -2129
# Episode 188 complete. Total reward: -2126
# Episode 189 complete. Total reward: -2195
# Episode 190 complete. Total reward: -2088
# Episode 191 complete. Total reward: -2173
# Episode 192 complete. Total reward: -2169
# Episode 193 complete. Total reward: -2126
# Episode 194 complete. Total reward: -2189
# Episode 195 complete. Total reward: -2130
# Episode 196 complete. Total reward: -2154
# Episode 197 complete. Total reward: -2165
# Episode 198 complete. Total reward: -2158
# Episode 199 complete. Total reward: -2215
# Episode 200 complete. Total reward: -2190
# Episode 201 complete. Total reward: -2219
# Episode 202 complete. Total reward: -2209
# Episode 203 complete. Total reward: -2138
# Episode 204 complete. Total reward: -2111
# Episode 205 complete. Total reward: -2100
# Episode 206 complete. Total reward: -2165
# Episode 207 complete. Total reward: -2224
# Episode 208 complete. Total reward: -2124
# Episode 209 complete. Total reward: -2154
# Episode 210 complete. Total reward: -2157
# Episode 211 complete. Total reward: -2106
# Episode 212 complete. Total reward: -2104
# Episode 213 complete. Total reward: -2133
# Episode 214 complete. Total reward: -2148
# Episode 215 complete. Total reward: -2185
# Episode 216 complete. Total reward: -2160
# Episode 217 complete. Total reward: -2148
# Episode 218 complete. Total reward: -2173
# Episode 219 complete. Total reward: -2068
# Episode 220 complete. Total reward: -2182
# Episode 221 complete. Total reward: -2083
# Episode 222 complete. Total reward: -2168
# Episode 223 complete. Total reward: -2128
# Episode 224 complete. Total reward: -2104
# Episode 225 complete. Total reward: -2104
# Episode 226 complete. Total reward: -2177
# Episode 227 complete. Total reward: -2154
# Episode 228 complete. Total reward: -2084
# Episode 229 complete. Total reward: -2150
# Episode 230 complete. Total reward: -2082
# Episode 231 complete. Total reward: -2055
# Episode 232 complete. Total reward: -2138
# Episode 233 complete. Total reward: -2067
# Episode 234 complete. Total reward: -2129
# Episode 235 complete. Total reward: -2073
# Episode 236 complete. Total reward: -2096
# Episode 237 complete. Total reward: -2173
# Episode 238 complete. Total reward: -2133
# Episode 239 complete. Total reward: -2117
# Episode 240 complete. Total reward: -2113
# Episode 241 complete. Total reward: -2166
# Episode 242 complete. Total reward: -2181
# Episode 243 complete. Total reward: -2050
# Episode 244 complete. Total reward: -2167
# Episode 245 complete. Total reward: -2191
# Episode 246 complete. Total reward: -2174
# Episode 247 complete. Total reward: -2078
# Episode 248 complete. Total reward: -2210
# Episode 249 complete. Total reward: -2115
# Episode 250 complete. Total reward: -2215
# Episode 251 complete. Total reward: -2073
# Episode 252 complete. Total reward: -2149
# Episode 253 complete. Total reward: -2090
# Episode 254 complete. Total reward: -2147
# Episode 255 complete. Total reward: -2199
# Episode 256 complete. Total reward: -2129
# Episode 257 complete. Total reward: -2121
# Episode 258 complete. Total reward: -2164
# Episode 259 complete. Total reward: -2156
# Episode 260 complete. Total reward: -2120
# Episode 261 complete. Total reward: -2126
# Episode 262 complete. Total reward: -2116
# Episode 263 complete. Total reward: -2182
# Episode 264 complete. Total reward: -2230
# Episode 265 complete. Total reward: -2099
# Episode 266 complete. Total reward: -2184
# Episode 267 complete. Total reward: -2223
# Episode 268 complete. Total reward: -2166
# Episode 269 complete. Total reward: -2137
# Episode 270 complete. Total reward: -2132
# Episode 271 complete. Total reward: -2070
# Episode 272 complete. Total reward: -2186
# Episode 273 complete. Total reward: -2201
# Episode 274 complete. Total reward: -2120
# Episode 275 complete. Total reward: -2195
# Episode 276 complete. Total reward: -2117
# Episode 277 complete. Total reward: -2168
# Episode 278 complete. Total reward: -2094
# Episode 279 complete. Total reward: -2125
# Episode 280 complete. Total reward: -2110
# Episode 281 complete. Total reward: -2140
# Episode 282 complete. Total reward: -2168
# Episode 283 complete. Total reward: -2163
# Episode 284 complete. Total reward: -2130
# Episode 285 complete. Total reward: -2155
# Episode 286 complete. Total reward: -2208
# Episode 287 complete. Total reward: -2124
# Episode 288 complete. Total reward: -2149
# Episode 289 complete. Total reward: -2162
# Episode 290 complete. Total reward: -2162
# Episode 291 complete. Total reward: -2124
# Episode 292 complete. Total reward: -2210
# Episode 293 complete. Total reward: -2165
# Episode 294 complete. Total reward: -2138
# Episode 295 complete. Total reward: -2131
# Episode 296 complete. Total reward: -2183
# Episode 297 complete. Total reward: -2122
# Episode 298 complete. Total reward: -2119
# Episode 299 complete. Total reward: -2124
# Episode 300 complete. Total reward: -2191
# Episode 301 complete. Total reward: -2142
# Episode 302 complete. Total reward: -2088
# Episode 303 complete. Total reward: -2175
# Episode 304 complete. Total reward: -2146
# Episode 305 complete. Total reward: -2150
# Episode 306 complete. Total reward: -2157
# Episode 307 complete. Total reward: -2189
# Episode 308 complete. Total reward: -2151
# Episode 309 complete. Total reward: -2167
# Episode 310 complete. Total reward: -2158
# Episode 311 complete. Total reward: -2184
# Episode 312 complete. Total reward: -2145
# Episode 313 complete. Total reward: -2132
# Episode 314 complete. Total reward: -2175
# Episode 315 complete. Total reward: -2099
# Episode 316 complete. Total reward: -2121
# Episode 317 complete. Total reward: -2136
# Episode 318 complete. Total reward: -2128
# Episode 319 complete. Total reward: -2150
# Episode 320 complete. Total reward: -2154
# Episode 321 complete. Total reward: -2131
# Episode 322 complete. Total reward: -2161
# Episode 323 complete. Total reward: -2180
# Episode 324 complete. Total reward: -2143
# Episode 325 complete. Total reward: -2158
# Episode 326 complete. Total reward: -2093
# Episode 327 complete. Total reward: -2161
# Episode 328 complete. Total reward: -2114
# Episode 329 complete. Total reward: -2190
# Episode 330 complete. Total reward: -2202
# Episode 331 complete. Total reward: -2162
# Episode 332 complete. Total reward: -2209
# Episode 333 complete. Total reward: -2139
# Episode 334 complete. Total reward: -2145
# Episode 335 complete. Total reward: -2147
# Episode 336 complete. Total reward: -2115
# Episode 337 complete. Total reward: -2064
# Episode 338 complete. Total reward: -2135
# Episode 339 complete. Total reward: -2127
# Episode 340 complete. Total reward: -2142
# Episode 341 complete. Total reward: -2189
# Episode 342 complete. Total reward: -2200
# Episode 343 complete. Total reward: -2128
# Episode 344 complete. Total reward: -2145
# Episode 345 complete. Total reward: -2157
# Episode 346 complete. Total reward: -2212
# Episode 347 complete. Total reward: -2152
# Episode 348 complete. Total reward: -2160
# Episode 349 complete. Total reward: -2111
# Episode 350 complete. Total reward: -2114
# Episode 351 complete. Total reward: -2169
# Episode 352 complete. Total reward: -2127
# Episode 353 complete. Total reward: -2225
# Episode 354 complete. Total reward: -2135
# Episode 355 complete. Total reward: -2213
# Episode 356 complete. Total reward: -2059
# Episode 357 complete. Total reward: -2082
# Episode 358 complete. Total reward: -2132
# Episode 359 complete. Total reward: -2163
# Episode 360 complete. Total reward: -2162
# Episode 361 complete. Total reward: -2153
# Episode 362 complete. Total reward: -2127
# Episode 363 complete. Total reward: -2148
# Episode 364 complete. Total reward: -2104
# Episode 365 complete. Total reward: -2193
# Episode 366 complete. Total reward: -2119
# Episode 367 complete. Total reward: -2133
# Episode 368 complete. Total reward: -2199
# Episode 369 complete. Total reward: -2196
# Episode 370 complete. Total reward: -2057
# Episode 371 complete. Total reward: -2090
# Episode 372 complete. Total reward: -2172
# Episode 373 complete. Total reward: -2188
# Episode 374 complete. Total reward: -2127
# Episode 375 complete. Total reward: -2227
# Episode 376 complete. Total reward: -2124
# Episode 377 complete. Total reward: -2097
# Episode 378 complete. Total reward: -2147
# Episode 379 complete. Total reward: -2055
# Episode 380 complete. Total reward: -2192
# Episode 381 complete. Total reward: -2125
# Episode 382 complete. Total reward: -2117
# Episode 383 complete. Total reward: -2127
# Episode 384 complete. Total reward: -2108
# Episode 385 complete. Total reward: -2105
# Episode 386 complete. Total reward: -2167
# Episode 387 complete. Total reward: -2156
# Episode 388 complete. Total reward: -2135
# Episode 389 complete. Total reward: -2246
# Episode 390 complete. Total reward: -2162
# Episode 391 complete. Total reward: -2128
# Episode 392 complete. Total reward: -2177
# Episode 393 complete. Total reward: -2188
# Episode 394 complete. Total reward: -2192
# Episode 395 complete. Total reward: -2178
# Episode 396 complete. Total reward: -2158
# Episode 397 complete. Total reward: -2146
# Episode 398 complete. Total reward: -2177
# Episode 399 complete. Total reward: -2154
# Episode 400 complete. Total reward: -2118
# Episode 401 complete. Total reward: -2144
# Episode 402 complete. Total reward: -2112
# Episode 403 complete. Total reward: -2156
# Episode 404 complete. Total reward: -2079
# Episode 405 complete. Total reward: -2098
# Episode 406 complete. Total reward: -2098
# Episode 407 complete. Total reward: -2193
# Episode 408 complete. Total reward: -2174
# Episode 409 complete. Total reward: -2098
# Episode 410 complete. Total reward: -2240
# Episode 411 complete. Total reward: -2075
# Episode 412 complete. Total reward: -2202
# Episode 413 complete. Total reward: -2067
# Episode 414 complete. Total reward: -2133
# Episode 415 complete. Total reward: -2199
# Episode 416 complete. Total reward: -2107
# Episode 417 complete. Total reward: -2199
# Episode 418 complete. Total reward: -2165
# Episode 419 complete. Total reward: -2148
# Episode 420 complete. Total reward: -2129
# Episode 421 complete. Total reward: -2111
# Episode 422 complete. Total reward: -2129
# Episode 423 complete. Total reward: -2130
# Episode 424 complete. Total reward: -2190
# Episode 425 complete. Total reward: -2118
# Episode 426 complete. Total reward: -2151
# Episode 427 complete. Total reward: -2068
# Episode 428 complete. Total reward: -2149
# Episode 429 complete. Total reward: -2169
# Episode 430 complete. Total reward: -2156
# Episode 431 complete. Total reward: -2104
# Episode 432 complete. Total reward: -2154
# Episode 433 complete. Total reward: -2134
# Episode 434 complete. Total reward: -2129
# Episode 435 complete. Total reward: -2200
# Episode 436 complete. Total reward: -2115
# Episode 437 complete. Total reward: -2124
# Episode 438 complete. Total reward: -2176
# Episode 439 complete. Total reward: -2193
# Episode 440 complete. Total reward: -2098
# Episode 441 complete. Total reward: -2205
# Episode 442 complete. Total reward: -2056
# Episode 443 complete. Total reward: -2189
# Episode 444 complete. Total reward: -2148
# Episode 445 complete. Total reward: -2105
# Episode 446 complete. Total reward: -2213
# Episode 447 complete. Total reward: -2161
# Episode 448 complete. Total reward: -2182
# Episode 449 complete. Total reward: -2092
# Episode 450 complete. Total reward: -2169
# Episode 451 complete. Total reward: -2115
# Episode 452 complete. Total reward: -2150
# Episode 453 complete. Total reward: -2124
# Episode 454 complete. Total reward: -2171
# Episode 455 complete. Total reward: -2099
# Episode 456 complete. Total reward: -2189
# Episode 457 complete. Total reward: -2162
# Episode 458 complete. Total reward: -2142
# Episode 459 complete. Total reward: -2110
# Episode 460 complete. Total reward: -2159
# Episode 461 complete. Total reward: -2171
# Episode 462 complete. Total reward: -2100
# Episode 463 complete. Total reward: -2131
# Episode 464 complete. Total reward: -2080
# Episode 465 complete. Total reward: -2145
# Episode 466 complete. Total reward: -2122
# Episode 467 complete. Total reward: -2124
# Episode 468 complete. Total reward: -2055
# Episode 469 complete. Total reward: -2111
# Episode 470 complete. Total reward: -2179
# Episode 471 complete. Total reward: -2109
# Episode 472 complete. Total reward: -2196
# Episode 473 complete. Total reward: -2138
# Episode 474 complete. Total reward: -2191
# Episode 475 complete. Total reward: -2162
# Episode 476 complete. Total reward: -2128
# Episode 477 complete. Total reward: -2163
# Episode 478 complete. Total reward: -2248
# Episode 479 complete. Total reward: -2171
# Episode 480 complete. Total reward: -2106
# Episode 481 complete. Total reward: -2182
# Episode 482 complete. Total reward: -2190
# Episode 483 complete. Total reward: -2225
# Episode 484 complete. Total reward: -2199
# Episode 485 complete. Total reward: -2151
# Episode 486 complete. Total reward: -2047
# Episode 487 complete. Total reward: -2135
# Episode 488 complete. Total reward: -2157
# Episode 489 complete. Total reward: -2215
# Episode 490 complete. Total reward: -2232
# Episode 491 complete. Total reward: -2186
# Episode 492 complete. Total reward: -2115
# Episode 493 complete. Total reward: -2099
# Episode 494 complete. Total reward: -2127
# Episode 495 complete. Total reward: -2153
# Episode 496 complete. Total reward: -2161
# Episode 497 complete. Total reward: -2177
# Episode 498 complete. Total reward: -2188
# Episode 499 complete. Total reward: -2196
# Episode 500 complete. Total reward: -2161
# Training complete! Now visualizing a final episode...

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pygame
import math

class CutSquareEnv(gym.Env):
    def __init__(self, grid_size=50, square_top=10, square_bottom=40, square_left=10, square_right=40):
        super().__init__()
        self.grid_size = grid_size
        self.observation_space = spaces.Box(low=0, high=1, shape=(grid_size, grid_size), dtype=np.int32)
        self.action_space = spaces.MultiDiscrete([grid_size, grid_size])
        
        # Square and inscribed circle parameters
        self.square_top = square_top
        self.square_bottom = square_bottom
        self.square_left = square_left
        self.square_right = square_right
        self.center = ((square_left + square_right) / 2, (square_top + square_bottom) / 2)
        self.circle_radius = (square_right - square_left) / 4  # Quarter the side length of the square
        
        # Pygame rendering setup
        pygame.init()
        self.cell_size = 10
        self.screen = pygame.display.set_mode((grid_size * self.cell_size, grid_size * self.cell_size))
        pygame.display.set_caption("Cut Square Environment")
        self.clock = pygame.time.Clock()
        
        self.reset()

    def reset(self, seed=None, options=None):
        self.grid = np.zeros((self.grid_size, self.grid_size), dtype=np.int32)
        self.grid[self.square_top:self.square_bottom, self.square_left:self.square_right] = 1  # Fill the square
        self.steps = 0
        return self.grid.copy(), {}

    def step(self, action):
        x, y = action
        reward = 0
        info = {}

        if self.grid[y, x] == 0:
            reward = -5  # Heavy penalty for selecting an already removed cell
        else:
            if self._is_edge(x, y):
                self.grid[y, x] = 0  # Remove the cell
                reward += 2  # Reward for correctly removing an edge pixel

                # Distance-based shaping incentive
                dist = math.hypot(x - self.center[0], y - self.center[1])
                if dist >= self.circle_radius:
                    reward += 3  # Reward for shaping towards a circle
                else:
                    reward -= 3  # Penalty for removing pixels inside the ideal circle too soon
            else:
                reward -= 4  # Heavy penalty if removing an internal pixel

        self.steps += 1
        done = self._is_circle_formed() or (self.steps >= 1000)
        return self.grid.copy(), reward, done, False, info

    def _is_edge(self, x, y):
        """A pixel is an edge if it's part of the square and at least one of its neighbors is removed or outside the square."""
        if self.grid[y, x] == 0:
            return False  # Already removed, not an edge

        for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
            nx, ny = x + dx, y + dy
            if not (self.square_left <= nx < self.square_right and self.square_top <= ny < self.square_bottom):
                return True  # Near the square boundary
            if self.grid[ny, nx] == 0:
                return True  # Neighbor is removed
        
        return False  # Otherwise, it's an internal pixel

    def _is_circle_formed(self):
        """Check if only the inscribed circle remains and all excess pixels are removed."""
        indices = np.indices(self.grid.shape)
        xs, ys = indices[1], indices[0]

        # Mask only the remaining filled pixels inside the original square
        mask = (self.grid == 1) & (self.square_left <= xs) & (xs < self.square_right) & (self.square_top <= ys) & (ys < self.square_bottom)

        # Compute Euclidean distance from the center
        dists = np.sqrt((xs - self.center[0])**2 + (ys - self.center[1])**2)

        # The process is done when all remaining pixels are within the inscribed circle
        return np.all(mask & (dists <= self.circle_radius))

    def render(self):
        """Render the grid with Pygame."""
        self.screen.fill((0, 0, 0))
        for y in range(self.grid_size):
            for x in range(self.grid_size):
                if self.grid[y, x] == 1:
                    # Check if it's part of the inscribed circle
                    dist = math.hypot(x - self.center[0], y - self.center[1])
                    if dist <= self.circle_radius:
                        color = (0, 255, 0)  # Green for inscribed circle
                    else:
                        color = (255, 255, 255)  # White for remaining square
                    rect = pygame.Rect(x * self.cell_size, y * self.cell_size, self.cell_size, self.cell_size)
                    pygame.draw.rect(self.screen, color, rect)
        pygame.display.flip()
        self.clock.tick(1000)

    def close(self):
        pygame.quit()

# Create the environment
env = CutSquareEnv()

# Training loop (without visualization)
for episode in range(500):
    state, _ = env.reset()
    done = False
    total_reward = 0
    while not done:
        action = env.action_space.sample()
        next_state, reward, done, _, _ = env.step(action)
        total_reward += reward
        state = next_state
    print(f"Episode {episode+1} complete. Total reward: {total_reward}")

print("Training complete! Now visualizing a final episode...")

# Final visualization
state, _ = env.reset()
done = False
while not done:
    action = env.action_space.sample()
    state, reward, done, _, _ = env.step(action)
    env.render()
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            done = True

env.close()
# Out:
# Episode 1 complete. Total reward: -4241
# Episode 2 complete. Total reward: -4285
# Episode 3 complete. Total reward: -4199
# Episode 4 complete. Total reward: -4293
# Episode 5 complete. Total reward: -4184
# Episode 6 complete. Total reward: -4334
# Episode 7 complete. Total reward: -4337
# Episode 8 complete. Total reward: -4173
# Episode 9 complete. Total reward: -4216
# Episode 10 complete. Total reward: -4234
# Episode 11 complete. Total reward: -4224
# Episode 12 complete. Total reward: -4245
# Episode 13 complete. Total reward: -4267
# Episode 14 complete. Total reward: -4087
# Episode 15 complete. Total reward: -4288
# Episode 16 complete. Total reward: -4145
# Episode 17 complete. Total reward: -4290
# Episode 18 complete. Total reward: -4089
# Episode 19 complete. Total reward: -4126
# Episode 20 complete. Total reward: -4091
# Episode 21 complete. Total reward: -4217
# Episode 22 complete. Total reward: -4169
# Episode 23 complete. Total reward: -4171
# Episode 24 complete. Total reward: -4180
# Episode 25 complete. Total reward: -4259
# Episode 26 complete. Total reward: -4179
# Episode 27 complete. Total reward: -4184
# Episode 28 complete. Total reward: -4273
# Episode 29 complete. Total reward: -4222
# Episode 30 complete. Total reward: -4104
# Episode 31 complete. Total reward: -4236
# Episode 32 complete. Total reward: -4190
# Episode 33 complete. Total reward: -4377
# Episode 34 complete. Total reward: -4272
# Episode 35 complete. Total reward: -4278
# Episode 36 complete. Total reward: -4364
# Episode 37 complete. Total reward: -4300
# Episode 38 complete. Total reward: -4123
# Episode 39 complete. Total reward: -4060
# Episode 40 complete. Total reward: -4157
# Episode 41 complete. Total reward: -4342
# Episode 42 complete. Total reward: -4222
# Episode 43 complete. Total reward: -4259
# Episode 44 complete. Total reward: -4206
# Episode 45 complete. Total reward: -4311
# Episode 46 complete. Total reward: -4279
# Episode 47 complete. Total reward: -4340
# Episode 48 complete. Total reward: -4117
# Episode 49 complete. Total reward: -4250
# Episode 50 complete. Total reward: -4162
# Episode 51 complete. Total reward: -4326
# Episode 52 complete. Total reward: -4219
# Episode 53 complete. Total reward: -4315
# Episode 54 complete. Total reward: -4171
# Episode 55 complete. Total reward: -4265
# Episode 56 complete. Total reward: -4133
# Episode 57 complete. Total reward: -4186
# Episode 58 complete. Total reward: -4312
# Episode 59 complete. Total reward: -4239
# Episode 60 complete. Total reward: -4109
# Episode 61 complete. Total reward: -4300
# Episode 62 complete. Total reward: -4255
# Episode 63 complete. Total reward: -4242
# Episode 64 complete. Total reward: -4192
# Episode 65 complete. Total reward: -4172
# Episode 66 complete. Total reward: -4140
# Episode 67 complete. Total reward: -4254
# Episode 68 complete. Total reward: -4196
# Episode 69 complete. Total reward: -4197
# Episode 70 complete. Total reward: -4182
# Episode 71 complete. Total reward: -4165
# Episode 72 complete. Total reward: -4242
# Episode 73 complete. Total reward: -4271
# Episode 74 complete. Total reward: -4216
# Episode 75 complete. Total reward: -4264
# Episode 76 complete. Total reward: -4202
# Episode 77 complete. Total reward: -4163
# Episode 78 complete. Total reward: -4258
# Episode 79 complete. Total reward: -4224
# Episode 80 complete. Total reward: -4198
# Episode 81 complete. Total reward: -4253
# Episode 82 complete. Total reward: -4189
# Episode 83 complete. Total reward: -4201
# Episode 84 complete. Total reward: -4334
# Episode 85 complete. Total reward: -4247
# Episode 86 complete. Total reward: -4261
# Episode 87 complete. Total reward: -4316
# Episode 88 complete. Total reward: -4249
# Episode 89 complete. Total reward: -4058
# Episode 90 complete. Total reward: -4188
# Episode 91 complete. Total reward: -4249
# Episode 92 complete. Total reward: -4254
# Episode 93 complete. Total reward: -4285
# Episode 94 complete. Total reward: -4176
# Episode 95 complete. Total reward: -4234
# Episode 96 complete. Total reward: -4185
# Episode 97 complete. Total reward: -4200
# Episode 98 complete. Total reward: -4109
# Episode 99 complete. Total reward: -4213
# Episode 100 complete. Total reward: -4292
# Episode 101 complete. Total reward: -4257
# Episode 102 complete. Total reward: -4098
# Episode 103 complete. Total reward: -4231
# Episode 104 complete. Total reward: -4226
# Episode 105 complete. Total reward: -4280
# Episode 106 complete. Total reward: -4267
# Episode 107 complete. Total reward: -4262
# Episode 108 complete. Total reward: -4129
# Episode 109 complete. Total reward: -4169
# Episode 110 complete. Total reward: -4269
# Episode 111 complete. Total reward: -4235
# Episode 112 complete. Total reward: -4239
# Episode 113 complete. Total reward: -4272
# Episode 114 complete. Total reward: -4147
# Episode 115 complete. Total reward: -4185
# Episode 116 complete. Total reward: -4082
# Episode 117 complete. Total reward: -4143
# Episode 118 complete. Total reward: -4203
# Episode 119 complete. Total reward: -4226
# Episode 120 complete. Total reward: -4257
# Episode 121 complete. Total reward: -4323
# Episode 122 complete. Total reward: -4174
# Episode 123 complete. Total reward: -4178
# Episode 124 complete. Total reward: -4236
# Episode 125 complete. Total reward: -4153
# Episode 126 complete. Total reward: -4178
# Episode 127 complete. Total reward: -4145
# Episode 128 complete. Total reward: -4265
# Episode 129 complete. Total reward: -4240
# Episode 130 complete. Total reward: -4188
# Episode 131 complete. Total reward: -4182
# Episode 132 complete. Total reward: -4188
# Episode 133 complete. Total reward: -4159
# Episode 134 complete. Total reward: -4277
# Episode 135 complete. Total reward: -4198
# Episode 136 complete. Total reward: -4173
# Episode 137 complete. Total reward: -4298
# Episode 138 complete. Total reward: -4305
# Episode 139 complete. Total reward: -4223
# Episode 140 complete. Total reward: -4308
# Episode 141 complete. Total reward: -4250
# Episode 142 complete. Total reward: -4187
# Episode 143 complete. Total reward: -4239
# Episode 144 complete. Total reward: -4206
# Episode 145 complete. Total reward: -4245
# Episode 146 complete. Total reward: -4213
# Episode 147 complete. Total reward: -4179
# Episode 148 complete. Total reward: -4189
# Episode 149 complete. Total reward: -4252
# Episode 150 complete. Total reward: -4289
# Episode 151 complete. Total reward: -4259
# Episode 152 complete. Total reward: -4231
# Episode 153 complete. Total reward: -4319
# Episode 154 complete. Total reward: -4221
# Episode 155 complete. Total reward: -4272
# Episode 156 complete. Total reward: -4374
# Episode 157 complete. Total reward: -4317
# Episode 158 complete. Total reward: -4160
# Episode 159 complete. Total reward: -4286
# Episode 160 complete. Total reward: -4238
# Episode 161 complete. Total reward: -4168
# Episode 162 complete. Total reward: -4253
# Episode 163 complete. Total reward: -4201
# Episode 164 complete. Total reward: -4265
# Episode 165 complete. Total reward: -4188
# Episode 166 complete. Total reward: -4348
# Episode 167 complete. Total reward: -4159
# Episode 168 complete. Total reward: -4214
# Episode 169 complete. Total reward: -4114
# Episode 170 complete. Total reward: -4257
# Episode 171 complete. Total reward: -4263
# Episode 172 complete. Total reward: -4243
# Episode 173 complete. Total reward: -4334
# Episode 174 complete. Total reward: -4232
# Episode 175 complete. Total reward: -4258
# Episode 176 complete. Total reward: -4228
# Episode 177 complete. Total reward: -4341
# Episode 178 complete. Total reward: -4160
# Episode 179 complete. Total reward: -4326
# Episode 180 complete. Total reward: -4197
# Episode 181 complete. Total reward: -4158
# Episode 182 complete. Total reward: -4221
# Episode 183 complete. Total reward: -4193
# Episode 184 complete. Total reward: -4226
# Episode 185 complete. Total reward: -4245
# Episode 186 complete. Total reward: -4272
# Episode 187 complete. Total reward: -4258
# Episode 188 complete. Total reward: -4196
# Episode 189 complete. Total reward: -4255
# Episode 190 complete. Total reward: -4218
# Episode 191 complete. Total reward: -4297
# Episode 192 complete. Total reward: -4255
# Episode 193 complete. Total reward: -4110
# Episode 194 complete. Total reward: -4205
# Episode 195 complete. Total reward: -4199
# Episode 196 complete. Total reward: -4262
# Episode 197 complete. Total reward: -4184
# Episode 198 complete. Total reward: -4178
# Episode 199 complete. Total reward: -4224
# Episode 200 complete. Total reward: -4204
# Episode 201 complete. Total reward: -4280
# Episode 202 complete. Total reward: -4290
# Episode 203 complete. Total reward: -4340
# Episode 204 complete. Total reward: -4229
# Episode 205 complete. Total reward: -4191
# Episode 206 complete. Total reward: -4321
# Episode 207 complete. Total reward: -4176
# Episode 208 complete. Total reward: -4262
# Episode 209 complete. Total reward: -4200
# Episode 210 complete. Total reward: -4235
# Episode 211 complete. Total reward: -4283
# Episode 212 complete. Total reward: -4258
# Episode 213 complete. Total reward: -4354
# Episode 214 complete. Total reward: -4292
# Episode 215 complete. Total reward: -4192
# Episode 216 complete. Total reward: -4253
# Episode 217 complete. Total reward: -4140
# Episode 218 complete. Total reward: -4250
# Episode 219 complete. Total reward: -4281
# Episode 220 complete. Total reward: -4258
# Episode 221 complete. Total reward: -4208
# Episode 222 complete. Total reward: -4212
# Episode 223 complete. Total reward: -4177
# Episode 224 complete. Total reward: -4353
# Episode 225 complete. Total reward: -4162
# Episode 226 complete. Total reward: -4150
# Episode 227 complete. Total reward: -4145
# Episode 228 complete. Total reward: -4241
# Episode 229 complete. Total reward: -4174
# Episode 230 complete. Total reward: -4215
# Episode 231 complete. Total reward: -4323
# Episode 232 complete. Total reward: -4220
# Episode 233 complete. Total reward: -4356
# Episode 234 complete. Total reward: -4177
# Episode 235 complete. Total reward: -4236
# Episode 236 complete. Total reward: -4254
# Episode 237 complete. Total reward: -4261
# Episode 238 complete. Total reward: -4307
# Episode 239 complete. Total reward: -4246
# Episode 240 complete. Total reward: -4247
# Episode 241 complete. Total reward: -4177
# Episode 242 complete. Total reward: -4265
# Episode 243 complete. Total reward: -4266
# Episode 244 complete. Total reward: -4176
# Episode 245 complete. Total reward: -4144
# Episode 246 complete. Total reward: -4204
# Episode 247 complete. Total reward: -4219
# Episode 248 complete. Total reward: -4212
# Episode 249 complete. Total reward: -4325
# Episode 250 complete. Total reward: -4213
# Episode 251 complete. Total reward: -4303
# Episode 252 complete. Total reward: -4287
# Episode 253 complete. Total reward: -4259
# Episode 254 complete. Total reward: -4269
# Episode 255 complete. Total reward: -4178
# Episode 256 complete. Total reward: -4250
# Episode 257 complete. Total reward: -4110
# Episode 258 complete. Total reward: -4297
# Episode 259 complete. Total reward: -4184
# Episode 260 complete. Total reward: -4147
# Episode 261 complete. Total reward: -4258
# Episode 262 complete. Total reward: -4239
# Episode 263 complete. Total reward: -4271
# Episode 264 complete. Total reward: -4148
# Episode 265 complete. Total reward: -4382
# Episode 266 complete. Total reward: -4274
# Episode 267 complete. Total reward: -4223
# Episode 268 complete. Total reward: -4275
# Episode 269 complete. Total reward: -4248
# Episode 270 complete. Total reward: -4301
# Episode 271 complete. Total reward: -4171
# Episode 272 complete. Total reward: -4253
# Episode 273 complete. Total reward: -4152
# Episode 274 complete. Total reward: -4219
# Episode 275 complete. Total reward: -4102
# Episode 276 complete. Total reward: -4052
# Episode 277 complete. Total reward: -4185
# Episode 278 complete. Total reward: -4240
# Episode 279 complete. Total reward: -4322
# Episode 280 complete. Total reward: -4179
# Episode 281 complete. Total reward: -4147
# Episode 282 complete. Total reward: -4269
# Episode 283 complete. Total reward: -4245
# Episode 284 complete. Total reward: -4260
# Episode 285 complete. Total reward: -4208
# Episode 286 complete. Total reward: -4217
# Episode 287 complete. Total reward: -4182
# Episode 288 complete. Total reward: -4311
# Episode 289 complete. Total reward: -4294
# Episode 290 complete. Total reward: -4176
# Episode 291 complete. Total reward: -4268
# Episode 292 complete. Total reward: -4283
# Episode 293 complete. Total reward: -4208
# Episode 294 complete. Total reward: -4290
# Episode 295 complete. Total reward: -4180
# Episode 296 complete. Total reward: -4190
# Episode 297 complete. Total reward: -4240
# Episode 298 complete. Total reward: -4102
# Episode 299 complete. Total reward: -4211
# Episode 300 complete. Total reward: -4365
# Episode 301 complete. Total reward: -4285
# Episode 302 complete. Total reward: -4195
# Episode 303 complete. Total reward: -4294
# Episode 304 complete. Total reward: -4054
# Episode 305 complete. Total reward: -4243
# Episode 306 complete. Total reward: -4295
# Episode 307 complete. Total reward: -4262
# Episode 308 complete. Total reward: -4154
# Episode 309 complete. Total reward: -4219
# Episode 310 complete. Total reward: -4219
# Episode 311 complete. Total reward: -4265
# Episode 312 complete. Total reward: -4157
# Episode 313 complete. Total reward: -4100
# Episode 314 complete. Total reward: -4093
# Episode 315 complete. Total reward: -4261
# Episode 316 complete. Total reward: -4327
# Episode 317 complete. Total reward: -4314
# Episode 318 complete. Total reward: -4183
# Episode 319 complete. Total reward: -4188
# Episode 320 complete. Total reward: -4222
# Episode 321 complete. Total reward: -4177
# Episode 322 complete. Total reward: -4271
# Episode 323 complete. Total reward: -4276
# Episode 324 complete. Total reward: -4134
# Episode 325 complete. Total reward: -4271
# Episode 326 complete. Total reward: -4272
# Episode 327 complete. Total reward: -4203
# Episode 328 complete. Total reward: -4240
# Episode 329 complete. Total reward: -4316
# Episode 330 complete. Total reward: -4205
# Episode 331 complete. Total reward: -4151
# Episode 332 complete. Total reward: -4249
# Episode 333 complete. Total reward: -4277
# Episode 334 complete. Total reward: -4204
# Episode 335 complete. Total reward: -4195
# Episode 336 complete. Total reward: -4135
# Episode 337 complete. Total reward: -4382
# Episode 338 complete. Total reward: -4311
# Episode 339 complete. Total reward: -4172
# Episode 340 complete. Total reward: -4262
# Episode 341 complete. Total reward: -4207
# Episode 342 complete. Total reward: -4234
# Episode 343 complete. Total reward: -4222
# Episode 344 complete. Total reward: -4138
# Episode 345 complete. Total reward: -4345
# Episode 346 complete. Total reward: -4315
# Episode 347 complete. Total reward: -4081
# Episode 348 complete. Total reward: -4261
# Episode 349 complete. Total reward: -4340
# Episode 350 complete. Total reward: -4266
# Episode 351 complete. Total reward: -4219
# Episode 352 complete. Total reward: -4251
# Episode 353 complete. Total reward: -4186
# Episode 354 complete. Total reward: -4089
# Episode 355 complete. Total reward: -4218
# Episode 356 complete. Total reward: -4295
# Episode 357 complete. Total reward: -4288
# Episode 358 complete. Total reward: -4265
# Episode 359 complete. Total reward: -4225
# Episode 360 complete. Total reward: -4184
# Episode 361 complete. Total reward: -4135
# Episode 362 complete. Total reward: -4136
# Episode 363 complete. Total reward: -4282
# Episode 364 complete. Total reward: -4215
# Episode 365 complete. Total reward: -4230
# Episode 366 complete. Total reward: -4203
# Episode 367 complete. Total reward: -4246
# Episode 368 complete. Total reward: -4250
# Episode 369 complete. Total reward: -4166
# Episode 370 complete. Total reward: -4279
# Episode 371 complete. Total reward: -4218
# Episode 372 complete. Total reward: -4214
# Episode 373 complete. Total reward: -4211
# Episode 374 complete. Total reward: -4218
# Episode 375 complete. Total reward: -4311
# Episode 376 complete. Total reward: -4308
# Episode 377 complete. Total reward: -4229
# Episode 378 complete. Total reward: -4236
# Episode 379 complete. Total reward: -4223
# Episode 380 complete. Total reward: -4169
# Episode 381 complete. Total reward: -4349
# Episode 382 complete. Total reward: -4280
# Episode 383 complete. Total reward: -4305
# Episode 384 complete. Total reward: -4209
# Episode 385 complete. Total reward: -4339
# Episode 386 complete. Total reward: -4252
# Episode 387 complete. Total reward: -4269
# Episode 388 complete. Total reward: -4112
# Episode 389 complete. Total reward: -4284
# Episode 390 complete. Total reward: -4238
# Episode 391 complete. Total reward: -4149
# Episode 392 complete. Total reward: -4218
# Episode 393 complete. Total reward: -4377
# Episode 394 complete. Total reward: -4244
# Episode 395 complete. Total reward: -4081
# Episode 396 complete. Total reward: -3992
# Episode 397 complete. Total reward: -4131
# Episode 398 complete. Total reward: -4214
# Episode 399 complete. Total reward: -4242
# Episode 400 complete. Total reward: -4310
# Episode 401 complete. Total reward: -4230
# Episode 402 complete. Total reward: -4263
# Episode 403 complete. Total reward: -4129
# Episode 404 complete. Total reward: -4362
# Episode 405 complete. Total reward: -4212
# Episode 406 complete. Total reward: -4275
# Episode 407 complete. Total reward: -4358
# Episode 408 complete. Total reward: -4342
# Episode 409 complete. Total reward: -4198
# Episode 410 complete. Total reward: -4360
# Episode 411 complete. Total reward: -4244
# Episode 412 complete. Total reward: -4271
# Episode 413 complete. Total reward: -4180
# Episode 414 complete. Total reward: -4112
# Episode 415 complete. Total reward: -4222
# Episode 416 complete. Total reward: -4186
# Episode 417 complete. Total reward: -4134
# Episode 418 complete. Total reward: -4250
# Episode 419 complete. Total reward: -4228
# Episode 420 complete. Total reward: -4234
# Episode 421 complete. Total reward: -4300
# Episode 422 complete. Total reward: -4218
# Episode 423 complete. Total reward: -4111
# Episode 424 complete. Total reward: -4316
# Episode 425 complete. Total reward: -4312
# Episode 426 complete. Total reward: -4135
# Episode 427 complete. Total reward: -4227
# Episode 428 complete. Total reward: -4188
# Episode 429 complete. Total reward: -4261
# Episode 430 complete. Total reward: -4267
# Episode 431 complete. Total reward: -4226
# Episode 432 complete. Total reward: -4299
# Episode 433 complete. Total reward: -4295
# Episode 434 complete. Total reward: -4138
# Episode 435 complete. Total reward: -4255
# Episode 436 complete. Total reward: -4215
# Episode 437 complete. Total reward: -4086
# Episode 438 complete. Total reward: -4203
# Episode 439 complete. Total reward: -4131
# Episode 440 complete. Total reward: -4311
# Episode 441 complete. Total reward: -4272
# Episode 442 complete. Total reward: -4323
# Episode 443 complete. Total reward: -4226
# Episode 444 complete. Total reward: -4339
# Episode 445 complete. Total reward: -4176
# Episode 446 complete. Total reward: -4142
# Episode 447 complete. Total reward: -4216
# Episode 448 complete. Total reward: -4157
# Episode 449 complete. Total reward: -4171
# Episode 450 complete. Total reward: -4309
# Episode 451 complete. Total reward: -4227
# Episode 452 complete. Total reward: -4219
# Episode 453 complete. Total reward: -4163
# Episode 454 complete. Total reward: -4276
# Episode 455 complete. Total reward: -4248
# Episode 456 complete. Total reward: -4211
# Episode 457 complete. Total reward: -4197
# Episode 458 complete. Total reward: -4166
# Episode 459 complete. Total reward: -4220
# Episode 460 complete. Total reward: -4164
# Episode 461 complete. Total reward: -4150
# Episode 462 complete. Total reward: -4351
# Episode 463 complete. Total reward: -4255
# Episode 464 complete. Total reward: -4200
# Episode 465 complete. Total reward: -4130
# Episode 466 complete. Total reward: -4202
# Episode 467 complete. Total reward: -4303
# Episode 468 complete. Total reward: -4216
# Episode 469 complete. Total reward: -4162
# Episode 470 complete. Total reward: -4093
# Episode 471 complete. Total reward: -4185
# Episode 472 complete. Total reward: -4146
# Episode 473 complete. Total reward: -4184
# Episode 474 complete. Total reward: -4231
# Episode 475 complete. Total reward: -4215
# Episode 476 complete. Total reward: -4226
# Episode 477 complete. Total reward: -4247
# Episode 478 complete. Total reward: -4320
# Episode 479 complete. Total reward: -4298
# Episode 480 complete. Total reward: -4143
# Episode 481 complete. Total reward: -4117
# Episode 482 complete. Total reward: -4171
# Episode 483 complete. Total reward: -4209
# Episode 484 complete. Total reward: -4239
# Episode 485 complete. Total reward: -4237
# Episode 486 complete. Total reward: -4197
# Episode 487 complete. Total reward: -4230
# Episode 488 complete. Total reward: -4230
# Episode 489 complete. Total reward: -4172
# Episode 490 complete. Total reward: -4124
# Episode 491 complete. Total reward: -4270
# Episode 492 complete. Total reward: -4237
# Episode 493 complete. Total reward: -4168
# Episode 494 complete. Total reward: -4285
# Episode 495 complete. Total reward: -4296
# Episode 496 complete. Total reward: -4223
# Episode 497 complete. Total reward: -4257
# Episode 498 complete. Total reward: -4195
# Episode 499 complete. Total reward: -4263
# Episode 500 complete. Total reward: -4141
# Training complete! Now visualizing a final episode...
