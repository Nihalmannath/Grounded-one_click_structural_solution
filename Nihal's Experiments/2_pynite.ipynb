# %%
# %pip install PyniteFEA[all]
# %pip install Pynite
# %pip install trimesh
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: PyniteFEA[all] in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (1.0.1)
# ...
# WARNING: pyvista 0.44.2 does not provide the extra 'trame'
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached trimesh-4.6.4-py3-none-any.whl.metadata (18 kB)
# ...
# Using cached trimesh-4.6.4-py3-none-any.whl (708 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import trimesh
from Pynite.FEModel3D import FEModel3D

# Load the OBJ file
mesh = trimesh.load(r"C:\Users\LEGION\Documents\GitHub\Octopusie\sahils experiments\Reference files\3d model for detection.obj")

#Create a new PyNite model
model = FEModel3D()

# Define a 'Steel' material to prevent the NameError
E = 29000       # Modulus of elasticity (ksi)
G = 11200       # Shear modulus of elasticity (ksi)
nu = 0.3        # Poisson's ratio
rho = 2.836e-4  # Density (kci)
model.add_material('Steel', E, G, nu, rho)

# Extract vertices (nodes)
nodes = {}
for i, vertex in enumerate(mesh.vertices):
    x, y, z = vertex
    node_name = f"N{i}"
    model.add_node(node_name, x, y, z)
    nodes[i] = node_name  # Store node names for reference

# Extract edges (beams) from faces
for edge in mesh.edges:
    node1, node2 = edge
    model.add_member(f"Beam_{node1}_{node2}", nodes[node1], nodes[node2], "Steel", "Beam_Section")

print("OBJ Imported Successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\LEGION\Documents\GitHub\Octopusie\.venv\lib\site-packages\Pynite\Member3D.py:40, in Member3D.__init__(self, model, name, i_node, j_node, material_name, section_name, rotation, tension_only, comp_only)
#      39 try:
# ---> 40     self.section = model.sections[section_name] # The element's section
#      41 except KeyError:
#
# KeyError: 'Beam_Section'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 28
#      26 for edge in mesh.edges:
#      27     node1, node2 = edge
# ---> 28     model.add_member(f"Beam_{node1}_{node2}", nodes[node1], nodes[node2], "Steel", "Beam_Section")
#      30 print("OBJ Imported Successfully!")
#
# ...
