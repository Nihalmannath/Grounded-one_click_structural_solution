# %%
# %pip install PyniteFEA[all]
# %pip install Pynite
# %pip install trimesh
# Out:
# Requirement already satisfied: PyniteFEA[all] in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (2.2.3)
# Requirement already satisfied: PrettyTable in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (3.15.1)
# Requirement already satisfied: scipy in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (1.15.2)
# Requirement already satisfied: matplotlib in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (3.10.1)
# Requirement already satisfied: Ipython in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (9.0.2)
# Requirement already satisfied: vtk in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (9.3.1)
# Requirement already satisfied: pyvista[all,trame] in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (0.44.2)
# Collecting trame_jupyter_extension (from PyniteFEA[all])
#   Downloading trame_jupyter_extension-2.1.4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: ipywidgets in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (8.1.5)
# Collecting pdfkit (from PyniteFEA[all])
#   Downloading pdfkit-1.0.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: Jinja2 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (3.1.6)
# Requirement already satisfied: colorama in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (0.4.6)
# Requirement already satisfied: decorator in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (4.12.2)
# Requirement already satisfied: comm>=0.1.3 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from ipywidgets->PyniteFEA[all]) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from ipywidgets->PyniteFEA[all]) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from ipywidgets->PyniteFEA[all]) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Jinja2->PyniteFEA[all]) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (2.9.0.post0)
# Requirement already satisfied: wcwidth in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PrettyTable->PyniteFEA[all]) (0.2.13)
# Requirement already satisfied: pooch in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pyvista[all,trame]; extra == "all"->PyniteFEA[all]) (1.8.2)
# Requirement already satisfied: scooby>=0.5.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pyvista[all,trame]; extra == "all"->PyniteFEA[all]) (0.10.0)
# Collecting jupyter-server<3,>=2.0.1 (from trame_jupyter_extension->PyniteFEA[all])
#   Downloading jupyter_server-2.16.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyterlab<5,>=4 (from trame_jupyter_extension->PyniteFEA[all])
#   Downloading jupyterlab-4.4.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: trame>=3.2.7 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trame_jupyter_extension->PyniteFEA[all]) (3.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jedi>=0.16->Ipython->PyniteFEA[all]) (0.8.4)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (4.9.0)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (5.7.2)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting nbconvert>=6.4.4 (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (7.7.0)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading prometheus_client-0.22.0-py3-none-any.whl.metadata (14 kB)
# Collecting pywinpty>=2.0.1 (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading pywinpty-2.0.15-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: pyzmq>=24 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (26.3.0)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (6.4.2)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (1.8.0)
# Collecting async-lru>=1.0.0 (from jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all])
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (6.29.5)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all])
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all])
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim>=0.2 (from jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all])
#   Downloading notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (75.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib->PyniteFEA[all]) (1.17.0)
# Requirement already satisfied: trame-server<4,>=3.2.3 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (3.4.0)
# Requirement already satisfied: trame-client<4,>=3.4 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (3.6.0)
# Requirement already satisfied: wslink>=2.1.3 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (2.3.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pooch->pyvista[all,trame]; extra == "all"->PyniteFEA[all]) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pooch->pyvista[all,trame]; extra == "all"->PyniteFEA[all]) (2.32.3)
# Collecting cmocean (from pyvista[all,trame]->PyniteFEA[all])
#   Downloading cmocean-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting colorcet (from pyvista[all,trame]->PyniteFEA[all])
#   Downloading colorcet-3.1.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting imageio (from pyvista[all,trame]->PyniteFEA[all])
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting meshio>=5.2 (from pyvista[all,trame]->PyniteFEA[all])
#   Downloading meshio-5.3.5-py3-none-any.whl.metadata (11 kB)
# Collecting jupyter-server-proxy (from pyvista[all,trame]->PyniteFEA[all])
#   Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: nest_asyncio in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pyvista[all,trame]->PyniteFEA[all]) (1.6.0)
# Collecting trame-vtk>=2.5.8 (from pyvista[all,trame]->PyniteFEA[all])
#   Downloading trame_vtk-2.8.15-py3-none-any.whl.metadata (13 kB)
# Collecting trame-vuetify>=2.3.1 (from pyvista[all,trame]->PyniteFEA[all])
#   Downloading trame_vuetify-3.0.1-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from stack_data->Ipython->PyniteFEA[all]) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from stack_data->Ipython->PyniteFEA[all]) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from stack_data->Ipython->PyniteFEA[all]) (0.2.3)
# Requirement already satisfied: idna>=2.8 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (1.3.1)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: certifi in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from httpx>=0.25.0->jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from httpx>=0.25.0->jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (1.8.13)
# Requirement already satisfied: psutil in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (7.0.0)
# Requirement already satisfied: pywin32>=300 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (307)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (4.23.0)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading python_json_logger-3.3.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (6.0.2)
# Requirement already satisfied: referencing in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (0.36.2)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all])
#   Downloading babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all])
#   Downloading json5-0.12.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: rich in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from meshio>=5.2->pyvista[all,trame]->PyniteFEA[all]) (14.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (4.13.4)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading mistune-3.1.3-py3-none-any.whl.metadata (1.8 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (2.21.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from requests>=2.19.0->pooch->pyvista[all,trame]; extra == "all"->PyniteFEA[all]) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from requests>=2.19.0->pooch->pyvista[all,trame]; extra == "all"->PyniteFEA[all]) (2.3.0)
# Requirement already satisfied: more-itertools in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trame-server<4,>=3.2.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (10.6.0)
# Collecting trame-client<4,>=3.4 (from trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all])
#   Downloading trame_client-3.9.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting trame-common>=0.2.0 (from trame-client<4,>=3.4->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all])
#   Downloading trame_common-0.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: aiohttp<4 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (3.11.14)
# Requirement already satisfied: msgpack<2,>=1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (1.1.0)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy->pyvista[all,trame]->PyniteFEA[all])
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp<4->wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp<4->wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp<4->wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp<4->wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp<4->wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp<4->wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp<4->wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (1.18.3)
# Collecting webencodings (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (0.23.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (3.0.0)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl.metadata (1.6 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (2.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from rich->meshio>=5.2->pyvista[all,trame]->PyniteFEA[all]) (3.0.0)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: mdurl~=0.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from markdown-it-py>=2.2.0->rich->meshio>=5.2->pyvista[all,trame]->PyniteFEA[all]) (0.1.2)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all])
#   Downloading types_python_dateutil-2.9.0.20250516-py3-none-any.whl.metadata (2.1 kB)
# Downloading pdfkit-1.0.0-py3-none-any.whl (12 kB)
# Downloading trame_jupyter_extension-2.1.4-py3-none-any.whl (31 kB)
# Downloading jupyter_server-2.16.0-py3-none-any.whl (386 kB)
# Downloading jupyterlab-4.4.2-py3-none-any.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ----------- ---------------------------- 3.4/12.3 MB 18.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.1/12.3 MB 18.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.3 MB 18.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 17.1 MB/s eta 0:00:00
# Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Downloading meshio-5.3.5-py3-none-any.whl (166 kB)
# Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading prometheus_client-0.22.0-py3-none-any.whl (62 kB)
# Downloading pywinpty-2.0.15-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 12.2 MB/s eta 0:00:00
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading trame_vtk-2.8.15-py3-none-any.whl (821 kB)
#    ---------------------------------------- 0.0/821.6 kB ? eta -:--:--
#    --------------------------------------- 821.6/821.6 kB 11.9 MB/s eta 0:00:00
# Downloading trame_vuetify-3.0.1-py3-none-any.whl (4.9 MB)
#    ---------------------------------------- 0.0/4.9 MB ? eta -:--:--
#    ------------------------- -------------- 3.1/4.9 MB 15.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.9/4.9 MB 14.3 MB/s eta 0:00:00
# Downloading trame_client-3.9.0-py3-none-any.whl (244 kB)
# Downloading cmocean-4.0.3-py3-none-any.whl (421 kB)
# Downloading colorcet-3.1.0-py3-none-any.whl (260 kB)
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl (37 kB)
# Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    -------------- ------------------------- 3.7/10.2 MB 18.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.3/10.2 MB 18.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 16.3 MB/s eta 0:00:00
# Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
# Downloading json5-0.12.0-py3-none-any.whl (36 kB)
# Downloading mistune-3.1.3-py3-none-any.whl (53 kB)
# Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Downloading trame_common-0.2.0-py3-none-any.whl (21 kB)
# Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl (181 kB)
# Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# Downloading types_python_dateutil-2.9.0.20250516-py3-none-any.whl (14 kB)
# Installing collected packages: webencodings, pdfkit, webcolors, uri-template, types-python-dateutil, trame-common, tinycss2, simpervisor, send2trash, rfc3986-validator, rfc3339-validator, pywinpty, python-json-logger, pycparser, prometheus-client, pandocfilters, mistune, jupyterlab-pygments, json5, imageio, fqdn, defusedxml, colorcet, bleach, babel, async-lru, trame-client, terminado, cffi, arrow, trame-vuetify, trame-vtk, meshio, jupyter-server-terminals, isoduration, cmocean, argon2-cffi-bindings, argon2-cffi, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-server-proxy, jupyter-lsp, jupyterlab, trame_jupyter_extension
#   Attempting uninstall: trame-client
#     Found existing installation: trame-client 3.6.0
#     Uninstalling trame-client-3.6.0:
#       Successfully uninstalled trame-client-3.6.0
# Successfully installed argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.5 babel-2.17.0 bleach-6.2.0 cffi-1.17.1 cmocean-4.0.3 colorcet-3.1.0 defusedxml-0.7.1 fqdn-1.5.1 imageio-2.37.0 isoduration-20.11.0 json5-0.12.0 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.16.0 jupyter-server-proxy-4.4.0 jupyter-server-terminals-0.5.3 jupyterlab-4.4.2 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 meshio-5.3.5 mistune-3.1.3 nbclient-0.10.2 nbconvert-7.16.6 notebook-shim-0.2.4 pandocfilters-1.5.1 pdfkit-1.0.0 prometheus-client-0.22.0 pycparser-2.22 python-json-logger-3.3.0 pywinpty-2.0.15 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.3 simpervisor-1.0.0 terminado-0.18.1 tinycss2-1.4.0 trame-client-3.9.0 trame-common-0.2.0 trame-vtk-2.8.15 trame-vuetify-3.0.1 trame_jupyter_extension-2.1.4 types-python-dateutil-2.9.0.20250516 uri-template-1.3.0 webcolors-24.11.1 webencodings-0.5.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: pyvista 0.44.2 does not provide the extra 'trame'
# Collecting Pynite
#   Downloading pynite-1.4.2.tar.gz (2.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: aiohttp in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Pynite) (3.11.14)
# Collecting python-box (from Pynite)
#   Downloading python_box-7.3.2-cp311-cp311-win_amd64.whl.metadata (8.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp->Pynite) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp->Pynite) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp->Pynite) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp->Pynite) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp->Pynite) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp->Pynite) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp->Pynite) (1.18.3)
# Requirement already satisfied: idna>=2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp->Pynite) (3.10)
# Downloading python_box-7.3.2-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 7.8 MB/s eta 0:00:00
# Building wheels for collected packages: Pynite
#   Building wheel for Pynite (setup.py): started
#   Building wheel for Pynite (setup.py): finished with status 'done'
#   Created wheel for Pynite: filename=pynite-1.4.2-py3-none-any.whl size=3754 sha256=7dd8f24ff1a2135832240d9d35b52b28800be1ef0704ac7e36d09076b898bc5b
#   Stored in directory: c:\users\legion\appdata\local\pip\cache\wheels\cf\b0\a5\2d5af2541abe8814dd4964515ef23e17687e8250c196c22096
# Successfully built Pynite
# Installing collected packages: python-box, Pynite
# Successfully installed Pynite-1.4.2 python-box-7.3.2
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: trimesh in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (4.6.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trimesh) (2.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# PyNite Script for Multi-Span Steel Frame with Uniform Slab Loads
# To model a simple steel frame (multi-span beam) supporting a concrete slab, we can use the PyNite FEA library in Python. The following script lets you define multiple spans and members, apply uniform Dead Load (DL) and Live Load (LL) on all beams (simulating slab weight and live load), and then analyze the structure under the standard 1.2 DL + 1.6 LL load combination.

# %%
# Import the FEModel3D class from PyNite
from Pynite import FEModel3D

# Initialize a new 3D finite element model
model = FEModel3D()

# %% [markdown]
# Define Material and Section Properties
# Next, define the material (steel) and cross-section properties for the beams. Here we use typical properties for structural steel.

# %%
# --- Material properties (Steel) ---
# Users can edit these values if using a different material or units.
E = 210e6   # Young's modulus in kN/m^2 (≈210 GPa, typical for steel)
nu = 0.3    # Poisson's ratio (steel ~0.3)
G = E / (2 * (1 + nu))  # Shear modulus in kN/m^2
rho = 77.0e-6  # Density in kN/m^3 (approx 77 kN/m^3, not critical unless self-weight is used)

# Add steel material to the model (name, E, G, nu, rho)
model.add_material('Steel', E, G, nu, rho)

# --- Cross-section properties for the steel beams ---
# Users can edit these to match a specific beam section (A: area, Iy/Iz: moments of inertia, J: torsional constant).
A  = 0.02      # Cross-sectional area in m^2 (example value)
Iy = 8.3e-6    # Moment of inertia about local y-axis (m^4) - e.g., weak axis
Iz = 4.2e-5    # Moment of inertia about local z-axis (m^4) - e.g., strong axis (vertical bending axis)
J  = 1.0e-5    # Torsional constant (m^4) - resistance to twisting

# Add the section properties to the model
model.add_section('BeamSection', A, Iy, Iz, J)

# %% [markdown]
# Define Geometry: Nodes and Members (Spans)

# %%
# --- Define span lengths (in meters) ---
# EDIT HERE: Modify this list to change the number of spans and their lengths.
span_lengths = [6.0, 6.0, 6.0]  # Example: three spans, each 6.0 m long

# Automatically generate node coordinates for the spans.
# We'll assume a straight horizontal beam (along global X-axis) at Y=0, Z=0 for simplicity.
current_x = 0.0
node_names = []  # to keep track of node naming
for i, L in enumerate(span_lengths):
    # Define node at the start of the span (for first span, this is the left end)
    if i == 0:
        node_name = f"N{i}"  # e.g., "N0"
        model.add_node(node_name, X=current_x, Y=0.0, Z=0.0)
        node_names.append(node_name)
    # Define node at the end of this span
    current_x += L  # advance x by the span length
    node_name = f"N{i+1}"  # e.g., "N1", "N2", ...
    model.add_node(node_name, X=current_x, Y=0.0, Z=0.0)
    node_names.append(node_name)

# Add beam members between consecutive nodes for each span
for i in range(len(span_lengths)):
    mem_name = f"M{i+1}"  # Name members as M1, M2, ...
    start_node = f"N{i}"
    end_node   = f"N{i+1}"
    # Connect the nodes with a steel beam member
    model.add_member(mem_name, i_node=start_node, j_node=end_node,
                     material_name='Steel', section_name='BeamSection', 
                     rotation=0.0)
    # (rotation=0 aligns the member's local axes with global axes by default)

# %% [markdown]
# Define supports at each node

# %%
# --- Define supports at each node ---
num_nodes = len(node_names)
for idx, node_name in enumerate(node_names):
    if idx == 0:
        # Left end support (Pinned: all translations fixed, rotations free)
        model.def_support(node_name, support_DX=True, support_DY=True, support_DZ=True,
                                      support_RX=False, support_RY=False, support_RZ=False)
    elif idx == num_nodes - 1:
        # Right end support (Roller: free in global X, fixed in vertical Y and Z; 
        # also fix torsional rotation RX for stability)
        model.def_support(node_name, support_DX=False, support_DY=True, support_DZ=True,
                                      support_RX=True, support_RY=False, support_RZ=False)
    else:
        # Intermediate supports (Pin: treat like pinned supports at column tops)
        model.def_support(node_name, support_DX=True, support_DY=True, support_DZ=True,
                                      support_RX=False, support_RY=False, support_RZ=False)

# %%
# --- Load cases and uniform load values ---
# EDIT HERE: Adjust the load intensities as needed (in kN/m in this example).
DL_intensity = 5.0   # Dead load (e.g. slab self-weight + finishes) in kN/m
LL_intensity = 2.5   # Live load (e.g. occupancy load) in kN/m

# Define load case names for clarity
DL_case = 'DL'
LL_case = 'LL'

# Add distributed loads to each beam member for each load case
for i, L in enumerate(span_lengths):
    mem_name = f"M{i+1}"
    # Dead Load: uniform over full span (x1=0, x2=L)
    model.add_member_dist_load(member_name=mem_name, direction="FY",
                               w1=-DL_intensity, w2=-DL_intensity, 
                               x1=0.0, x2=L, case=DL_case)
    # Live Load: uniform over full span
    model.add_member_dist_load(member_name=mem_name, direction="FY",
                               w1=-LL_intensity, w2=-LL_intensity, 
                               x1=0.0, x2=L, case=LL_case)

# %%
# --- Define load combination for ultimate design ---
combo_name = '1.2DL+1.6LL'
model.add_load_combo(name=combo_name, 
                     factors={DL_case: 1.2, LL_case: 1.6})

# %%
# --- Run linear static analysis for the defined load combination ---
model.analyze_linear(check_stability=True, check_statics=True)

# %%
# --- Results Visualization ---

# 1. Shear force diagrams (vertical shear 'Fy' along each member)
for member in model.members.values():
    member.plot_shear(direction='Fy', combo_name=combo_name, n_points=50)

# 2. Bending moment diagrams (major axis bending 'Mz' for each member)
for member in model.members.values():
    member.plot_moment(direction='Mz', combo_name=combo_name, n_points=50)

# 3. Deflected shape diagrams (vertical deflection 'dy' for each member)
for member in model.members.values():
    member.plot_deflection(direction='dy', combo_name=combo_name, n_points=50)

# 4. Support reactions: print vertical reaction at each support node for the combo
print("Support Reactions under combo", combo_name)
for i in range(len(node_names)):
    node = model.nodes[f"N{i}"]
    # RxnFY is the reaction force in global Y at node. It returns a dict of values per combo.
    reaction = node.RxnFY[combo_name]  # get the vertical reaction for our combo
    print(f"  Node {node.name}:  RY = {reaction:.2f} kN")

# %%
Support Reactions under combo 1.2DL+1.6LL
  Node N0:  RY = XX.XX kN
  Node N1:  RY = YY.YY kN
  Node N2:  RY = ZZ.ZZ kN
  Node N3:  RY = WW.WW kN
