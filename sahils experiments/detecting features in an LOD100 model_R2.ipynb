# %%
# %pip install rtree
# %pip install open3d
# Out:
# Requirement already satisfied: rtree in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (1.4.0)
# Note: you may need to restart the kernel to use updated packages.
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Collecting open3d
#   Using cached open3d-0.19.0-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from open3d) (2.2.3)
# Collecting dash>=2.6.0 (from open3d)
#   Using cached dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Collecting werkzeug>=3.0.0 (from open3d)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting flask>=3.0.0 (from open3d)
#   Using cached flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: nbformat>=5.7.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from open3d) (5.10.4)
# Collecting configargparse (from open3d)
#   Using cached ConfigArgParse-1.7-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: ipywidgets>=8.0.4 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from open3d) (8.1.5)
# Collecting flask>=3.0.0 (from open3d)
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting werkzeug>=3.0.0 (from open3d)
#   Using cached werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Collecting plotly>=5.0.0 (from dash>=2.6.0->open3d)
#   Using cached plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting dash-html-components==2.0.0 (from dash>=2.6.0->open3d)
#   Using cached dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash>=2.6.0->open3d)
#   Using cached dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash>=2.6.0->open3d)
#   Using cached dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting importlib-metadata (from dash>=2.6.0->open3d)
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from dash>=2.6.0->open3d) (4.12.2)
# Requirement already satisfied: requests in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from dash>=2.6.0->open3d) (2.32.3)
# Collecting retrying (from dash>=2.6.0->open3d)
#   Using cached retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from dash>=2.6.0->open3d) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from dash>=2.6.0->open3d) (63.2.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from flask>=3.0.0->open3d) (3.1.6)
# Collecting itsdangerous>=2.1.2 (from flask>=3.0.0->open3d)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from flask>=3.0.0->open3d)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting blinker>=1.6.2 (from flask>=3.0.0->open3d)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipywidgets>=8.0.4->open3d) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipywidgets>=8.0.4->open3d) (8.33.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipywidgets>=8.0.4->open3d) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipywidgets>=8.0.4->open3d) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipywidgets>=8.0.4->open3d) (3.0.13)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from nbformat>=5.7.0->open3d) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from nbformat>=5.7.0->open3d) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from nbformat>=5.7.0->open3d) (5.7.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from werkzeug>=3.0.0->open3d) (3.0.2)
# Requirement already satisfied: colorama in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from click>=8.1.3->flask>=3.0.0->open3d) (0.4.6)
# Requirement already satisfied: decorator in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.6.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.23.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (308)
# Collecting narwhals>=1.15.1 (from plotly>=5.0.0->dash>=2.6.0->open3d)
#   Using cached narwhals-1.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (24.2)
# Collecting zipp>=3.20 (from importlib-metadata->dash>=2.6.0->open3d)
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from requests->dash>=2.6.0->open3d) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from requests->dash>=2.6.0->open3d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from requests->dash>=2.6.0->open3d) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from requests->dash>=2.6.0->open3d) (2025.1.31)
# Requirement already satisfied: six>=1.7.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from retrying->dash>=2.6.0->open3d) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.3)
# Using cached open3d-0.19.0-cp310-cp310-win_amd64.whl (69.2 MB)
# Using cached dash-2.18.2-py3-none-any.whl (7.8 MB)
# Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Using cached flask-3.0.3-py3-none-any.whl (101 kB)
# Using cached werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Using cached ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached plotly-6.0.0-py3-none-any.whl (14.8 MB)
# Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Using cached narwhals-1.29.1-py3-none-any.whl (308 kB)
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, zipp, werkzeug, retrying, narwhals, itsdangerous, configargparse, click, blinker, plotly, importlib-metadata, flask, dash, open3d
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\LEGION\\Documents\\GitHub\\Octopusie\\.venv\\Lib\\site-packages\\open3d\\tbb12.dll'
# Check the permissions.

# %%
# %pip install open3d
# Out:
# Collecting open3d
#   Using cached open3d-0.19.0-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from open3d) (2.2.3)
# Collecting dash>=2.6.0 (from open3d)
#   Using cached dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: werkzeug>=3.0.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from open3d) (3.0.6)
# Collecting flask>=3.0.0 (from open3d)
#   Using cached flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: nbformat>=5.7.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from open3d) (5.10.4)
# Requirement already satisfied: configargparse in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from open3d) (1.7)
# Requirement already satisfied: ipywidgets>=8.0.4 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from open3d) (8.1.5)
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from dash>=2.6.0->open3d) (6.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from dash>=2.6.0->open3d) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from dash>=2.6.0->open3d) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from dash>=2.6.0->open3d) (5.0.0)
# Collecting importlib-metadata (from dash>=2.6.0->open3d)
#   Using cached importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from dash>=2.6.0->open3d) (4.12.2)
# Requirement already satisfied: requests in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from dash>=2.6.0->open3d) (2.32.3)
# Requirement already satisfied: retrying in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from dash>=2.6.0->open3d) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from dash>=2.6.0->open3d) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from dash>=2.6.0->open3d) (63.2.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from flask>=3.0.0->open3d) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from flask>=3.0.0->open3d) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from flask>=3.0.0->open3d) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from flask>=3.0.0->open3d) (1.9.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipywidgets>=8.0.4->open3d) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipywidgets>=8.0.4->open3d) (8.33.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipywidgets>=8.0.4->open3d) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipywidgets>=8.0.4->open3d) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipywidgets>=8.0.4->open3d) (3.0.13)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from nbformat>=5.7.0->open3d) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from nbformat>=5.7.0->open3d) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from nbformat>=5.7.0->open3d) (5.7.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from werkzeug>=3.0.0->open3d) (3.0.2)
# Requirement already satisfied: colorama in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from click>=8.1.3->flask>=3.0.0->open3d) (0.4.6)
# Requirement already satisfied: decorator in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.6.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.23.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (308)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (1.29.1)
# Requirement already satisfied: packaging in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (24.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from importlib-metadata->dash>=2.6.0->open3d) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from requests->dash>=2.6.0->open3d) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from requests->dash>=2.6.0->open3d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from requests->dash>=2.6.0->open3d) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from requests->dash>=2.6.0->open3d) (2025.1.31)
# Requirement already satisfied: six>=1.7.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from retrying->dash>=2.6.0->open3d) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\legion\documents\github\octopusie\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.3)
# Using cached open3d-0.19.0-cp310-cp310-win_amd64.whl (69.2 MB)
# Using cached dash-2.18.2-py3-none-any.whl (7.8 MB)
# Using cached flask-3.0.3-py3-none-any.whl (101 kB)
# Using cached importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Installing collected packages: importlib-metadata, flask, dash, open3d
# Successfully installed dash-2.18.2 flask-3.0.3 importlib-metadata-8.6.1 open3d-0.19.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Ensure that the 'rtree' library is installed. If not, run: pip install rtree

import trimesh
import numpy as np
import open3d as o3d
import plotly.graph_objects as go

# Load the OBJ model
import os


obj_path = r"../Reference Files/3d model for detection.obj"

mesh = trimesh.load(obj_path)

# Extract vertices and faces
vertices = mesh.vertices
faces = mesh.faces

# Edge Detection
edges = mesh.edges_unique
edge_vertices = vertices[edges]

# Get user input for floor height
num_floors_input = int(input('Enter the desired number of floors: '))

# User-defined Floor Division with Single Floor Height
def divide_into_floors(vertices, num_floors):
    # Find the bounding box of the model
    min_z = np.min(vertices[:, 2])
    max_z = np.max(vertices[:, 2])

    # Calculate the floor height
    floor_height = (max_z - min_z) / num_floors

    # Create floor levels
    floor_levels = [min_z + i * floor_height for i in range(num_floors + 1)]

    return floor_levels

# Divide into floors
floor_levels = divide_into_floors(vertices, num_floors_input)
print('Floor Levels:', floor_levels)

# Identify Floors and Walls (more sophisticated approach)
def is_floor(face_normal, normal_threshold=0.1):
    # Check if the face normal is mostly pointing up or down
    return abs(face_normal[2]) > (1 - normal_threshold)

def is_wall(face_normal, normal_threshold=0.1):
    # Check if the face normal is mostly horizontal
    return abs(face_normal[2]) < normal_threshold

floor_faces = set()
wall_faces = set()

# Adjacency
mesh.process() # Compute the face adjacency before accessing it
face_adjacency = mesh.face_adjacency

def group_connected_faces(faces, normals, similarity_threshold=0.95):
    groups = []
    visited = set()

    for face_index in faces:
        if face_index in visited:
            continue

        group = {face_index}
        queue = [face_index]
        visited.add(face_index)

        while queue:
            current_face = queue.pop(0)
            # Check if current_face is within the bounds of face_adjacency
            if current_face >= len(face_adjacency):
                continue
            neighbors = mesh.face_adjacency[current_face]

            if neighbors is None:
                continue

            for neighbor in neighbors:
                if neighbor in visited or neighbor in group:
                    continue

                if np.dot(normals[current_face], normals[neighbor]) > similarity_threshold:
                    group.add(neighbor)
                    queue.append(neighbor)
                    visited.add(neighbor)

        groups.append(list(group))

    return groups

all_faces = set(range(len(faces)))
floor_normals = [mesh.face_normals[i] for i in all_faces if is_floor(mesh.face_normals[i])]
floor_faces_indices = [i for i in all_faces if is_floor(mesh.face_normals[i])]
wall_normals = [mesh.face_normals[i] for i in all_faces if is_wall(mesh.face_normals[i])]
wall_faces_indices = [i for i in all_faces if is_wall(mesh.face_normals[i])]

floor_groups = group_connected_faces(floor_faces_indices, mesh.face_normals)
wall_groups = group_connected_faces(wall_faces_indices, mesh.face_normals)

num_floors = len(floor_groups)
num_walls = len(wall_groups)

# Print the number of walls and floors
print(f'Number of floor faces: {num_floors}')
print(f'Number of wall faces: {num_walls}')

# Visualization using Plotly
def visualize_floors(vertices, faces, floor_levels):
    # Create a Plotly figure
    fig = go.Figure()

    # Add the base mesh
    fig.add_trace(go.Mesh3d(x=vertices[:, 0], y=vertices[:, 1], z=vertices[:, 2],
                            i=faces[:, 0], j=faces[:, 1], k=faces[:, 2],
                            opacity=0.1, color='lightgrey'))

    # Find the bounds of the model
    x_min, x_max = np.min(vertices[:, 0]), np.max(vertices[:, 0])
    y_min, y_max = np.min(vertices[:, 1]), np.max(vertices[:, 1])

    # Create floor surfaces
    for i in range(len(floor_levels) - 1):
        z_level = floor_levels[i]

        # Create a grid of points for the floor surface
        x = np.linspace(x_min, x_max, 50)
        y = np.linspace(y_min, y_max, 50)
        X, Y = np.meshgrid(x, y)
        Z = np.full_like(X, z_level)

        # Flatten the grid for point querying
        points = np.stack([X.flatten(), Y.flatten(), Z.flatten()], axis=-1)

        # Check which points are inside the mesh
        inside_points = mesh.contains(points)

        # Reshape the inside points to the grid shape
        inside_grid = inside_points.reshape(X.shape)

        # Mask the X, Y, and Z grids
        X_masked = np.where(inside_grid, X, np.nan)
        Y_masked = np.where(inside_grid, Y, np.nan)
        Z_masked = np.where(inside_grid, Z, np.nan)

        # Add the masked surface to the figure
        fig.add_trace(go.Surface(x=X_masked, y=Y_masked, z=Z_masked, opacity=0.5, colorscale=[[0, 'blue'], [1, 'blue']]))

    # Update layout for interactive rotation
    fig.update_layout(scene=dict(aspectmode='data'))

    fig.show()

# Visualize the floors
visualize_floors(vertices, faces, floor_levels)

# Visualization (Open3D) - Commented out
mesh_o3d = o3d.io.read_triangle_mesh(obj_path)
# o3d.visualization.draw_geometries([mesh_o3d])
# Out:
# Floor Levels: [np.float64(0.0), np.float64(12.5), np.float64(25.0), np.float64(37.5), np.float64(50.0)]
# Number of floor faces: 6
# Number of wall faces: 7
