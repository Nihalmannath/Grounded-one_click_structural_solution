# %%
# %pip install -q rhino3dm shapely trimesh matplotlib pyvista pandas
# %pip install PyniteFEA[all]
# %pip install Pynite
# %pip install trimesh
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: PyniteFEA[all] in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (2.2.3)
# Requirement already satisfied: PrettyTable in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (3.15.1)
# Requirement already satisfied: scipy in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (1.15.2)
# Requirement already satisfied: matplotlib in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (3.10.1)
# Requirement already satisfied: Ipython in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (9.0.2)
# Requirement already satisfied: vtk in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (9.3.1)
# Requirement already satisfied: pyvista[all,trame] in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (0.44.2)
# Requirement already satisfied: trame_jupyter_extension in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (2.1.4)
# Requirement already satisfied: ipywidgets in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (8.1.5)
# Requirement already satisfied: pdfkit in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (1.0.0)
# Requirement already satisfied: Jinja2 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PyniteFEA[all]) (3.1.6)
# Requirement already satisfied: colorama in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (0.4.6)
# Requirement already satisfied: decorator in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Ipython->PyniteFEA[all]) (4.12.2)
# Requirement already satisfied: comm>=0.1.3 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from ipywidgets->PyniteFEA[all]) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from ipywidgets->PyniteFEA[all]) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from ipywidgets->PyniteFEA[all]) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Jinja2->PyniteFEA[all]) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from matplotlib->PyniteFEA[all]) (2.9.0.post0)
# Requirement already satisfied: wcwidth in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from PrettyTable->PyniteFEA[all]) (0.2.13)
# Requirement already satisfied: pooch in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pyvista[all,trame]; extra == "all"->PyniteFEA[all]) (1.8.2)
# Requirement already satisfied: scooby>=0.5.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pyvista[all,trame]; extra == "all"->PyniteFEA[all]) (0.10.0)
# Requirement already satisfied: jupyter-server<3,>=2.0.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trame_jupyter_extension->PyniteFEA[all]) (2.16.0)
# Requirement already satisfied: jupyterlab<5,>=4 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trame_jupyter_extension->PyniteFEA[all]) (4.4.2)
# Requirement already satisfied: trame>=3.2.7 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trame_jupyter_extension->PyniteFEA[all]) (3.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jedi>=0.16->Ipython->PyniteFEA[all]) (0.8.4)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (0.22.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (26.3.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (0.18.1)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (6.4.2)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (2.2.5)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (75.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib->PyniteFEA[all]) (1.17.0)
# Requirement already satisfied: trame-server<4,>=3.2.3 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (3.4.0)
# Requirement already satisfied: trame-client<4,>=3.4 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (3.9.0)
# Requirement already satisfied: wslink>=2.1.3 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (2.3.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pooch->pyvista[all,trame]; extra == "all"->PyniteFEA[all]) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pooch->pyvista[all,trame]; extra == "all"->PyniteFEA[all]) (2.32.3)
# Requirement already satisfied: cmocean in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pyvista[all,trame]->PyniteFEA[all]) (4.0.3)
# Requirement already satisfied: colorcet in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pyvista[all,trame]->PyniteFEA[all]) (3.1.0)
# Requirement already satisfied: imageio in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pyvista[all,trame]->PyniteFEA[all]) (2.37.0)
# Requirement already satisfied: meshio>=5.2 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pyvista[all,trame]->PyniteFEA[all]) (5.3.5)
# Requirement already satisfied: jupyter-server-proxy in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pyvista[all,trame]->PyniteFEA[all]) (4.4.0)
# Requirement already satisfied: nest_asyncio in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pyvista[all,trame]->PyniteFEA[all]) (1.6.0)
# Requirement already satisfied: trame-vtk>=2.5.8 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pyvista[all,trame]->PyniteFEA[all]) (2.8.15)
# Requirement already satisfied: trame-vuetify>=2.3.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from pyvista[all,trame]->PyniteFEA[all]) (3.0.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from stack_data->Ipython->PyniteFEA[all]) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from stack_data->Ipython->PyniteFEA[all]) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from stack_data->Ipython->PyniteFEA[all]) (0.2.3)
# Requirement already satisfied: idna>=2.8 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (21.2.0)
# Requirement already satisfied: certifi in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from httpx>=0.25.0->jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from httpx>=0.25.0->jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (1.8.13)
# Requirement already satisfied: psutil in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (7.0.0)
# Requirement already satisfied: pywin32>=300 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (307)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (4.23.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (6.0.2)
# Requirement already satisfied: referencing in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (0.36.2)
# Requirement already satisfied: rfc3339-validator in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (0.1.1)
# Requirement already satisfied: babel>=2.10 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4->trame_jupyter_extension->PyniteFEA[all]) (0.12.0)
# Requirement already satisfied: rich in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from meshio>=5.2->pyvista[all,trame]->PyniteFEA[all]) (14.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (2.21.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from requests>=2.19.0->pooch->pyvista[all,trame]; extra == "all"->PyniteFEA[all]) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from requests>=2.19.0->pooch->pyvista[all,trame]; extra == "all"->PyniteFEA[all]) (2.3.0)
# Requirement already satisfied: trame-common>=0.2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trame-client<4,>=3.4->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (0.2.0)
# Requirement already satisfied: more-itertools in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trame-server<4,>=3.2.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (10.6.0)
# Requirement already satisfied: aiohttp<4 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (3.11.14)
# Requirement already satisfied: msgpack<2,>=1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (1.1.0)
# Requirement already satisfied: simpervisor>=1.0.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jupyter-server-proxy->pyvista[all,trame]->PyniteFEA[all]) (1.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp<4->wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp<4->wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp<4->wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp<4->wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp<4->wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp<4->wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp<4->wslink>=2.1.3->trame>=3.2.7->trame_jupyter_extension->PyniteFEA[all]) (1.18.3)
# Requirement already satisfied: webencodings in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (1.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (0.23.1)
# Requirement already satisfied: fqdn in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (2.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from rich->meshio>=5.2->pyvista[all,trame]->PyniteFEA[all]) (3.0.0)
# Requirement already satisfied: pycparser in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (2.22)
# Requirement already satisfied: mdurl~=0.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from markdown-it-py>=2.2.0->rich->meshio>=5.2->pyvista[all,trame]->PyniteFEA[all]) (0.1.2)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->trame_jupyter_extension->PyniteFEA[all]) (2.9.0.20250516)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: pyvista 0.44.2 does not provide the extra 'trame'
# Requirement already satisfied: Pynite in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (1.4.2)
# Requirement already satisfied: aiohttp in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Pynite) (3.11.14)
# Requirement already satisfied: python-box in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from Pynite) (7.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp->Pynite) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp->Pynite) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp->Pynite) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp->Pynite) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp->Pynite) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp->Pynite) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from aiohttp->Pynite) (1.18.3)
# Requirement already satisfied: idna>=2.0 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp->Pynite) (3.10)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: trimesh in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (4.6.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\legion\documents\github\octopusie\.conda\lib\site-packages (from trimesh) (2.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
print (df_beams ,df_columns, df_nodes)
# Out:
#        ID i_node j_node  length
# 0      B0     N1     N5   4.511
# 1      B1     N2     N6   4.511
# 2      B2     N3     N7   4.511
# 3      B3   N109   N113   4.511
# 4      B4   N110   N114   4.511
# ..    ...    ...    ...     ...
# 139  B139   N155    N90   1.779
# 140  B140   N157    N91   1.779
# 141  B141   N154   N116   1.779
# 142  B142   N156   N117   1.779
# 143  B143   N158   N118   1.779
#
# [144 rows x 4 columns]      ID i_node j_node  length
# 0    C0     N0     N1     2.0
# 1    C1     N1     N2     2.0
# 2    C2     N2     N3     2.0
# 3    C3     N4     N5     2.0
# 4    C4     N5     N6     2.0
# ..  ...    ...    ...     ...
# 82  C82   N109   N110     2.0
# 83  C83   N110   N111     2.0
# 84  C84   N112   N113     2.0
# 85  C85   N113   N114     2.0
# 86  C86   N114   N115     2.0
#
# [87 rows x 4 columns]        ID        X         Y    Z
# 0      N0 -7.17073   6.84157  0.0
# 1      N1 -7.17073   6.84157  2.0
# 2      N2 -7.17073   6.84157  4.0
# 3      N3 -7.17073   6.84157  6.0
# 4      N4 -7.17073  11.35236  0.0
# ..    ...      ...       ...  ...
# 154  N154 -1.77904   6.84157  2.0
# 155  N155 -1.77904   4.97135  4.0
# 156  N156 -1.77904   6.84157  4.0
# 157  N157 -1.77904   4.97135  6.0
# 158  N158 -1.77904   6.84157  6.0
#
# [159 rows x 4 columns]

# %%
import rhino3dm
import numpy as np
from shapely.geometry import Polygon, Point, MultiPolygon, LineString
import matplotlib.pyplot as plt
import os
import pyvista as pv
import csv # Import the csv module

# File path
# Note: Using the remembered path from your previous interactions.
rhino_path = r"../Reference Files\rectangles3dcantileverarchitectural.3dm" # Updated to your remembered path
if not os.path.exists(rhino_path):
    raise FileNotFoundError(f"File not found: {rhino_path}")

# Load model
model = rhino3dm.File3dm.Read(rhino_path)
layers = {layer.Name.lower(): layer.Index for layer in model.Layers}
if 'building' not in layers or ('column' not in layers and 'columns' not in layers):
    raise RuntimeError("Missing required layers: 'building' and 'column' or 'columns'.")

column_layer = 'columns' if 'columns' in layers else 'column'

# Extract building volume & height
building_volumes = []
imported_columns = []
max_z = 0.0 # Global maximum Z for the entire building footprint

wall_breps = []

for obj in model.Objects:
    layer_idx = obj.Attributes.LayerIndex
    geom = obj.Geometry

    if layer_idx == layers['building'] and geom.ObjectType == rhino3dm.ObjectType.Brep:
        bbox = geom.GetBoundingBox()
        base_pts = [
            [bbox.Min.X, bbox.Min.Y],
            [bbox.Max.X, bbox.Min.Y],
            [bbox.Max.X, bbox.Max.Y],
            [bbox.Min.X, bbox.Max.Y],
            [bbox.Min.X, bbox.Max.Y] # Ensure polygon is closed for Shapely
        ]
        poly = Polygon(base_pts)
        building_volumes.append(poly)
        wall_breps.append({'polygon': poly, 'bbox': bbox})
        max_z = max(max_z, bbox.Max.Z) # Update global max_z

    elif layer_idx == layers[column_layer] and geom.ObjectType == rhino3dm.ObjectType.Brep:
        bbox = geom.GetBoundingBox()
        center_x = (bbox.Min.X + bbox.Max.X) / 2
        center_y = (bbox.Min.Y + bbox.Max.Y) / 2
        imported_columns.append((center_x, center_y))

if not building_volumes:
    raise RuntimeError("No valid building geometry found on the 'building' layer.")

# Ask for number of floors
while True:
    try:
        floor_height = float(input("Enter desired floor height (in meters): "))
        if floor_height <= 0:
            raise ValueError
        # Automatically divide floors if building height exceeds twice the floor height
        if max_z > 2 * floor_height:
            num_floors = int(np.ceil(max_z / floor_height))
        else:
            num_floors = 1
        print(f"Building will be divided into {num_floors} floor(s).")
        break
    except ValueError:
        print("Please enter a valid positive number for the floor height.")

# --- Section for perimeter line and wall thickness ---
while True:
    try:
        wall_thickness = float(input("Enter desired wall thickness for the perimeter (e.g., 0.3): "))
        if wall_thickness <= 0:
            raise ValueError
        break
    except ValueError:
        print("Please enter a valid positive number for wall thickness.")

# Combine all building polygons into a single MultiPolygon
combined_building_polygon = MultiPolygon(building_volumes)

# Get the exterior boundary of the combined building and offset it
try:
    exterior_perimeter = combined_building_polygon.buffer(wall_thickness, join_style=1) # join_style=1 for mitered joints
except Exception as e:
    print(f"Could not buffer the building outline. Error: {e}")
    exterior_perimeter = None

# If the buffer operation results in a MultiPolygon, get the largest component
if exterior_perimeter and exterior_perimeter.geom_type == 'MultiPolygon':
    exterior_perimeter = max(exterior_perimeter.geoms, key=lambda p: p.area)

perimeter_line_coords = []
if exterior_perimeter:
    if exterior_perimeter.geom_type == 'Polygon':
        # Extract the exterior ring coordinates
        perimeter_line_coords = list(exterior_perimeter.exterior.coords)
    elif exterior_perimeter.geom_type == 'MultiPolygon':
        # For MultiPolygon, take the exterior of the largest polygon component
        perimeter_line_coords = list(exterior_perimeter.geoms[0].exterior.coords)
    else:
        print("Warning: The buffered perimeter is not a Polygon or MultiPolygon. Cannot extract line coordinates.")

# --- End perimeter section ---

# Room sorting
detected_rooms = sorted([(poly, poly.area) for poly in building_volumes], key=lambda x: -x[1])

# Structural logic
MaxS = 6.0
MinS = 3.0

columns = []
corrected_columns = []
available_imported = imported_columns.copy()
existing_columns = imported_columns.copy()
beams = []

for room_poly, _ in detected_rooms:
    minx, miny, maxx, maxy = room_poly.bounds
    width, height = maxx - minx, maxy - miny
    divisions_x = int(np.ceil(width / MaxS))
    divisions_y = int(np.ceil(height / MaxS))
    x_points = np.linspace(minx, maxx, divisions_x + 1)
    y_points = np.linspace(miny, maxy, divisions_y + 1)
    room_candidates = [(x, y) for x in x_points for y in y_points]

    for col in room_candidates:
        snap = False
        for imp_col in available_imported:
            if np.linalg.norm(np.array(col) - np.array(imp_col)) < MinS:
                corrected_columns.append(col)
                existing_columns.append(col)
                available_imported.remove(imp_col)
                snap = True
                break
        if not snap and all(np.linalg.norm(np.array(col) - np.array(exist_col)) >= MinS for exist_col in existing_columns):
            columns.append(col)
            existing_columns.append(col)

    for x in x_points:
        beams.append(((x, miny), (x, maxy)))
    for y in y_points:
        beams.append(((minx, y), (maxx, y)))

    for corner in list(room_poly.exterior.coords):
        if all(np.linalg.norm(np.array(corner) - np.array(exist_col)) >= MinS * 0.5 for exist_col in existing_columns):
            columns.append(corner)
            existing_columns.append(corner)

# Combine all base columns
all_base_columns = columns + corrected_columns

# --- COLUMN GRID NUMBERING LOGIC ---
# Get unique X and Y coordinates from all generated/snapped columns for grid lines
grid_xs = sorted(list(set([col[0] for col in all_base_columns])))
grid_ys = sorted(list(set([col[1] for col in all_base_columns])))

# Create mapping for X-coordinates to letters (A, B, C...)
x_grid_labels = {x: chr(65 + i) for i, x in enumerate(grid_xs)}
# Create mapping for Y-coordinates to numbers (1, 2, 3...)
y_grid_labels = {y: i + 1 for i, y in enumerate(grid_ys)}

# Determine the actual min/max X/Y of the columns for drawing grid lines
col_min_x_extent = min(col[0] for col in all_base_columns) if all_base_columns else 0
col_max_x_extent = max(col[0] for col in all_base_columns) if all_base_columns else 0
col_min_y_extent = min(col[1] for col in all_base_columns) if all_base_columns else 0
col_max_y_extent = max(col[1] for col in all_base_columns) if all_base_columns else 0

# Add a small buffer to the column extents for drawing grid lines
grid_extent_buffer = 1.0 # Adjusted for better visual spacing
col_min_x_extent -= grid_extent_buffer
col_max_x_extent += grid_extent_buffer
col_min_y_extent -= grid_extent_buffer
col_max_y_extent += grid_extent_buffer

# Determine overall plot limits (consider building outline and grid labels)
# Adjusted limits to provide more space for labels without cutting off the perimeter
# Increased padding for labels
min_x_plot = min(col_min_x_extent, min([coord[0] for coord in perimeter_line_coords] + [col[0] for col in all_base_columns])) - 3.0 if perimeter_line_coords else col_min_x_extent - 3.0
max_x_plot = max(col_max_x_extent, max([coord[0] for coord in perimeter_line_coords] + [col[0] for col in all_base_columns])) + 1.0 if perimeter_line_coords else col_max_x_extent + 1.0
min_y_plot = min(col_min_y_extent, min([coord[1] for coord in perimeter_line_coords] + [col[1] for col in all_base_columns])) - 1.0 if perimeter_line_coords else col_min_y_extent - 1.0
max_y_plot = max(col_max_y_extent, max([coord[1] for coord in perimeter_line_coords] + [col[1] for col in all_base_columns])) + 2.0 if perimeter_line_coords else col_max_y_extent + 2.0


# 2D Visualization
fig, ax = plt.subplots(figsize=(12, 10)) # Increased figure width for legend

# Room outlines
for poly, _ in detected_rooms:
    px, py = poly.exterior.xy
    ax.plot(px, py, 'k-', linewidth=1)

# Plot the new perimeter line
if perimeter_line_coords:
    px_perimeter, py_perimeter = zip(*perimeter_line_coords)
    ax.plot(px_perimeter, py_perimeter, 'm--', linewidth=2, label=f'Outer Perimeter (Thickness: {wall_thickness}m)')

# Plot all columns
gx, gy = zip(*columns)
ax.scatter(gx, gy, c='blue', s=80, label='Generated Columns', zorder=5)

# Snapped imported columns
if corrected_columns:
    cx, cy = zip(*corrected_columns)
    ax.scatter(cx, cy, c='purple', s=80, label='Snapped Imported Columns', zorder=7)

# Original imported columns
if imported_columns:
    ix, iy = zip(*imported_columns)
    ax.scatter(ix, iy, c='red', s=80, label='Original Imported Columns', zorder=10)

# Only draw one label for beam lines in 2D
if beams:
    x1, y1 = beams[0][0]
    x2, y2 = beams[0][1]
    ax.plot([x1, x2], [y1, y2], color='green', linestyle='--', linewidth=1.5, label='Beam Lines')

# Draw and label grid lines
# Increased offset for labels for better clarity
for x_coord in grid_xs:
    ax.plot([x_coord, x_coord], [col_min_y_extent, col_max_y_extent], 'k:', linewidth=0.8) # Dashed vertical grid line
    ax.text(x_coord, col_max_y_extent + 0.8, x_grid_labels[x_coord], ha='center', va='bottom', fontsize=10, color='gray') # Label at top

for y_coord in grid_ys:
    ax.plot([col_min_x_extent, col_max_x_extent], [y_coord, y_coord], 'k:', linewidth=0.8) # Dashed horizontal grid line
    ax.text(col_min_x_extent - 1.0, y_coord, y_grid_labels[y_coord], ha='right', va='center', fontsize=10, color='gray') # Label on left


ax.set_aspect('equal', 'box')
ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0.) # Moved legend
plt.title("2D Column and Beam Grid with Structural Grid Labeling and Perimeter")

# Using subplots_adjust for explicit margin control instead of tight_layout
# This gives more precise control over the margins for labels
plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.1) # Adjusted values for left and top margin


ax.set_xlim(min_x_plot, max_x_plot)
ax.set_ylim(min_y_plot, max_y_plot)
plt.show()

# PyVista 3D visualization
plotter = pv.Plotter(title="3D Structural System")

# Define sizes for structural elements (now dimensions for rectangular prisms)
column_width = 0.3
column_depth = 0.3

beam_width = 0.25
beam_depth = 0.35

slab_thickness = 0.20

slab_extension_buffer = max(column_width, column_depth) / 2 + 0.05

# Calculate story heights per room, since rooms might have different max Z
room_story_heights = {}
for room_poly, _ in detected_rooms:
    room_specific_max_z = 0.0
    for wall_data in wall_breps:
        if wall_data['polygon'].equals(room_poly):
            room_specific_max_z = wall_data['bbox'].Max.Z
            break
    if room_specific_max_z == 0.0:
        room_specific_max_z = max_z
    
    num_vertical_sections = num_floors 

    if num_vertical_sections > 0:
        story_height = room_specific_max_z / num_vertical_sections
    else:
        story_height = room_specific_max_z
    
    room_story_heights[room_poly.wkt] = story_height


# --- Define Z-levels for each floor in a more structured way ---
floor_z_levels = {} 
for room_poly, _ in detected_rooms:
    room_specific_max_z = 0.0
    for wall_data in wall_breps:
        if wall_data['polygon'].equals(room_poly):
            room_specific_max_z = wall_data['bbox'].Max.Z
            break
    if room_specific_max_z == 0.0:
        room_specific_max_z = max_z

    current_room_floor_z = []
    
    # Slab 0: Ground Slab
    current_room_floor_z.append((0.0, slab_thickness))

    if num_floors > 0: # Only generate intermediate and roof slabs if there's at least 1 floor
        story_height = room_story_heights.get(room_poly.wkt, max_z)
        
        # Intermediate Slabs (from 1 to num_floors-1)
        for i in range(1, num_floors): 
            slab_base_z = i * story_height
            slab_top_z = slab_base_z + slab_thickness

            if slab_top_z > room_specific_max_z + 1e-6:
                slab_top_z = room_specific_max_z
                slab_base_z = max(slab_base_z, slab_top_z - slab_thickness)

            if slab_top_z - slab_base_z < 1e-6:
                continue
                
            current_room_floor_z.append((slab_base_z, slab_top_z))
        
        # Last Slab: Roof Slab
        roof_slab_top_z = room_specific_max_z 
        roof_slab_base_z = roof_slab_top_z - slab_thickness
        
        if current_room_floor_z:
            last_slab_top = current_room_floor_z[-1][1]
            if roof_slab_base_z < last_slab_top + 1e-6:
                roof_slab_base_z = last_slab_top
                roof_slab_top_z = roof_slab_base_z + slab_thickness
                if roof_slab_top_z > room_specific_max_z + 1e-6:
                    roof_slab_top_z = room_specific_max_z
                    roof_slab_base_z = max(roof_slab_top_z - slab_thickness, last_slab_top)
        
        if roof_slab_top_z - roof_slab_base_z < 1e-6:
            pass
        else:
            current_room_floor_z.append((roof_slab_base_z, roof_slab_top_z))

    floor_z_levels[room_poly.wkt] = current_room_floor_z

# --- Add Slabs ---
for room_poly, _ in detected_rooms:
    room_floor_data = floor_z_levels.get(room_poly.wkt, [])
    if not room_floor_data:
        continue

    extended_room_poly = room_poly.buffer(slab_extension_buffer)
    
    for i, (slab_base_z, slab_top_z) in enumerate(room_floor_data):
        current_slab_thickness = slab_top_z - slab_base_z
        if current_slab_thickness < 1e-6:
            continue

        points_3d_for_slab_base = []
        poly_coords = list(extended_room_poly.exterior.coords)
        if poly_coords[0] != poly_coords[-1]:
            poly_coords.append(poly_coords[0])
            
        for x, y in poly_coords:
            points_3d_for_slab_base.append([x, y, 0.0])
        
        points_3d_for_slab_base = np.array(points_3d_for_slab_base)

        if len(points_3d_for_slab_base) < 3:
            continue

        slab_base_mesh = pv.PolyData(points_3d_for_slab_base)
        
        try:
            triangulated_faces = slab_base_mesh.delaunay_2d().faces
            if triangulated_faces is None or len(triangulated_faces) == 0:
                continue
            slab_base_mesh = pv.PolyData(points_3d_for_slab_base, faces=triangulated_faces)
        except Exception as e:
            print(f"Delaunay triangulation failed for a slab base ({room_poly.bounds}): {e}. Skipping slab.")
            continue

        slab_mesh = slab_base_mesh.extrude(vector=(0, 0, current_slab_thickness), capping=True)
        slab_mesh = slab_mesh.translate((0, 0, slab_base_z))
        
        plotter.add_mesh(slab_mesh, color='sienna', opacity=0.8, smooth_shading=True)


# --- Data Structures for Export ---
all_nodes_data = {} # (x, y, z) -> "N_ID"
export_columns = [] # List of {"ID": "C0", "i_node": "N0", "j_node": "N1"}
export_beams = []   # List of {"ID": "B0", "i_node": "N0", "j_node": "N1"}
node_id_counter = 0

def get_node_id(x, y, z):
    global node_id_counter
    # Use a tuple (x, y, z) as key, rounded to avoid floating point issues
    # Adjust rounding precision as needed
    rounded_coords = (round(x, 6), round(y, 6), round(z, 6))
    if rounded_coords not in all_nodes_data:
        node_id = f"N{node_id_counter}"
        all_nodes_data[rounded_coords] = node_id
        node_id_counter += 1
    return all_nodes_data[rounded_coords]

# --- Add Columns (and populate export_columns, all_nodes_data) ---
column_id_counter = 0
for x, y in all_base_columns:
    column_room_wkt = None
    for room_poly, _ in detected_rooms:
        if Point(x, y).within(room_poly):
            column_room_wkt = room_poly.wkt
            break
    if column_room_wkt is None:
        min_dist = float('inf')
        for room_poly, _ in detected_rooms:
            dist = Point(x,y).distance(room_poly)
            if dist < min_dist:
                min_dist = dist
                column_room_wkt = room_poly.wkt
        if column_room_wkt is None:
             continue

    room_floor_data = floor_z_levels.get(column_room_wkt, [])
    if not room_floor_data or len(room_floor_data) <= 1:
        continue
    
    num_slabs_in_room = len(room_floor_data)
    
    for i in range(num_slabs_in_room - 1):
        col_base_z = room_floor_data[i][1] 
        col_top_z = room_floor_data[i+1][0] 

        if col_top_z <= col_base_z + 1e-6:
            continue

        col_min_x = x - column_width / 2
        col_max_x = x + column_width / 2
        col_min_y = y - column_depth / 2
        col_max_y = y + column_depth / 2
        
        column_box = pv.Box([col_min_x, col_max_x, col_min_y, col_max_y, col_base_z, col_top_z])
        plotter.add_mesh(column_box, color='blue', smooth_shading=True)

        # Collect data for export_columns
        i_node_id = get_node_id(x, y, col_base_z)
        j_node_id = get_node_id(x, y, col_top_z)
        export_columns.append({"ID": f"C{column_id_counter}", "i_node": i_node_id, "j_node": j_node_id})
        column_id_counter += 1


# --- Add Beams (and populate export_beams, all_nodes_data) ---
beam_id_counter = 0
for (x1, y1), (x2, y2) in beams:
    full_beam_line = LineString([(x1, y1), (x2, y2)])

    for i in range(len(room_floor_data)): # Iterate through floor levels (slabs)
        relevant_rooms_for_this_floor = []
        for room_poly, _ in detected_rooms:
            if room_poly.intersects(full_beam_line.buffer(1e-3)):
                room_floor_data_current_room = floor_z_levels.get(room_poly.wkt, [])
                if len(room_floor_data_current_room) > i:
                    slab_base_z_for_this_room_floor = room_floor_data_current_room[i][0]
                    # slab_top_z_for_this_room_floor = room_floor_data_current_room[i][1] # Not directly used for beam z here

                    room_specific_max_z = 0.0
                    for wall_data in wall_breps:
                        if wall_data['polygon'].equals(room_poly):
                            room_specific_max_z = wall_data['bbox'].Max.Z
                            break
                    if room_specific_max_z == 0.0: room_specific_max_z = max_z

                    if slab_base_z_for_this_room_floor >= room_specific_max_z - 1e-6 and i < len(room_floor_data_current_room) -1:
                        continue 
                    
                    relevant_rooms_for_this_floor.append((room_poly, slab_base_z_for_this_room_floor))

        if not relevant_rooms_for_this_floor:
            continue

        for room_poly, slab_base_z_for_current_room in relevant_rooms_for_this_floor:
            intersection = full_beam_line.intersection(room_poly)

            if intersection.geom_type == 'LineString':
                segments_to_draw = [intersection]
            elif intersection.geom_type == 'MultiLineString':
                segments_to_draw = list(intersection.geoms)
            else: 
                continue

            for segment in segments_to_draw:
                if not segment.is_empty and segment.length > 1e-6:
                    seg_x1, seg_y1 = segment.coords[0]
                    seg_x2, seg_y2 = segment.coords[-1]

                    beam_top_z = slab_base_z_for_current_room
                    beam_base_z = beam_top_z - beam_depth

                    if beam_base_z < 0:
                        beam_base_z = 0
                        if beam_top_z <= 0:
                            continue
                    
                    if beam_top_z <= beam_base_z + 1e-6:
                        continue

                    if abs(seg_x1 - seg_x2) > abs(seg_y1 - seg_y2):
                        beam_min_x = min(seg_x1, seg_x2)
                        beam_max_x = max(seg_x1, seg_x2)
                        beam_center_y = (seg_y1 + seg_y2) / 2
                        beam_min_y = beam_center_y - beam_width / 2
                        beam_max_y = beam_center_y + beam_width / 2
                    else:
                        beam_min_y = min(seg_y1, seg_y2)
                        beam_max_y = max(seg_y1, seg_y2)
                        beam_center_x = (seg_x1 + seg_x2) / 2
                        beam_min_x = beam_center_x - beam_width / 2
                        beam_max_x = beam_center_x + beam_width / 2

                    beam_box = pv.Box([beam_min_x, beam_max_x, beam_min_y, beam_max_y, beam_base_z, beam_top_z])

                    is_roof_slab = (i == len(room_floor_data_current_room) - 1)
                    color = 'green' if is_roof_slab else 'orange' 
                    plotter.add_mesh(beam_box, color=color, smooth_shading=True)

                    # Collect data for export_beams
                    # Beams' nodes are at their centerlines (seg_x1, seg_y1, beam_top_z) and (seg_x2, seg_y2, beam_top_z)
                    i_node_id = get_node_id(seg_x1, seg_y1, beam_top_z)
                    j_node_id = get_node_id(seg_x2, seg_y2, beam_top_z)
                    export_beams.append({"ID": f"B{beam_id_counter}", "i_node": i_node_id, "j_node": j_node_id})
                    beam_id_counter += 1

# Convert all_nodes_data dictionary to a list of dictionaries for CSV export
final_nodes_data = []
for coords, node_id in all_nodes_data.items():
    final_nodes_data.append({"ID": node_id, "X": coords[0], "Y": coords[1], "Z": coords[2]})

# Actual Brep-based walls visualization (semi-transparent)
def mesh_brep(brep, mesh_type=rhino3dm.MeshType.Any):
    meshes = []
    for face in brep.Faces:
        try:
            m = face.GetMesh(mesh_type)
            if m: meshes.append(m)
        except:
            continue
    return meshes

for obj in model.Objects:
    geom = obj.Geometry
    layer_idx = obj.Attributes.LayerIndex
    if layer_idx == layers['building'] and isinstance(geom, rhino3dm.Brep):
        meshes = mesh_brep(geom)
        for mesh in meshes:
            pts = [(v.X, v.Y, v.Z) for v in mesh.Vertices]
            faces = []
            for f in mesh.Faces:
                if len(f) == 4:
                    idxs = (f[0], f[1], f[2], f[3])
                else:
                    idxs = (f[0], f[1], f[2])
                faces.append((len(idxs),) + idxs)
            faces_flat = [i for face in faces for i in face]
            pv_mesh = pv.PolyData(pts, faces_flat)
            plotter.add_mesh(pv_mesh, color='lightgray', opacity=0.3)

plotter.show_grid()
plotter.show()


import pandas as pd
import numpy as np
import plotly.graph_objects as go
from collections import OrderedDict
import os # Import the os module for path operations


# --- Utility function for wall height (re-used from your code) ---
from shapely.geometry import Point # Ensure Point is imported for get_wall_height
def get_wall_height(x, y, wall_data, global_max_z):
    pt = Point(x, y)
    closest_wall_height = global_max_z # Default to global max_z if no specific wall found
    min_dist_to_wall = float('inf')

    for wall in wall_data:
        if wall['polygon'].contains(pt):
            return wall['bbox'].Max.Z # If the point is inside a wall's base polygon
        
        dist = wall['polygon'].exterior.distance(pt)
        if dist < min_dist_to_wall:
            min_dist_to_wall = dist
            closest_wall_height = wall['bbox'].Max.Z
    
    return closest_wall_height # Return the height of the closest wall or global max_z





node_coords = []
node_dict = OrderedDict() # Maps (x,y,z) tuple to node ID

def add_node(pt):
    key = tuple(np.round(pt, 5))
    if key not in node_dict:
        node_id = f"N{len(node_dict)}"
        node_dict[key] = node_id
        node_coords.append([node_id] + list(key))
    return node_dict[key]

# Ensure column_lines and beam_lines are populated based on the processed data
column_lines = []
for x, y in all_base_columns: # Use all_base_columns directly for vertical elements
    current_column_max_z = get_wall_height(x,y, wall_breps, max_z)
    
    # Generate nodes for each floor level for columns
    for i in range(num_floors + 1): # Including ground (0) and roof (num_floors)
        z_level = (i / num_floors) * current_column_max_z
        if i == 0: # Base of the column
            id_btm = add_node((x, y, 0))
            id_top = add_node((x, y, z_level))
            if z_level > 0: # Only add if it forms a segment
                 column_lines.append((id_btm, id_top))
        elif i > 0: # For subsequent segments between floors
            prev_z_level = ((i-1) / num_floors) * current_column_max_z
            id_prev_node = add_node((x, y, prev_z_level))
            id_current_node = add_node((x, y, z_level))
            column_lines.append((id_prev_node, id_current_node))


beam_lines = []
for (x1, y1), (x2, y2) in beams:
    # Beams exist at each floor level (from 1st floor to roof)
    segment_max_z_for_height = min(get_wall_height(x1, y1, wall_breps, max_z), get_wall_height(x2, y2, wall_breps, max_z))
    
    for i in range(1, num_floors + 1):
        z_level = (i / num_floors) * segment_max_z_for_height
        
        # Ensure beams don't extend above the actual wall height (with a tiny tolerance)
        if z_level > (segment_max_z_for_height + 1e-6):
            continue

        id1 = add_node((x1, y1, z_level))
        id2 = add_node((x2, y2, z_level))
        beam_lines.append((id1, id2))


# --- Export nodes.csv ---
nodes_df = pd.DataFrame(node_coords, columns=["ID", "X", "Y", "Z"])

# --- Export columns.csv ---
col_data = []
for i, (i_node_id, j_node_id) in enumerate(column_lines):
    # Lookup coordinates from the generated df_nodes
    p1_coords = nodes_df[nodes_df["ID"] == i_node_id][["X", "Y", "Z"]].values[0]
    p2_coords = nodes_df[nodes_df["ID"] == j_node_id][["X", "Y", "Z"]].values[0]
    length = np.linalg.norm(p2_coords - p1_coords)
    col_data.append([f"C{i}", i_node_id, j_node_id, round(length, 3)])

columns_df = pd.DataFrame(col_data, columns=["ID", "i_node", "j_node", "length"])

# --- Export beams.csv ---
beam_data = []
for i, (i_node_id, j_node_id) in enumerate(beam_lines):
    # Lookup coordinates from the generated df_nodes
    p1_coords = nodes_df[nodes_df["ID"] == i_node_id][["X", "Y", "Z"]].values[0]
    p2_coords = nodes_df[nodes_df["ID"] == j_node_id][["X", "Y", "Z"]].values[0]
    length = np.linalg.norm(p2_coords - p1_coords)
    beam_data.append([f"B{i}", i_node_id, j_node_id, round(length, 3)])

beams_df = pd.DataFrame(beam_data, columns=["ID", "i_node", "j_node", "length"])



# # Prepare data for plotting lines (columns and beams)
# column_plotly_lines_x, column_plotly_lines_y, column_plotly_lines_z = [], [], []
# beam_plotly_lines_x, beam_plotly_lines_y, beam_plotly_lines_z = [], [], []

# # Add Columns to line data
# for index, row in df_columns.iterrows():
#     p1 = node_lookup_loaded[row['i_node']]
#     p2 = node_lookup_loaded[row['j_node']]
#     column_plotly_lines_x.extend([p1[0], p2[0], None])
#     column_plotly_lines_y.extend([p1[1], p2[1], None])
#     column_plotly_lines_z.extend([p1[2], p2[2], None])

# # Add Beams to line data
# for index, row in df_beams.iterrows():
#     p1 = node_lookup_loaded[row['i_node']]
#     p2 = node_lookup_loaded[row['j_node']]
#     beam_plotly_lines_x.extend([p1[0], p2[0], None])
#     beam_plotly_lines_y.extend([p1[1], p2[1], None])
#     beam_plotly_lines_z.extend([p1[2], p2[2], None])

# # Prepare slab data for Plotly (using the `wall_breps`, `detected_rooms`, `num_floors`, `max_z` from prior code)
# slab_meshes = []
# slab_thickness = 0.15
# slab_extension_buffer = max(0.3, 0.3) / 2 + 0.01 + 0.005 # Example buffer

# # Use detected_rooms and wall_breps from your previous code execution
# for room_poly, _ in detected_rooms:
#     room_specific_max_z = 0.0
#     for wall_data in wall_breps:
#         if wall_data['polygon'].equals(room_poly):
#             room_specific_max_z = wall_data['bbox'].Max.Z
#             break
#     if room_specific_max_z == 0.0:
#         room_specific_max_z = max_z # Fallback

#     if num_floors <= 0:
#         continue

#     extended_room_poly = room_poly.buffer(slab_extension_buffer, join_style=1)
#     if extended_room_poly.geom_type == 'MultiPolygon':
#         extended_room_poly = max(extended_room_poly.geoms, key=lambda p: p.area)
#     elif extended_room_poly.geom_type != 'Polygon':
#         # print(f"Warning: Extended room polygon for {room_poly.bounds} is not a single Polygon. Skipping slab.")
#         continue

#     story_height = room_specific_max_z / num_floors

#     for i in range(1, num_floors + 1):
#         intended_slab_top_z = i * story_height
#         slab_base_z = intended_slab_top_z - slab_thickness

#         if slab_base_z < 0:
#             slab_base_z = 0
#             current_slab_thickness_for_this_level = intended_slab_top_z
#         else:
#             current_slab_thickness_for_this_level = slab_thickness
        
#         if (slab_base_z + current_slab_thickness_for_this_level) > (room_specific_max_z + 1e-6):
#             current_slab_thickness_for_this_level = max(0, room_specific_max_z - slab_base_z)
#             if current_slab_thickness_for_this_level < 1e-6:
#                 continue

#         # Convert polygon bounds to a rectangular slab for Plotly for simplicity
#         minx_s, miny_s, maxx_s, maxy_s = extended_room_poly.bounds
        
#         slab_x_coords = [minx_s, maxx_s, maxx_s, minx_s, minx_s]
#         slab_y_coords = [miny_s, miny_s, maxy_s, maxy_s, miny_s]

#         # Top surface of slab
#         slab_meshes.append(go.Mesh3d(
#             x=slab_x_coords,
#             y=slab_y_coords,
#             z=[slab_base_z + current_slab_thickness_for_this_level] * len(slab_x_coords),
#             color='sienna',
#             opacity=0.8,
#             name=f'Floor {i} Slab Top',
#             # Add faces for simple rectangles: two triangles for a quad
#             # This makes the mesh solid rather than just a plane
#             i=[0, 0], j=[1, 2], k=[2, 3] # Indices for the two triangles forming the quad
#         ))


# # --- Create Plotly Figure ---
# fig = go.Figure()

# # Add Nodes as scatter points
# fig.add_trace(go.Scatter3d(
#     x=df_nodes_loaded['X'],
#     y=df_nodes_loaded['Y'],
#     z=df_nodes_loaded['Z'],
#     mode='markers',
#     marker=dict(size=5, color='blue', symbol='circle'),
#     name='Nodes',
#     text=df_nodes_loaded['ID'],
#     hoverinfo='text'
# ))

# # Add Columns as lines
# fig.add_trace(go.Scatter3d(
#     x=column_plotly_lines_x,
#     y=column_plotly_lines_y,
#     z=column_plotly_lines_z,
#     mode='lines',
#     line=dict(color='blue', width=7),
#     name='Columns'
# ))

# # Add Beams as lines
# fig.add_trace(go.Scatter3d(
#     x=beam_plotly_lines_x,
#     y=beam_plotly_lines_y,
#     z=beam_plotly_lines_z,
#     mode='lines',
#     line=dict(color='green', width=5),
#     name='Beams'
# ))

# # Add Slabs
# for slab_mesh in slab_meshes:
#     fig.add_trace(slab_mesh)

# # Add 3D representation of perimeter line at Z=0 (from `perimeter_line_coords` from previous execution)
# if 'perimeter_line_coords' in locals() and perimeter_line_coords:
#     perimeter_3d_x = [p[0] for p in perimeter_line_coords]
#     perimeter_3d_y = [p[1] for p in perimeter_line_coords]
#     # Close the loop
#     if perimeter_3d_x and perimeter_3d_x[0] != perimeter_3d_x[-1] or perimeter_3d_y[0] != perimeter_3d_y[-1]:
#         perimeter_3d_x.append(perimeter_3d_x[0])
#         perimeter_3d_y.append(perimeter_3d_y[0])

#     fig.add_trace(go.Scatter3d(
#         x=perimeter_3d_x,
#         y=perimeter_3d_y,
#         z=[0] * len(perimeter_3d_x),
#         mode='lines',
#         line=dict(color='magenta', width=7),
#         name='Outer Perimeter (Base)'
#     ))

# # Update layout for better visualization
# fig.update_layout(
#     title='3D Structural Visualization from Saved CSVs',
#     scene=dict(
#         xaxis_title='X',
#         yaxis_title='Y',
#         zaxis_title='Z',
#         aspectmode='data',
#         camera=dict(
#             eye=dict(x=1.8, y=1.8, z=1.8)
#         )
#     ),
#     height=800,
#     margin=dict(l=0, r=0, b=0, t=40)
# )

# fig.show()




# ─────────────────────────────────────────────────────────────────
# 1) IMPORTS
# ─────────────────────────────────────────────────────────────────
from Pynite.Visualization import Renderer
from Pynite.FEModel3D import FEModel3D
import pandas as pd
import numpy as np


# ─────────────────────────────────────────────────────────────────
# 3) INITIALIZE A NEW FINITE‐ELEMENT MODEL
# ─────────────────────────────────────────────────────────────────
model = FEModel3D()

# ─────────────────────────────────────────────────────────────────
# 4) ADD NODES TO THE MODEL
# ─────────────────────────────────────────────────────────────────
# Convert meters → inches
UNIT_CONVERSION = 39.37  # meters to inches

for _, row in nodes_df.iterrows():
    nid = str(row['ID'])
    model.add_node(
        nid,
        row['X'] * UNIT_CONVERSION,
        row['Y'] * UNIT_CONVERSION,
        row['Z'] * UNIT_CONVERSION
    )


# ─────────────────────────────────────────────────────────────────
# 5) DEFINE MATERIAL & SECTION (RCC)
# ─────────────────────────────────────────────────────────────────
f_c   = 4.0                           # concrete compressive strength (ksi)
E_c   = 57000 * (f_c ** 0.5)         # elastic modulus (ksi)
G_c   = E_c / (2 * (1 + 0.2))        # shear modulus (ksi), ν≈0.2
rho_c = (150 / 1728) * 1e-3          # density (kip/in³)

model.add_material('RCC', E_c, G_c, f_c, rho_c)

# Section geometry (all members use W14X30 here)
A, Iy, Iz, J = 8.84, 49.0, 14.4, 0.95
model.add_section('W14X30', A, Iy, Iz, J)

# ─────────────────────────────────────────────────────────────────
# 6) ADD MEMBERS (BEAMS + COLUMNS)
# ─────────────────────────────────────────────────────────────────
for _, row in beams_df.iterrows():
    bid = str(row['ID'])
    iN  = str(row['i_node'])
    jN  = str(row['j_node'])
    model.add_member(bid, iN, jN, 'RCC', 'W14X30')

for _, row in columns_df.iterrows():
    cid = str(row['ID'])
    iN  = str(row['i_node'])
    jN  = str(row['j_node'])
    model.add_member(cid, iN, jN, 'RCC', 'W14X30')

# ─────────────────────────────────────────────────────────────────
# 7) DEFINE SUPPORTS (Z=0 nodes fully fixed)
# ─────────────────────────────────────────────────────────────────
for _, row in nodes_df.iterrows():
    fixed = (row['Z'] == 0)
    model.def_support(
        str(row['ID']),
        fixed, fixed, fixed,   # Tx, Ty, Tz
        fixed, fixed, fixed    # Rx, Ry, Rz
    )

# ─────────────────────────────────────────────────────────────────
# 8) COMPUTE MEMBER LENGTHS
# ─────────────────────────────────────────────────────────────────
beam_lengths   = {}
column_lengths = {}

for _, row in beams_df.iterrows():
    mid = str(row['ID'])
    iN, jN = str(row['i_node']), str(row['j_node'])
    xi, yi, zi = model.nodes[iN].X, model.nodes[iN].Y, model.nodes[iN].Z
    xj, yj, zj = model.nodes[jN].X, model.nodes[jN].Y, model.nodes[jN].Z
    beam_lengths[mid] = float(np.sqrt((xj-xi)**2 + (yj-yi)**2 + (zj-zi)**2))

for _, row in columns_df.iterrows():
    mid = str(row['ID'])
    iN, jN = str(row['i_node']), str(row['j_node'])
    xi, yi, zi = model.nodes[iN].X, model.nodes[iN].Y, model.nodes[iN].Z
    xj, yj, zj = model.nodes[jN].X, model.nodes[jN].Y, model.nodes[jN].Z
    column_lengths[mid] = float(np.sqrt((xj-xi)**2 + (yj-yi)**2 + (zj-zi)**2))

# ─────────────────────────────────────────────────────────────────
# 9–10) APPLY EQUIVALENT DISTRIBUTED LOADS FOR DL & LL
# ─────────────────────────────────────────────────────────────────
length_lookup = {**beam_lengths, **column_lengths}

for mid in model.members:
    if mid not in length_lookup:
        raise KeyError(f"No length for member '{mid}'")
    L = length_lookup[mid]

    # Dead/Live intensities (kN/m)
    if mid in beam_lengths:
        w_DL, w_LL = -0.02, -0.015    # beams
    else:
        w_DL, w_LL = -0.01, -0.008    # columns

    # Apply distributed loads across full member length
    model.add_member_dist_load(mid, 'FZ', w_DL, w_DL, 0, L, case='DL')
    model.add_member_dist_load(mid, 'FZ', w_LL, w_LL, 0, L, case='LL')

# ─────────────────────────────────────────────────────────────────
# 10.5) APPLY LATERAL NODE LOAD (“W”)
# ─────────────────────────────────────────────────────────────────
# for nid in model.nodes:
#     model.add_node_load(nid, 'FY', -25, case='W')

# ─────────────────────────────────────────────────────────────────
# 11) DEFINE LOAD COMBINATIONS
# ─────────────────────────────────────────────────────────────────
model.add_load_combo('0.9DL+1.0W', factors={'DL': 1.2, 'W': 1.0})
model.add_load_combo('1.2DL+1.0W', factors={'DL': 0.9, 'W': 1.0})

# ─────────────────────────────────────────────────────────────────
# 12) RUN YOUR ANALYSIS
# ─────────────────────────────────────────────────────────────────
model.analyze()

# ─────────────────────────────────────────────────────────────────
# 12.5) VISUALIZE DEFORMED SHAPE
# ─────────────────────────────────────────────────────────────────
rndr = Renderer(model)
rndr.annotation_size = 1.3
rndr.deformed_shape   = True
rndr.deformed_scale   = 50
rndr.combo_name       = '1.2DL+1.0W'
rndr.show_loads       = True
rndr.show_reactions   = True
rndr.window_width     = 750
rndr.window_height    = 750
rndr.render_model()

# ─────────────────────────────────────────────────────────────────
# 13) COLUMN SLENDERNESS CHECK (L/r)
# ─────────────────────────────────────────────────────────────────
slenderness_limit_col = 200.0
print("\nCOLUMN SLENDERNESS CHECK (L/r):")
for _, row in columns_df.iterrows():
    cid = str(row['ID'])
    L   = column_lengths[cid]
    sec = model.sections['W14X30']
    r_y = np.sqrt(sec.Iy / sec.A)
    r_z = np.sqrt(sec.Iz / sec.A)
    r   = min(r_y, r_z)
    sl  = L / r
    status = "PASS" if sl <= slenderness_limit_col else "FAIL"
    print(f"  Column {cid}: L={L:.2f} in, r={r:.2f} in → L/r={sl:.1f} ({status})")

# ─────────────────────────────────────────────────────────────────
# 14) BEAM SLENDERNESS CHECK (L/r)
# ─────────────────────────────────────────────────────────────────
slenderness_limit_beam = 300.0
print("\nBEAM SLENDERNESS CHECK (L/r):")
for _, row in beams_df.iterrows():
    bid = str(row['ID'])
    L   = beam_lengths[bid]
    sec = model.sections['W14X30']
    r_y = np.sqrt(sec.Iy / sec.A)
    r_z = np.sqrt(sec.Iz / sec.A)
    r   = min(r_y, r_z)
    sl  = L / r
    status = "PASS" if sl <= slenderness_limit_beam else "FAIL"
    print(f"  Beam   {bid}: L={L:.2f} in, r={r:.2f} in → L/r={sl:.1f} ({status})")

# ─────────────────────────────────────────────────────────────────
# 15) PRINT GLOBAL STIFFNESS MATRIX & NODAL DISPLACEMENTS
# ─────────────────────────────────────────────────────────────────
K_sparse = model.K(combo_name='1.2DL+1.0W', log=True, check_stability=True, sparse=True)
K_dense  = K_sparse.toarray()
print("\nGlobal Stiffness Matrix [K] (size {}×{}):".format(*K_dense.shape))
labels = [f"{nid}_{dof}" for nid in model.nodes for dof in ('DX','DY','DZ','RX','RY','RZ')]
K_df = pd.DataFrame(K_dense, index=labels, columns=labels)
print(K_df)

print("\nNODAL DISPLACEMENTS (1.2DL+1.0W):")
for nid, node in model.nodes.items():
    dx = node.DX.get('1.2DL+1.0W', 0.0)
    dy = node.DY.get('1.2DL+1.0W', 0.0)
    dz = node.DZ.get('1.2DL+1.0W', 0.0)
    print(f"  Node {nid}: DX={dx:.6e} in, DY={dy:.6e} in, DZ={dz:.6e} in")
# Out:
# Building will be divided into 3 floor(s).
# Widget(value='<iframe src="http://localhost:57971/index.html?ui=P_0x2359e6a3990_1&reconnect=auto" class="pyvis…
# COLUMN SLENDERNESS CHECK (L/r):
#   Column C0: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C1: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C2: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C3: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C4: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C5: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C6: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C7: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C8: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C9: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C10: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C11: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C12: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C13: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C14: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C15: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C16: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C17: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C18: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C19: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C20: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C21: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C22: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C23: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C24: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C25: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C26: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C27: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C28: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C29: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C30: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C31: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C32: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C33: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C34: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C35: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C36: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C37: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C38: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C39: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C40: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C41: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C42: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C43: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C44: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C45: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C46: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C47: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C48: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C49: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C50: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C51: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C52: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C53: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C54: L=39.37 in, r=1.28 in → L/r=30.8 (PASS)
#   Column C55: L=39.37 in, r=1.28 in → L/r=30.8 (PASS)
#   Column C56: L=39.37 in, r=1.28 in → L/r=30.8 (PASS)
#   Column C57: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C58: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C59: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C60: L=39.37 in, r=1.28 in → L/r=30.8 (PASS)
#   Column C61: L=39.37 in, r=1.28 in → L/r=30.8 (PASS)
#   Column C62: L=39.37 in, r=1.28 in → L/r=30.8 (PASS)
#   Column C63: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C64: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C65: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C66: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C67: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C68: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C69: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C70: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C71: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C72: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C73: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C74: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C75: L=58.38 in, r=1.28 in → L/r=45.7 (PASS)
#   Column C76: L=58.38 in, r=1.28 in → L/r=45.7 (PASS)
#   Column C77: L=58.38 in, r=1.28 in → L/r=45.7 (PASS)
#   Column C78: L=58.38 in, r=1.28 in → L/r=45.7 (PASS)
#   Column C79: L=58.38 in, r=1.28 in → L/r=45.7 (PASS)
#   Column C80: L=58.38 in, r=1.28 in → L/r=45.7 (PASS)
#   Column C81: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C82: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C83: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C84: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C85: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#   Column C86: L=78.74 in, r=1.28 in → L/r=61.7 (PASS)
#
# BEAM SLENDERNESS CHECK (L/r):
#   Beam   B0: L=177.59 in, r=1.28 in → L/r=139.1 (PASS)
#   Beam   B1: L=177.59 in, r=1.28 in → L/r=139.1 (PASS)
#   Beam   B2: L=177.59 in, r=1.28 in → L/r=139.1 (PASS)
#   Beam   B3: L=177.59 in, r=1.28 in → L/r=139.1 (PASS)
#   Beam   B4: L=177.59 in, r=1.28 in → L/r=139.1 (PASS)
#   Beam   B5: L=177.59 in, r=1.28 in → L/r=139.1 (PASS)
#   Beam   B6: L=177.59 in, r=1.28 in → L/r=139.1 (PASS)
#   Beam   B7: L=177.59 in, r=1.28 in → L/r=139.1 (PASS)
#   Beam   B8: L=177.59 in, r=1.28 in → L/r=139.1 (PASS)
#   Beam   B9: L=332.23 in, r=1.28 in → L/r=260.3 (PASS)
#   Beam   B10: L=332.23 in, r=1.28 in → L/r=260.3 (PASS)
#   Beam   B11: L=332.23 in, r=1.28 in → L/r=260.3 (PASS)
#   Beam   B12: L=332.23 in, r=1.28 in → L/r=260.3 (PASS)
#   Beam   B13: L=332.23 in, r=1.28 in → L/r=260.3 (PASS)
#   Beam   B14: L=332.23 in, r=1.28 in → L/r=260.3 (PASS)
#   Beam   B15: L=269.35 in, r=1.28 in → L/r=211.0 (PASS)
#   Beam   B16: L=269.35 in, r=1.28 in → L/r=211.0 (PASS)
#   Beam   B17: L=269.35 in, r=1.28 in → L/r=211.0 (PASS)
#   Beam   B18: L=269.35 in, r=1.28 in → L/r=211.0 (PASS)
#   Beam   B19: L=269.35 in, r=1.28 in → L/r=211.0 (PASS)
#   Beam   B20: L=269.35 in, r=1.28 in → L/r=211.0 (PASS)
#   Beam   B21: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B22: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B23: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B24: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B25: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B26: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B27: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B28: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B29: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B30: L=269.35 in, r=1.28 in → L/r=211.0 (PASS)
#   Beam   B31: L=269.35 in, r=1.28 in → L/r=211.0 (PASS)
#   Beam   B32: L=269.35 in, r=1.28 in → L/r=211.0 (PASS)
#   Beam   B33: L=269.35 in, r=1.28 in → L/r=211.0 (PASS)
#   Beam   B34: L=269.35 in, r=1.28 in → L/r=211.0 (PASS)
#   Beam   B35: L=269.35 in, r=1.28 in → L/r=211.0 (PASS)
#   Beam   B36: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B37: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B38: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B39: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B40: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B41: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B42: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B43: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B44: L=128.36 in, r=1.28 in → L/r=100.6 (PASS)
#   Beam   B45: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B46: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B47: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B48: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B49: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B50: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B51: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B52: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B53: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B54: L=328.79 in, r=1.28 in → L/r=257.6 (PASS)
#   Beam   B55: L=328.79 in, r=1.28 in → L/r=257.6 (PASS)
#   Beam   B56: L=328.79 in, r=1.28 in → L/r=257.6 (PASS)
#   Beam   B57: L=328.79 in, r=1.28 in → L/r=257.6 (PASS)
#   Beam   B58: L=328.79 in, r=1.28 in → L/r=257.6 (PASS)
#   Beam   B59: L=328.79 in, r=1.28 in → L/r=257.6 (PASS)
#   Beam   B60: L=118.45 in, r=1.28 in → L/r=92.8 (PASS)
#   Beam   B61: L=118.45 in, r=1.28 in → L/r=92.8 (PASS)
#   Beam   B62: L=118.45 in, r=1.28 in → L/r=92.8 (PASS)
#   Beam   B63: L=118.45 in, r=1.28 in → L/r=92.8 (PASS)
#   Beam   B64: L=118.45 in, r=1.28 in → L/r=92.8 (PASS)
#   Beam   B65: L=118.45 in, r=1.28 in → L/r=92.8 (PASS)
#   Beam   B66: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B67: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B68: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B69: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B70: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B71: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B72: L=118.44 in, r=1.28 in → L/r=92.8 (PASS)
#   Beam   B73: L=118.44 in, r=1.28 in → L/r=92.8 (PASS)
#   Beam   B74: L=118.44 in, r=1.28 in → L/r=92.8 (PASS)
#   Beam   B75: L=118.44 in, r=1.28 in → L/r=92.8 (PASS)
#   Beam   B76: L=118.44 in, r=1.28 in → L/r=92.8 (PASS)
#   Beam   B77: L=118.44 in, r=1.28 in → L/r=92.8 (PASS)
#   Beam   B78: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B79: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B80: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B81: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B82: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B83: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B84: L=71.26 in, r=1.28 in → L/r=55.8 (PASS)
#   Beam   B85: L=71.26 in, r=1.28 in → L/r=55.8 (PASS)
#   Beam   B86: L=71.26 in, r=1.28 in → L/r=55.8 (PASS)
#   Beam   B87: L=71.26 in, r=1.28 in → L/r=55.8 (PASS)
#   Beam   B88: L=71.26 in, r=1.28 in → L/r=55.8 (PASS)
#   Beam   B89: L=71.26 in, r=1.28 in → L/r=55.8 (PASS)
#   Beam   B90: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B91: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B92: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B93: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B94: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B95: L=200.42 in, r=1.28 in → L/r=157.0 (PASS)
#   Beam   B96: L=117.17 in, r=1.28 in → L/r=91.8 (PASS)
#   Beam   B97: L=117.17 in, r=1.28 in → L/r=91.8 (PASS)
#   Beam   B98: L=117.17 in, r=1.28 in → L/r=91.8 (PASS)
#   Beam   B99: L=117.17 in, r=1.28 in → L/r=91.8 (PASS)
#   Beam   B100: L=117.17 in, r=1.28 in → L/r=91.8 (PASS)
#   Beam   B101: L=117.17 in, r=1.28 in → L/r=91.8 (PASS)
#   Beam   B102: L=100.81 in, r=1.28 in → L/r=79.0 (PASS)
#   Beam   B103: L=100.81 in, r=1.28 in → L/r=79.0 (PASS)
#   Beam   B104: L=100.81 in, r=1.28 in → L/r=79.0 (PASS)
#   Beam   B105: L=100.81 in, r=1.28 in → L/r=79.0 (PASS)
#   Beam   B106: L=100.81 in, r=1.28 in → L/r=79.0 (PASS)
#   Beam   B107: L=100.81 in, r=1.28 in → L/r=79.0 (PASS)
#   Beam   B108: L=142.41 in, r=1.28 in → L/r=111.6 (PASS)
#   Beam   B109: L=142.41 in, r=1.28 in → L/r=111.6 (PASS)
#   Beam   B110: L=142.41 in, r=1.28 in → L/r=111.6 (PASS)
#   Beam   B111: L=142.41 in, r=1.28 in → L/r=111.6 (PASS)
#   Beam   B112: L=142.41 in, r=1.28 in → L/r=111.6 (PASS)
#   Beam   B113: L=142.41 in, r=1.28 in → L/r=111.6 (PASS)
#   Beam   B114: L=78.44 in, r=1.28 in → L/r=61.5 (PASS)
#   Beam   B115: L=78.44 in, r=1.28 in → L/r=61.5 (PASS)
#   Beam   B116: L=78.44 in, r=1.28 in → L/r=61.5 (PASS)
#   Beam   B117: L=78.44 in, r=1.28 in → L/r=61.5 (PASS)
#   Beam   B118: L=78.44 in, r=1.28 in → L/r=61.5 (PASS)
#   Beam   B119: L=78.44 in, r=1.28 in → L/r=61.5 (PASS)
#   Beam   B120: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B121: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B122: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B123: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B124: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B125: L=97.83 in, r=1.28 in → L/r=76.7 (PASS)
#   Beam   B126: L=95.50 in, r=1.28 in → L/r=74.8 (PASS)
#   Beam   B127: L=95.50 in, r=1.28 in → L/r=74.8 (PASS)
#   Beam   B128: L=95.50 in, r=1.28 in → L/r=74.8 (PASS)
#   Beam   B129: L=95.50 in, r=1.28 in → L/r=74.8 (PASS)
#   Beam   B130: L=95.50 in, r=1.28 in → L/r=74.8 (PASS)
#   Beam   B131: L=95.50 in, r=1.28 in → L/r=74.8 (PASS)
#   Beam   B132: L=73.63 in, r=1.28 in → L/r=57.7 (PASS)
#   Beam   B133: L=73.63 in, r=1.28 in → L/r=57.7 (PASS)
#   Beam   B134: L=73.63 in, r=1.28 in → L/r=57.7 (PASS)
#   Beam   B135: L=73.63 in, r=1.28 in → L/r=57.7 (PASS)
#   Beam   B136: L=73.63 in, r=1.28 in → L/r=57.7 (PASS)
#   Beam   B137: L=73.63 in, r=1.28 in → L/r=57.7 (PASS)
#   Beam   B138: L=70.04 in, r=1.28 in → L/r=54.9 (PASS)
#   Beam   B139: L=70.04 in, r=1.28 in → L/r=54.9 (PASS)
#   Beam   B140: L=70.04 in, r=1.28 in → L/r=54.9 (PASS)
#   Beam   B141: L=70.04 in, r=1.28 in → L/r=54.9 (PASS)
#   Beam   B142: L=70.04 in, r=1.28 in → L/r=54.9 (PASS)
#   Beam   B143: L=70.04 in, r=1.28 in → L/r=54.9 (PASS)
# - Adding nodal spring support stiffness terms to global stiffness matrix
# - Adding spring stiffness terms to global stiffness matrix
# - Adding member stiffness terms to global stiffness matrix
# - Adding quadrilateral stiffness terms to global stiffness matrix
# - Adding plate stiffness terms to global stiffness matrix
# - Checking nodal stability
#
# Global Stiffness Matrix [K] (size 954×954):
#                N0_DX        N0_DY         N0_DZ         N0_RX          N0_RY  \
# N0_DX     137.308033     0.000000      0.000000      0.000000    5405.817263
# N0_DY       0.000000    40.351749      0.000000  -1588.648339       0.000000
# N0_DZ       0.000000     0.000000  12798.577597      0.000000       0.000000
# N0_RX       0.000000 -1588.648339      0.000000  83393.446787       0.000000
# N0_RY    5405.817263     0.000000      0.000000      0.000000  283769.367539
# ...              ...          ...           ...           ...            ...
# N158_DY     0.000000     0.000000      0.000000      0.000000       0.000000
# N158_DZ     0.000000     0.000000      0.000000      0.000000       0.000000
# N158_RX     0.000000     0.000000      0.000000      0.000000       0.000000
# N158_RY     0.000000     0.000000      0.000000      0.000000       0.000000
# N158_RZ     0.000000     0.000000      0.000000      0.000000       0.000000
#
#          N0_RZ        N1_DX        N1_DY         N1_DZ         N1_RX  ...  \
# N0_DX      0.0  -137.308033     0.000000      0.000000      0.000000  ...
# N0_DY      0.0     0.000000   -40.351749      0.000000  -1588.648339  ...
# N0_DZ      0.0     0.000000     0.000000 -12798.577597      0.000000  ...
# N0_RX      0.0     0.000000  1588.648339      0.000000  41696.723393  ...
# N0_RY      0.0 -5405.817263     0.000000      0.000000      0.000000  ...
# ...        ...          ...          ...           ...           ...  ...
# N158_DY    0.0     0.000000     0.000000      0.000000      0.000000  ...
# N158_DZ    0.0     0.000000     0.000000      0.000000      0.000000  ...
# N158_RX    0.0     0.000000     0.000000      0.000000      0.000000  ...
# N158_RY    0.0     0.000000     0.000000      0.000000      0.000000  ...
# N158_RZ    0.0     0.000000     0.000000      0.000000      0.000000  ...
#
#              N157_DZ        N157_RX     N157_RY       N157_RZ      N158_DX  \
# N0_DX       0.000000       0.000000    0.000000      0.000000     0.000000
# N0_DY       0.000000       0.000000    0.000000      0.000000     0.000000
# N0_DZ       0.000000       0.000000    0.000000      0.000000     0.000000
# N0_RX       0.000000       0.000000    0.000000      0.000000     0.000000
# N0_RY       0.000000       0.000000    0.000000      0.000000     0.000000
# ...              ...            ...         ...           ...          ...
# N158_DY     0.000000       0.000000    0.000000      0.000000     0.000000
# N158_DZ  -167.922094   -6182.099037    0.000000      0.000000     0.000000
# N158_RX  6182.099037  151730.474243    0.000000      0.000000     0.000000
# N158_RY     0.000000       0.000000 -612.856933      0.000000     0.000000
# N158_RZ     0.000000       0.000000    0.000000  44590.180186  1816.780125
#
#               N158_DY      N158_DZ        N158_RX       N158_RY        N158_RZ
# N0_DX        0.000000     0.000000       0.000000  0.000000e+00       0.000000
# N0_DY        0.000000     0.000000       0.000000  0.000000e+00       0.000000
# N0_DZ        0.000000     0.000000       0.000000  0.000000e+00       0.000000
# N0_RX        0.000000     0.000000       0.000000  0.000000e+00       0.000000
# N0_RY        0.000000     0.000000       0.000000  0.000000e+00       0.000000
# ...               ...          ...            ...           ...            ...
# N158_DY  14001.727751     0.000000       0.000000  0.000000e+00    -608.120542
# N158_DZ      0.000000  1239.864015   -6182.099037  2.069299e+03       0.000000
# N158_RX      0.000000 -6182.099037  305727.174765  0.000000e+00       0.000000
# N158_RY      0.000000  2069.299067       0.000000  1.122753e+06       0.000000
# N158_RZ   -608.120542     0.000000       0.000000  0.000000e+00  418952.066446
#
# [954 rows x 954 columns]
#
# NODAL DISPLACEMENTS (1.2DL+1.0W):
#   Node N0: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N1: DX=-1.187449e-03 in, DY=5.794960e-04 in, DZ=-8.470200e-04 in
#   Node N2: DX=-3.344749e-03 in, DY=1.266873e-03 in, DZ=-1.402051e-03 in
#   Node N3: DX=-4.955392e-03 in, DY=1.728227e-03 in, DZ=-1.661337e-03 in
#   Node N4: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N5: DX=-4.123487e-04 in, DY=6.131453e-04 in, DZ=-8.544936e-04 in
#   Node N6: DX=-1.227610e-03 in, DY=1.296091e-03 in, DZ=-1.414513e-03 in
#   Node N7: DX=-2.006250e-03 in, DY=1.613781e-03 in, DZ=-1.677454e-03 in
#   Node N8: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N9: DX=-1.115631e-03 in, DY=1.636718e-04 in, DZ=-2.250815e-03 in
#   Node N10: DX=-3.296355e-03 in, DY=2.004318e-03 in, DZ=-3.738273e-03 in
#   Node N11: DX=-5.192917e-03 in, DY=4.687089e-03 in, DZ=-4.472613e-03 in
#   Node N12: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N13: DX=-3.507114e-04 in, DY=2.045861e-04 in, DZ=-1.142220e-03 in
#   Node N14: DX=-1.154901e-03 in, DY=2.031866e-03 in, DZ=-1.897992e-03 in
#   Node N15: DX=-2.236889e-03 in, DY=4.561438e-03 in, DZ=-2.261390e-03 in
#   Node N16: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N17: DX=-1.404135e-03 in, DY=4.154898e-04 in, DZ=-7.562804e-04 in
#   Node N18: DX=-3.399143e-03 in, DY=1.992476e-03 in, DZ=-1.250109e-03 in
#   Node N19: DX=-4.750916e-03 in, DY=4.097442e-03 in, DZ=-1.480027e-03 in
#   Node N20: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N21: DX=-1.510024e-03 in, DY=4.296528e-04 in, DZ=-1.312910e-03 in
#   Node N22: DX=-5.219559e-03 in, DY=2.001647e-03 in, DZ=-2.181460e-03 in
#   Node N23: DX=-9.469650e-03 in, DY=4.058681e-03 in, DZ=-2.609999e-03 in
#   Node N24: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N25: DX=-1.389696e-03 in, DY=3.877017e-04 in, DZ=-7.540503e-04 in
#   Node N26: DX=-3.381174e-03 in, DY=1.126856e-03 in, DZ=-1.248462e-03 in
#   Node N27: DX=-4.815784e-03 in, DY=1.809243e-03 in, DZ=-1.475011e-03 in
#   Node N28: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N29: DX=-1.469784e-03 in, DY=4.012281e-04 in, DZ=-2.530606e-03 in
#   Node N30: DX=-5.201088e-03 in, DY=1.131138e-03 in, DZ=-4.207450e-03 in
#   Node N31: DX=-9.655733e-03 in, DY=1.774325e-03 in, DZ=-5.042508e-03 in
#   Node N32: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N33: DX=-1.108541e-03 in, DY=4.180728e-04 in, DZ=-1.859437e-03 in
#   Node N34: DX=-3.291668e-03 in, DY=1.137321e-03 in, DZ=-3.094683e-03 in
#   Node N35: DX=-5.214893e-03 in, DY=1.734269e-03 in, DZ=-3.706784e-03 in
#   Node N36: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N37: DX=-9.978346e-04 in, DY=-3.425461e-06 in, DZ=-2.371880e-03 in
#   Node N38: DX=-4.987743e-03 in, DY=-9.474960e-04 in, DZ=-3.950633e-03 in
#   Node N39: DX=-1.138791e-02 in, DY=-2.669238e-03 in, DZ=-4.735124e-03 in
#   Node N40: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N41: DX=-9.493148e-04 in, DY=-1.593666e-06 in, DZ=-1.611967e-03 in
#   Node N42: DX=-2.862196e-03 in, DY=-9.447304e-04 in, DZ=-2.677242e-03 in
#   Node N43: DX=-4.792350e-03 in, DY=-2.676684e-03 in, DZ=-3.211026e-03 in
#   Node N44: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N45: DX=2.321171e-04 in, DY=1.782640e-05 in, DZ=-7.836950e-04 in
#   Node N46: DX=1.237924e-03 in, DY=-9.337704e-04 in, DZ=-1.295531e-03 in
#   Node N47: DX=2.741938e-03 in, DY=-2.729940e-03 in, DZ=-1.534745e-03 in
#   Node N48: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N49: DX=-1.018447e-03 in, DY=-2.224694e-04 in, DZ=-1.438212e-03 in
#   Node N50: DX=-4.993347e-03 in, DY=-1.358967e-03 in, DZ=-2.361491e-03 in
#   Node N51: DX=-1.135667e-02 in, DY=-2.890522e-03 in, DZ=-2.757246e-03 in
#   Node N52: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N53: DX=-9.376513e-04 in, DY=-2.172117e-04 in, DZ=-9.969160e-04 in
#   Node N54: DX=-2.843469e-03 in, DY=-1.362531e-03 in, DZ=-1.652546e-03 in
#   Node N55: DX=-4.841478e-03 in, DY=-2.924724e-03 in, DZ=-1.969576e-03 in
#   Node N56: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N57: DX=2.480530e-04 in, DY=-2.092015e-04 in, DZ=-6.711318e-04 in
#   Node N58: DX=1.258245e-03 in, DY=-1.360867e-03 in, DZ=-1.109906e-03 in
#   Node N59: DX=2.676403e-03 in, DY=-2.954611e-03 in, DZ=-1.313157e-03 in
#   Node N60: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N61: DX=-1.328087e-03 in, DY=-2.232200e-04 in, DZ=-1.742551e-03 in
#   Node N62: DX=-4.060932e-03 in, DY=-1.358002e-03 in, DZ=-2.760413e-03 in
#   Node N63: DX=-7.620435e-03 in, DY=-2.879686e-03 in, DZ=-3.195542e-03 in
#   Node N64: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N65: DX=8.012061e-04 in, DY=-2.142776e-06 in, DZ=-1.560209e-03 in
#   Node N66: DX=-3.242898e-03 in, DY=-9.462967e-04 in, DZ=-2.589896e-03 in
#   Node N67: DX=-1.515920e-02 in, DY=-2.674770e-03 in, DZ=-3.073722e-03 in
#   Node N68: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N69: DX=-2.640235e-03 in, DY=4.180309e-04 in, DZ=-8.825827e-04 in
#   Node N70: DX=-2.609494e-03 in, DY=1.137735e-03 in, DZ=-1.460363e-03 in
#   Node N71: DX=5.801680e-03 in, DY=1.738386e-03 in, DZ=-1.726108e-03 in
#   Node N72: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N73: DX=-1.072930e-04 in, DY=9.981916e-05 in, DZ=-3.704139e-04 in
#   Node N74: DX=-2.444197e-04 in, DY=4.399233e-04 in, DZ=-6.148250e-04 in
#   Node N75: DX=-2.482561e-05 in, DY=1.070296e-03 in, DZ=-7.334318e-04 in
#   Node N76: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N77: DX=-1.377419e-03 in, DY=4.575293e-04 in, DZ=-1.789042e-03 in
#   Node N78: DX=-4.111491e-03 in, DY=-5.236880e-04 in, DZ=-2.878800e-03 in
#   Node N79: DX=-7.439148e-03 in, DY=-2.545737e-03 in, DZ=-3.395414e-03 in
#   Node N80: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N81: DX=-1.578945e-05 in, DY=-3.562851e-04 in, DZ=-3.701333e-04 in
#   Node N82: DX=-8.890278e-05 in, DY=-2.455855e-04 in, DZ=-6.129354e-04 in
#   Node N83: DX=-4.709708e-04 in, DY=1.345187e-04 in, DZ=-7.326829e-04 in
#   Node N84: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N85: DX=-2.322231e-03 in, DY=9.623367e-04 in, DZ=-6.625201e-04 in
#   Node N86: DX=-5.098262e-03 in, DY=2.246971e-03 in, DZ=-1.093201e-03 in
#   Node N87: DX=-5.210730e-03 in, DY=3.202466e-03 in, DZ=-1.291830e-03 in
#   Node N88: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N89: DX=-1.565317e-03 in, DY=4.288598e-04 in, DZ=-1.286022e-03 in
#   Node N90: DX=-4.178802e-03 in, DY=2.002639e-03 in, DZ=-2.139065e-03 in
#   Node N91: DX=-6.283747e-03 in, DY=4.058720e-03 in, DZ=-2.548981e-03 in
#   Node N92: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N93: DX=-1.575404e-03 in, DY=9.713109e-04 in, DZ=-8.568737e-04 in
#   Node N94: DX=-4.186371e-03 in, DY=2.254715e-03 in, DZ=-1.417624e-03 in
#   Node N95: DX=-6.241731e-03 in, DY=3.181243e-03 in, DZ=-1.680688e-03 in
#   Node N96: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N97: DX=6.710192e-05 in, DY=4.178941e-04 in, DZ=-5.567081e-04 in
#   Node N98: DX=-9.628950e-04 in, DY=1.138281e-03 in, DZ=-9.145354e-04 in
#   Node N99: DX=-4.788995e-03 in, DY=1.744431e-03 in, DZ=-1.076324e-03 in
#   Node N100: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N101: DX=3.360598e-04 in, DY=2.926720e-06 in, DZ=-3.730065e-04 in
#   Node N102: DX=-2.668103e-03 in, DY=-2.459661e-05 in, DZ=-6.210737e-04 in
#   Node N103: DX=-5.092121e-03 in, DY=-7.981158e-05 in, DZ=-7.370068e-04 in
#   Node N104: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N105: DX=-4.600836e-04 in, DY=1.046929e-05 in, DZ=-3.478867e-04 in
#   Node N106: DX=-2.756847e-03 in, DY=-1.975454e-05 in, DZ=-5.691443e-04 in
#   Node N107: DX=-6.078042e-03 in, DY=-1.031474e-04 in, DZ=-6.701080e-04 in
#   Node N108: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N109: DX=-1.156428e-03 in, DY=9.080802e-04 in, DZ=-1.543489e-03 in
#   Node N110: DX=-3.321987e-03 in, DY=2.330267e-03 in, DZ=-2.564340e-03 in
#   Node N111: DX=-5.065487e-03 in, DY=3.614052e-03 in, DZ=-3.066191e-03 in
#   Node N112: DX=0.000000e+00 in, DY=0.000000e+00 in, DZ=0.000000e+00 in
#   Node N113: DX=-3.831009e-04 in, DY=9.412715e-04 in, DZ=-1.249349e-03 in
#   Node N114: DX=-1.193469e-03 in, DY=2.357633e-03 in, DZ=-2.073711e-03 in
#   Node N115: DX=-2.117510e-03 in, DY=3.497340e-03 in, DZ=-2.477212e-03 in
#   Node N116: DX=-1.125603e-03 in, DY=4.300448e-04 in, DZ=-1.055078e-02 in
#   Node N117: DX=-3.303201e-03 in, DY=2.005396e-03 in, DZ=-1.157211e-02 in
#   Node N118: DX=-5.163394e-03 in, DY=4.056666e-03 in, DZ=-1.328449e-02 in
#   Node N119: DX=-1.384659e-03 in, DY=3.952702e-04 in, DZ=-5.974168e-03 in
#   Node N120: DX=-1.013224e-03 in, DY=4.034004e-04 in, DZ=-4.729584e-03 in
#   Node N121: DX=-4.114746e-03 in, DY=1.128823e-03 in, DZ=-6.931038e-03 in
#   Node N122: DX=-4.986113e-03 in, DY=1.131886e-03 in, DZ=-6.363153e-03 in
#   Node N123: DX=-7.405375e-03 in, DY=1.788768e-03 in, DZ=-7.533139e-03 in
#   Node N124: DX=-1.130412e-02 in, DY=1.768867e-03 in, DZ=-7.538547e-03 in
#   Node N125: DX=-1.368532e-03 in, DY=3.584489e-04 in, DZ=-1.035400e-02 in
#   Node N126: DX=-1.000620e-03 in, DY=3.572137e-04 in, DZ=-1.463673e-02 in
#   Node N127: DX=-4.102723e-03 in, DY=-6.724553e-04 in, DZ=-1.017987e-02 in
#   Node N128: DX=-4.987130e-03 in, DY=-6.700947e-04 in, DZ=-1.619749e-02 in
#   Node N129: DX=-7.473086e-03 in, DY=-3.055215e-03 in, DZ=-1.436254e-02 in
#   Node N130: DX=-1.137150e-02 in, DY=-3.056585e-03 in, DZ=-1.861293e-02 in
#   Node N131: DX=7.629725e-04 in, DY=4.121168e-04 in, DZ=-1.022190e-02 in
#   Node N132: DX=-3.262263e-03 in, DY=1.135195e-03 in, DZ=-1.156831e-02 in
#   Node N133: DX=-1.501852e-02 in, DY=1.748745e-03 in, DZ=-1.326434e-02 in
#   Node N134: DX=-2.609981e-03 in, DY=3.436590e-06 in, DZ=-9.411366e-03 in
#   Node N135: DX=-2.588048e-03 in, DY=-9.419829e-04 in, DZ=-9.892612e-03 in
#   Node N136: DX=5.693376e-03 in, DY=-2.690887e-03 in, DZ=-1.209126e-02 in
#   Node N137: DX=-1.638248e-03 in, DY=1.197590e-04 in, DZ=-9.223156e-04 in
#   Node N138: DX=-2.277259e-03 in, DY=1.001418e-03 in, DZ=-2.361928e-03 in
#   Node N139: DX=4.606152e-04 in, DY=-3.548852e-04 in, DZ=-9.080340e-04 in
#   Node N140: DX=-2.673734e-03 in, DY=6.210368e-05 in, DZ=-2.294765e-03 in
#   Node N141: DX=-2.311281e-03 in, DY=4.258486e-04 in, DZ=-7.692300e-03 in
#   Node N142: DX=-5.096893e-03 in, DY=1.999347e-03 in, DZ=-8.042186e-03 in
#   Node N143: DX=-5.259259e-03 in, DY=4.069804e-03 in, DZ=-1.001045e-02 in
#   Node N144: DX=6.311906e-05 in, DY=1.920075e-04 in, DZ=-1.324593e-02 in
#   Node N145: DX=-9.687924e-04 in, DY=2.022861e-03 in, DZ=-1.205669e-02 in
#   Node N146: DX=-4.777362e-03 in, DY=4.598635e-03 in, DZ=-1.818865e-02 in
#   Node N147: DX=3.871243e-04 in, DY=-6.665569e-04 in, DZ=-1.322073e-03 in
#   Node N148: DX=-2.712307e-03 in, DY=1.529740e-04 in, DZ=-2.277060e-03 in
#   Node N149: DX=-5.060661e-03 in, DY=-1.372284e-03 in, DZ=-2.874476e-03 in
#   Node N150: DX=-4.511279e-04 in, DY=-2.083037e-05 in, DZ=-1.085643e-03 in
#   Node N151: DX=-2.749764e-03 in, DY=-7.257049e-04 in, DZ=-1.911276e-03 in
#   Node N152: DX=-6.078080e-03 in, DY=-1.668119e-03 in, DZ=-2.470202e-03 in
#   Node N153: DX=-1.570669e-03 in, DY=7.554559e-04 in, DZ=-2.677817e-03 in
#   Node N154: DX=-1.138924e-03 in, DY=7.556116e-04 in, DZ=-9.672970e-03 in
#   Node N155: DX=-4.182374e-03 in, DY=2.255879e-03 in, DZ=-3.003855e-03 in
#   Node N156: DX=-3.311861e-03 in, DY=2.255133e-03 in, DZ=-1.041134e-02 in
#   Node N157: DX=-6.260140e-03 in, DY=3.941451e-03 in, DZ=-4.179009e-03 in
#   Node N158: DX=-5.122663e-03 in, DY=3.938952e-03 in, DZ=-1.210132e-02 in
