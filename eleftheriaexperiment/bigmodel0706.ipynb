# %%
# !pip install -q rhino3dm shapely trimesh matplotlib pyvista

# %%
# 2. Imports
import rhino3dm
import numpy as np
from shapely.geometry import Polygon, Point
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import os
import pyvista as pv

# File path
rhino_path = r"C:\Users\papad\Documents\GitHub\Octopusie\Reference Files\rectangles3dcantilever - Copy.3dm"
if not os.path.exists(rhino_path):
    raise FileNotFoundError(f"File not found: {rhino_path}")

# Load model
model = rhino3dm.File3dm.Read(rhino_path)
layers = {layer.Name.lower(): layer.Index for layer in model.Layers}
if 'building' not in layers or ('column' not in layers and 'columns' not in layers):
    raise RuntimeError("Missing required layers: 'building' and 'column' or 'columns'.")

column_layer = 'columns' if 'columns' in layers else 'column'

# Extract building volume & height
building_volumes = []
imported_columns = []
max_z = 0.0

wall_breps = []

for obj in model.Objects:
    layer_idx = obj.Attributes.LayerIndex
    geom = obj.Geometry

    if layer_idx == layers['building'] and geom.ObjectType == rhino3dm.ObjectType.Brep:
        bbox = geom.GetBoundingBox()
        base_pts = [
            [bbox.Min.X, bbox.Min.Y],
            [bbox.Max.X, bbox.Min.Y],
            [bbox.Max.X, bbox.Max.Y],
            [bbox.Min.X, bbox.Max.Y]
        ]
        poly = Polygon(base_pts)
        building_volumes.append(poly)
        wall_breps.append({'polygon': poly, 'bbox': bbox})
        max_z = max(max_z, bbox.Max.Z)

    elif layer_idx == layers[column_layer] and geom.ObjectType == rhino3dm.ObjectType.Brep:
        bbox = geom.GetBoundingBox()
        center_x = (bbox.Min.X + bbox.Max.X) / 2
        center_y = (bbox.Min.Y + bbox.Max.Y) / 2
        imported_columns.append((center_x, center_y))

if not building_volumes:
    raise RuntimeError("No valid building geometry found on the 'building' layer.")

# Ask for number of floors
while True:
    try:
        num_floors = int(input("How many floors does the building have? (e.g., 2): "))
        if num_floors < 1:
            raise ValueError
        break
    except ValueError:
        print("Please enter a valid positive integer for the number of floors.")

# Room sorting
detected_rooms = sorted([(poly, poly.area) for poly in building_volumes], key=lambda x: -x[1])

from shapely.geometry import Polygon

# Group rooms by touching
room_polygons = [poly for poly, _ in detected_rooms]
touch_graph = {i: set() for i in range(len(room_polygons))}

# Build graph of which rooms touch
for i, room in enumerate(room_polygons):
    for j, other in enumerate(room_polygons):
        if i != j and room.touches(other):
            touch_graph[i].add(j)
            touch_graph[j].add(i)

# DFS to group rooms
def dfs(start, group, visited):
    visited.add(start)
    group.append(room_polygons[start])
    for neighbor in touch_graph[start]:
        if neighbor not in visited:
            dfs(neighbor, group, visited)

visited = set()
grouped_rooms = []

for i in range(len(room_polygons)):
    if i not in visited:
        group = []
        dfs(i, group, visited)
        grouped_rooms.append(group)


# Structural logic
MaxS = 6.0
MinS = 4.0

columns = []
corrected_columns = []
available_imported = imported_columns.copy()
existing_columns = imported_columns.copy()
beams = []
for room_group in grouped_rooms:
    is_isolated = len(room_group) == 1
    # Shared or local memory based on group size
    existing_columns = []
    local_corrected_columns = []
    local_generated_columns = []

    for room_poly in room_group:
        minx, miny, maxx, maxy = room_poly.bounds
        width, height = maxx - minx, maxy - miny
        divisions_x = int(np.ceil(width / MaxS))
        divisions_y = int(np.ceil(height / MaxS))
        x_points = np.linspace(minx, maxx, divisions_x + 1)
        y_points = np.linspace(miny, maxy, divisions_y + 1)
        room_candidates = [(x, y) for x in x_points for y in y_points]

        for col in room_candidates:
            snap = False
            for imp_col in available_imported:
                if np.linalg.norm(np.array(col) - np.array(imp_col)) < MinS:
                    local_corrected_columns.append(col)
                    existing_columns.append(col)
                    available_imported.remove(imp_col)
                    snap = True
                    break
            if not snap and all(np.linalg.norm(np.array(col) - np.array(exist_col)) >= MinS for exist_col in existing_columns):
                local_generated_columns.append(col)
                existing_columns.append(col)

        # Interior beams
        for x in x_points:
            beams.append(((x, miny), (x, maxy)))
        for y in y_points:
            beams.append(((minx, y), (maxx, y)))

        # Perimeter beams
        for corner1, corner2 in zip(room_poly.exterior.coords, room_poly.exterior.coords[1:] + room_poly.exterior.coords[:1]):
            p1 = np.array(corner1)
            p2 = np.array(corner2)
            if np.linalg.norm(p1 - p2) >= MinS * 0.5:
                beams.append((tuple(p1[:2]), tuple(p2[:2])))

        # Corner columns (only if far enough)
        for corner in list(room_poly.exterior.coords)[:-1]:
            if all(np.linalg.norm(np.array(corner) - np.array(exist_col)) >= MinS * 0.5 for exist_col in existing_columns):
                local_generated_columns.append(corner)
                existing_columns.append(corner)

    # Store output to global lists
    corrected_columns.extend(local_corrected_columns)
    columns.extend(local_generated_columns)


    for room_poly in room_group:
        minx, miny, maxx, maxy = room_poly.bounds
        width, height = maxx - minx, maxy - miny
        divisions_x = int(np.ceil(width / MaxS))
        divisions_y = int(np.ceil(height / MaxS))
        x_points = np.linspace(minx, maxx, divisions_x + 1)
        y_points = np.linspace(miny, maxy, divisions_y + 1)
        room_candidates = [(x, y) for x in x_points for y in y_points]

        for col in room_candidates:
            snap = False
            for imp_col in available_imported:
                if np.linalg.norm(np.array(col) - np.array(imp_col)) < MinS:
                    corrected_columns.append(col)
                    existing_columns.append(col)
                    available_imported.remove(imp_col)
                    snap = True
                    break
            if not snap and all(np.linalg.norm(np.array(col) - np.array(exist_col)) >= MinS for exist_col in existing_columns):
                columns.append(col)
                existing_columns.append(col)

        # Interior grid beams
        for x in x_points:
            beams.append(((x, miny), (x, maxy)))
        for y in y_points:
            beams.append(((minx, y), (maxx, y)))

        # Perimeter beams
        for corner1, corner2 in zip(room_poly.exterior.coords, room_poly.exterior.coords[1:] + room_poly.exterior.coords[:1]):
            p1 = np.array(corner1)
            p2 = np.array(corner2)
            if np.linalg.norm(p1 - p2) >= MinS * 0.5:
                beams.append((tuple(p1[:2]), tuple(p2[:2])))

        # Force corner columns
        for corner in list(room_poly.exterior.coords)[:-1]:
            columns.append(corner)
            existing_columns.append(corner)


# Combine all base columns
all_base_columns = columns + corrected_columns

# 8. 2D Visualization (same as before)
fig, ax = plt.subplots(figsize=(10, 10))

# Room outlines
for poly, _ in detected_rooms:
    px, py = poly.exterior.xy
    ax.plot(px, py, 'k-', linewidth=1)

# Generated columns
if columns:
    gx, gy = zip(*columns)
    ax.scatter(gx, gy, c='blue', s=80, label='Generated Columns', zorder=5)

# Snapped imported columns
if corrected_columns:
    cx, cy = zip(*corrected_columns)
    ax.scatter(cx, cy, c='purple', s=80, label='Snapped Imported Columns', zorder=7)

# Original imported columns
if imported_columns:
    ix, iy = zip(*imported_columns)
    ax.scatter(ix, iy, c='red', s=80, label='Original Imported Columns', zorder=10)

intermediate_label_added = False
roof_label_added = False

for (x1, y1), (x2, y2) in beams:
    if num_floors > 1:
        for floor in range(1, num_floors):  # intermediate floors
            ax.plot([x1, x2], [y1, y2], color='orange', linestyle=':', linewidth=1,
                    label='Intermediate Floor Beams' if not intermediate_label_added else "")
            intermediate_label_added = True

    ax.plot([x1, x2], [y1, y2], color='green', linestyle='--', linewidth=1.5,
            label='Roof Beams' if not roof_label_added else "")
    roof_label_added = True

ax.set_aspect('equal', 'box')
ax.legend()
plt.title("2D Column and Beam Grid with Snapped Imported Columns")
ax.grid(True)
plt.show()

def get_wall_height(x, y, wall_data):
    pt = np.array([x, y])
    closest_wall = None
    closest_dist = float('inf')

    for wall in wall_data:
        poly = wall['polygon']
        dist = poly.exterior.distance(Point(x, y))
        if dist < closest_dist:
            closest_dist = dist
            closest_wall = wall

    if closest_wall:
        return closest_wall['bbox'].Max.Z
    else:
        return max_z  # fallback

def get_bbox_from_room(pt, wall_breps):
    point = Point(pt)
    for wall in wall_breps:
        if wall['polygon'].contains(point) or wall['polygon'].distance(point) < 0.1:
            return wall['bbox']
    return None

# PyVista 3D visualization
plotter = pv.Plotter(title="3D Structural System")

# Columns as vertical cylinders
for x, y in all_base_columns:
    wall_height = get_wall_height(x, y, wall_breps)
    cylinder = pv.Cylinder(center=(x, y, wall_height / 2), direction=(0, 0, 1),
                       radius=0.1, height=wall_height)

    plotter.add_mesh(cylinder, color='blue')

# Beams as thinner cylinders
beam_radius = 0.04  # thinner than column radius 0.1

min_wall_z = min(wall['bbox'].Min.Z for wall in wall_breps)

for (x1, y1), (x2, y2) in beams:
    h1 = get_wall_height(x1, y1, wall_breps)
    h2 = get_wall_height(x2, y2, wall_breps)
    max_height = max(h1, h2)

    room_bbox = get_bbox_from_room((x1, y1), wall_breps)
    room_base_z = room_bbox.Min.Z if room_bbox else 0.0
    room_top_z = room_bbox.Max.Z if room_bbox else max_z
    room_height = room_top_z - room_base_z

    # Detect cantilever (room base is significantly above the building's base level)
    if room_base_z - min_wall_z > 0.2:
        # Add a beam at the bottom of the cantilever
        start = np.array([x1, y1, room_base_z])
        end = np.array([x2, y2, room_base_z])
        direction = end - start
        length = np.linalg.norm(direction)
        if length >= 1e-6:
            direction /= length
            center = (start + end) / 2
            beam = pv.Cylinder(center=center, direction=direction, radius=beam_radius, height=length)
            plotter.add_mesh(beam, color='blue')  # Optional: use a distinct color for cantilever base beam

    # Place beams for each floor level (from room base upward)
    for floor in range(1, num_floors + 1):
        z = room_base_z + room_height / num_floors * floor
        if z > room_top_z:
            continue

        start = np.array([x1, y1, z])
        end = np.array([x2, y2, z])
        direction = end - start
        length = np.linalg.norm(direction)
        if length < 1e-6:
            continue

        direction /= length
        center = (start + end) / 2
        beam = pv.Cylinder(center=center, direction=direction, radius=beam_radius, height=length)
        color = 'green' if floor == num_floors else 'orange'
        plotter.add_mesh(beam, color=color)


# Actual Brep-based walls visualization
def mesh_brep(brep, mesh_type=rhino3dm.MeshType.Any):
    meshes = []
    for face in brep.Faces:
        try:
            m = face.GetMesh(mesh_type)
            if m: meshes.append(m)
        except:
            continue
    return meshes

for obj in model.Objects:
    geom = obj.Geometry
    layer_idx = obj.Attributes.LayerIndex
    if layer_idx == layers['building'] and isinstance(geom, rhino3dm.Brep):
        meshes = mesh_brep(geom)
        for mesh in meshes:
            pts = [(v.X, v.Y, v.Z) for v in mesh.Vertices]
            faces = []
            for f in mesh.Faces:
                if len(f) == 4:
                    idxs = (f[0], f[1], f[2], f[3])
                else:
                    idxs = (f[0], f[1], f[2])
                faces.append((len(idxs),) + idxs)
            faces_flat = [i for face in faces for i in face]
            pv_mesh = pv.PolyData(pts, faces_flat)
            plotter.add_mesh(pv_mesh, color='lightgray', opacity=0.3)

# Set up the camera and show
plotter.show_grid()
plotter.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 363
#     361 # Set up the camera and show
#     362 plotter.show_grid()
# --> 363 plotter.show()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyvista\plotting\plotter.py:6971, in Plotter.show(self, title, window_size, interactive, auto_close, interactive_update, full_screen, screenshot, return_img, cpos, jupyter_backend, return_viewer, return_cpos, before_close_callback, **kwargs)
#    6968         jupyter_backend = self._theme.jupyter_backend
#    6970     if jupyter_backend.lower() != 'none':
# -> 6971         jupyter_disp = handle_plotter(self, backend=jupyter_backend, **jupyter_kwargs)
#    6973 self.render()
#    6975 # initial double render needed for certain passes when offscreen
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyvista\jupyter\notebook.py:33, in handle_plotter(plotter, backend, screenshot, **kwargs)
#      30     if backend in ['server', 'client', 'trame', 'html']:
#      31         from pyvista.trame.jupyter import show_trame
# ---> 33         return show_trame(plotter, mode=backend, **kwargs)
#      35 except ImportError as e:
#      36     warnings.warn(
#      37         f'Failed to use notebook backend: \n\n{e}\n\nFalling back to a static output.',
#      38     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyvista\trame\jupyter.py:395, in show_trame(plotter, mode, name, server_proxy_enabled, server_proxy_prefix, jupyter_extension_enabled, collapse_menu, add_menu, add_menu_items, default_server_rendering, handler, **kwargs)
#     392     raise TrameServerDownError(name)
#     394 # Initialize app
# --> 395 viewer = initialize(
#     396     server,
#     397     plotter,
#     398     mode=mode,
#     399     default_server_rendering=default_server_rendering,
#     400     collapse_menu=collapse_menu,
#     401     add_menu=add_menu,
#     402     add_menu_items=add_menu_items,
#     403 )
#     405 if jupyter_extension_enabled:  # pragma: no cover
#     406     from trame_client.ui.core import iframe_url_builder_jupyter_extension
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyvista\trame\jupyter.py:254, in initialize(server, plotter, mode, default_server_rendering, collapse_menu, **kwargs)
#     252 with viewer.make_layout(server, template_name=plotter._id_name) as layout:
#     253     viewer.layout = layout
# --> 254     viewer.ui(
#     255         mode=mode,
#     256         default_server_rendering=default_server_rendering,
#     257         collapse_menu=collapse_menu,
#     258         **kwargs,
#     259     )
#     261 return viewer
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyvista\trame\ui\vuetify3.py:333, in Viewer.ui(self, mode, default_server_rendering, collapse_menu, add_menu, add_menu_items, **kwargs)
#     331                     add_menu_items()
#     332 if mode == 'trame':
# --> 333     view = PyVistaRemoteLocalView(
#     334         self.plotter,
#     335         mode=(
#     336             # Must use single-quote string for JS here
#     337             f"{self.SERVER_RENDERING} ? 'remote' : 'local'",
#     338             'remote' if default_server_rendering else 'local',
#     339         ),
#     340         **kwargs,
#     341     )
#     342 elif mode == 'server':
#     343     view = PyVistaRemoteView(self.plotter, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyvista\trame\views.py:273, in PyVistaRemoteLocalView.__init__(self, plotter, interactive_ratio, still_ratio, namespace, **kwargs)
#     270 # Track namespace for our use since trame attributes are name mangled
#     271 self._namespace = namespace
# --> 273 self._post_initialize()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyvista\trame\views.py:276, in PyVistaRemoteLocalView._post_initialize(self)
#     275 def _post_initialize(self):
# --> 276     super()._post_initialize()
#     277     self.set_widgets(
#     278         [ren.axes_widget for ren in self._plotter().renderers if hasattr(ren, 'axes_widget')],  # type: ignore[union-attr]
#     279     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyvista\trame\views.py:57, in _BasePyVistaView._post_initialize(self)
#      55 def _post_initialize(self):
#      56     if self._server.running:  # type: ignore[attr-defined]
# ---> 57         self.update()  # type: ignore[attr-defined]
#      58     else:
#      59         self._server.controller.on_server_ready.add(self.update)  # type: ignore[attr-defined]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trame_vtk\widgets\vtk\common.py:569, in VtkRemoteLocalView.update(self, reset_camera, widgets, orientation_axis, **kwargs)
#     567 if self.__rendering:
#     568     self.update_image(reset_camera)
# --> 569 self.update_geometry(
#     570     reset_camera=reset_camera,
#     571     widgets=widgets,
#     572     orientation_axis=orientation_axis,
#     573 )
#     575 if reset_camera:
#     576     self.server.js_call(
#     577         self.__ref,
#     578         "setCamera",
#     579         self._helper.camera(self.__view),
#     580     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trame_vtk\widgets\vtk\common.py:506, in VtkRemoteLocalView.update_geometry(self, reset_camera, widgets, orientation_axis, **kwargs)
#     503 if not self.server.protocol:
#     504     return
# --> 506 delta_state = self._helper.scene(
#     507     self.__view,
#     508     new_state=False,
#     509     widgets=widgets,
#     510     orientation_axis=orientation_axis,
#     511 )
#     512 self.server.protocol.publish("trame.vtk.delta", delta_state)
#     514 full_state = self._helper.scene(
#     515     self.__view,
#     516     new_state=True,
#     517     widgets=widgets,
#     518     orientation_axis=orientation_axis,
#     519 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trame_vtk\modules\vtk\__init__.py:78, in Helper.scene(self, render_window, reset_camera, new_state, widgets, orientation_axis, **kwargs)
#      69 def scene(
#      70     self,
#      71     render_window,
#    (...)     76     **kwargs,
#      77 ):
# ---> 78     scene_state = self._trame_server.protocol_call(
#      79         "viewport.geometry.view.get.state",
#      80         self.id(render_window),
#      81         new_state,
#      82         widgets=widgets,
#      83         orientation_axis=orientation_axis,
#      84     )
#      85     if reset_camera:
#      86         scene_state.setdefault("extra", {})["resetCamera"] = 1
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trame_server\core.py:515, in Server.protocol_call(self, method, *args, **kwargs)
#     513     if pair:
#     514         obj, func = pair
# --> 515         return func(obj, *args, **kwargs)
#     516     return None
#     518 error = "Protocol does not exist yet"
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trame_vtk\modules\vtk\protocols\local_rendering.py:115, in vtkWebLocalRendering.get_view_state(self, view_id, new_subscription, widgets, orientation_axis, **kwargs)
#     113 camera = renderer.GetActiveCamera()
#     114 render_window_id = self.app.GetObjectIdMap().GetGlobalId(s_view)
# --> 115 view_instance = serialize(
#     116     None, render_window, render_window_id, self.context, 1
#     117 )
#     118 view_instance["extra"] = {
#     119     "vtkRefId": reference_id(render_window),
#     120     "centerOfRotation": camera.GetFocalPoint(),
#     121     "camera": reference_id(camera),
#     122 }
#     124 # Handle widgets/behaviors
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trame_vtk\modules\vtk\serializers\serialize.py:19, in serialize(parent, instance, instance_id, context, depth)
#      16 serializer = SERIALIZERS[instance_type] if instance_type in SERIALIZERS else None
#      18 if serializer:
# ---> 19     return serializer(parent, instance, instance_id, context, depth)
#      21 if instance_type not in NO_SERIALIZER_FOR_INSTANCE:
#      22     # Only print the warning once for each type of serializer
#      23     logger.warning(f"!!!No serializer for {instance_type} with id {instance_id}")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trame_vtk\modules\vtk\serializers\render_windows.py:115, in render_window_serializer(parent, instance, obj_id, context, depth)
#     113 renderer = renderer_collection.GetItemAsObject(r_idx)
#     114 renderer_id = reference_id(renderer)
# --> 115 renderer_instance = serialize(
#     116     instance, renderer, renderer_id, context, depth + 1
#     117 )
#     118 if renderer_instance:
#     119     dependencies.append(renderer_instance)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trame_vtk\modules\vtk\serializers\serialize.py:19, in serialize(parent, instance, instance_id, context, depth)
#      16 serializer = SERIALIZERS[instance_type] if instance_type in SERIALIZERS else None
#      18 if serializer:
# ---> 19     return serializer(parent, instance, instance_id, context, depth)
#      21 if instance_type not in NO_SERIALIZER_FOR_INSTANCE:
#      22     # Only print the warning once for each type of serializer
#      23     logger.warning(f"!!!No serializer for {instance_type} with id {instance_id}")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trame_vtk\modules\vtk\serializers\render_windows.py:26, in renderer_serializer(parent, instance, obj_id, context, depth)
#      23 view_prop = view_prop_collection.GetItemAsObject(rp_idx)
#      24 view_prop_id = reference_id(view_prop)
# ---> 26 view_prop_instance = serialize(
#      27     instance, view_prop, view_prop_id, context, depth + 1
#      28 )
#      29 if view_prop_instance:
#      30     dependencies.append(view_prop_instance)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trame_vtk\modules\vtk\serializers\serialize.py:19, in serialize(parent, instance, instance_id, context, depth)
#      16 serializer = SERIALIZERS[instance_type] if instance_type in SERIALIZERS else None
#      18 if serializer:
# ---> 19     return serializer(parent, instance, instance_id, context, depth)
#      21 if instance_type not in NO_SERIALIZER_FOR_INSTANCE:
#      22     # Only print the warning once for each type of serializer
#      23     logger.warning(f"!!!No serializer for {instance_type} with id {instance_id}")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trame_vtk\modules\vtk\serializers\actors.py:30, in generic_actor_serializer(parent, actor, actor_id, context, depth)
#      28 if mapper:
#      29     mapper_id = reference_id(mapper)
# ---> 30     mapper_instance = serialize(actor, mapper, mapper_id, context, depth + 1)
#      31     if mapper_instance:
#      32         dependencies.append(mapper_instance)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trame_vtk\modules\vtk\serializers\serialize.py:19, in serialize(parent, instance, instance_id, context, depth)
#      16 serializer = SERIALIZERS[instance_type] if instance_type in SERIALIZERS else None
#      18 if serializer:
# ---> 19     return serializer(parent, instance, instance_id, context, depth)
#      21 if instance_type not in NO_SERIALIZER_FOR_INSTANCE:
#      22     # Only print the warning once for each type of serializer
#      23     logger.warning(f"!!!No serializer for {instance_type} with id {instance_id}")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trame_vtk\modules\vtk\serializers\mappers.py:33, in generic_mapper_serializer(parent, mapper, mapper_id, context, depth)
#      31     alg = vtkDataSetSurfaceFilter()
#      32     alg.SetInputData(data_object)
# ---> 33     alg.Update()
#      34     data_object = alg.GetOutput()
#      36 data_object_id = "%s-dataset" % mapper_id
#
# KeyboardInterrupt:

# %%
# 2. Imports
import rhino3dm
import numpy as np
from shapely.geometry import Polygon, Point
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import os
import pyvista as pv

# File path
rhino_path = r"C:\Users\papad\Documents\GitHub\Octopusie\Reference Files\rectangles3dcantilever - Copy.3dm"
if not os.path.exists(rhino_path):
    raise FileNotFoundError(f"File not found: {rhino_path}")

# Load model
model = rhino3dm.File3dm.Read(rhino_path)
layers = {layer.Name.lower(): layer.Index for layer in model.Layers}
if 'building' not in layers or ('column' not in layers and 'columns' not in layers):
    raise RuntimeError("Missing required layers: 'building' and 'column' or 'columns'.")

column_layer = 'columns' if 'columns' in layers else 'column'

# Extract building volume & height
building_volumes = []
imported_columns = []
max_z = 0.0

wall_breps = []

for obj in model.Objects:
    layer_idx = obj.Attributes.LayerIndex
    geom = obj.Geometry

    if layer_idx == layers['building'] and geom.ObjectType == rhino3dm.ObjectType.Brep:
        bbox = geom.GetBoundingBox()
        base_pts = [
            [bbox.Min.X, bbox.Min.Y],
            [bbox.Max.X, bbox.Min.Y],
            [bbox.Max.X, bbox.Max.Y],
            [bbox.Min.X, bbox.Max.Y]
        ]
        poly = Polygon(base_pts)
        building_volumes.append(poly)
        wall_breps.append({'polygon': poly, 'bbox': bbox})
        max_z = max(max_z, bbox.Max.Z)

    elif layer_idx == layers[column_layer] and geom.ObjectType == rhino3dm.ObjectType.Brep:
        bbox = geom.GetBoundingBox()
        center_x = (bbox.Min.X + bbox.Max.X) / 2
        center_y = (bbox.Min.Y + bbox.Max.Y) / 2
        imported_columns.append((center_x, center_y))

if not building_volumes:
    raise RuntimeError("No valid building geometry found on the 'building' layer.")

# Ask for number of floors
while True:
    try:
        num_floors = int(input("How many floors does the building have? (e.g., 2): "))
        if num_floors < 1:
            raise ValueError
        break
    except ValueError:
        print("Please enter a valid positive integer for the number of floors.")

# Room sorting
detected_rooms = sorted([(poly, poly.area) for poly in building_volumes], key=lambda x: -x[1])

from shapely.geometry import Polygon

# Group rooms by touching
room_polygons = [poly for poly, _ in detected_rooms]
touch_graph = {i: set() for i in range(len(room_polygons))}

# Build graph of which rooms touch
for i, room in enumerate(room_polygons):
    for j, other in enumerate(room_polygons):
        if i != j and room.touches(other):
            touch_graph[i].add(j)
            touch_graph[j].add(i)

# DFS to group rooms
def dfs(start, group, visited):
    visited.add(start)
    group.append(room_polygons[start])
    for neighbor in touch_graph[start]:
        if neighbor not in visited:
            dfs(neighbor, group, visited)

visited = set()
grouped_rooms = []

for i in range(len(room_polygons)):
    if i not in visited:
        group = []
        dfs(i, group, visited)
        grouped_rooms.append(group)


# Structural logic
MaxS = 6.0
MinS = 4.0

columns = []
corrected_columns = []
available_imported = imported_columns.copy()
existing_columns = imported_columns.copy()
beams = []

for room_group in grouped_rooms:
    # Reset state for this group
    existing_columns = []
    available_imported_group = available_imported.copy()  # optional if needed

for room_group in grouped_rooms:
    existing_columns = []
    available_imported_group = available_imported.copy()

    for room_poly in room_group:
        minx, miny, maxx, maxy = room_poly.bounds
        width, height = maxx - minx, maxy - miny
        divisions_x = int(np.ceil(width / MaxS))
        divisions_y = int(np.ceil(height / MaxS))
        x_points = np.linspace(minx, maxx, divisions_x + 1)
        y_points = np.linspace(miny, maxy, divisions_y + 1)
        room_candidates = [(x, y) for x in x_points for y in y_points]

        for col in room_candidates:
            snap = False
            for imp_col in available_imported:
                if np.linalg.norm(np.array(col) - np.array(imp_col)) < MinS:
                    corrected_columns.append(col)
                    existing_columns.append(col)
                    available_imported.remove(imp_col)
                    snap = True
                    break
            if not snap and all(np.linalg.norm(np.array(col) - np.array(exist_col)) >= MinS for exist_col in existing_columns):
                columns.append(col)
                existing_columns.append(col)

        # Interior grid beams
        for x in x_points:
            beams.append(((x, miny), (x, maxy)))
        for y in y_points:
            beams.append(((minx, y), (maxx, y)))

        # Perimeter beams
        for corner1, corner2 in zip(room_poly.exterior.coords, room_poly.exterior.coords[1:] + room_poly.exterior.coords[:1]):
            p1 = np.array(corner1)
            p2 = np.array(corner2)
            if np.linalg.norm(p1 - p2) >= MinS * 0.5:
                beams.append((tuple(p1[:2]), tuple(p2[:2])))

        # Force corner columns
        for corner in list(room_poly.exterior.coords)[:-1]:
            columns.append(corner)
            existing_columns.append(corner)


# Combine all base columns
all_base_columns = columns + corrected_columns

# 8. 2D Visualization (same as before)
fig, ax = plt.subplots(figsize=(10, 10))

# Room outlines
for poly, _ in detected_rooms:
    px, py = poly.exterior.xy
    ax.plot(px, py, 'k-', linewidth=1)

# Generated columns
if columns:
    gx, gy = zip(*columns)
    ax.scatter(gx, gy, c='blue', s=80, label='Generated Columns', zorder=5)

# Snapped imported columns
if corrected_columns:
    cx, cy = zip(*corrected_columns)
    ax.scatter(cx, cy, c='purple', s=80, label='Snapped Imported Columns', zorder=7)

# Original imported columns
if imported_columns:
    ix, iy = zip(*imported_columns)
    ax.scatter(ix, iy, c='red', s=80, label='Original Imported Columns', zorder=10)

intermediate_label_added = False
roof_label_added = False

for (x1, y1), (x2, y2) in beams:
    if num_floors > 1:
        for floor in range(1, num_floors):  # intermediate floors
            ax.plot([x1, x2], [y1, y2], color='orange', linestyle=':', linewidth=1,
                    label='Intermediate Floor Beams' if not intermediate_label_added else "")
            intermediate_label_added = True

    ax.plot([x1, x2], [y1, y2], color='green', linestyle='--', linewidth=1.5,
            label='Roof Beams' if not roof_label_added else "")
    roof_label_added = True

ax.set_aspect('equal', 'box')
ax.legend()
plt.title("2D Column and Beam Grid with Snapped Imported Columns")
ax.grid(True)
plt.show()

def get_wall_height(x, y, wall_data):
    pt = np.array([x, y])
    closest_wall = None
    closest_dist = float('inf')

    for wall in wall_data:
        poly = wall['polygon']
        dist = poly.exterior.distance(Point(x, y))
        if dist < closest_dist:
            closest_dist = dist
            closest_wall = wall

    if closest_wall:
        return closest_wall['bbox'].Max.Z
    else:
        return max_z  # fallback

def get_bbox_from_room(pt, wall_breps):
    point = Point(pt)
    for wall in wall_breps:
        if wall['polygon'].contains(point) or wall['polygon'].distance(point) < 0.1:
            return wall['bbox']
    return None

# PyVista 3D visualization
plotter = pv.Plotter(title="3D Structural System")

# Columns as vertical cylinders
for x, y in all_base_columns:
    wall_height = get_wall_height(x, y, wall_breps)
    cylinder = pv.Cylinder(center=(x, y, wall_height / 2), direction=(0, 0, 1),
                       radius=0.1, height=wall_height)

    plotter.add_mesh(cylinder, color='blue')

# Beams as thinner cylinders
beam_radius = 0.04  # thinner than column radius 0.1

min_wall_z = min(wall['bbox'].Min.Z for wall in wall_breps)

for (x1, y1), (x2, y2) in beams:
    h1 = get_wall_height(x1, y1, wall_breps)
    h2 = get_wall_height(x2, y2, wall_breps)
    max_height = max(h1, h2)

    room_bbox = get_bbox_from_room((x1, y1), wall_breps)
    room_base_z = room_bbox.Min.Z if room_bbox else 0.0
    room_top_z = room_bbox.Max.Z if room_bbox else max_z
    room_height = room_top_z - room_base_z

    # Detect cantilever (room base is significantly above the building's base level)
    if room_base_z - min_wall_z > 0.2:
        # Add a beam at the bottom of the cantilever
        start = np.array([x1, y1, room_base_z])
        end = np.array([x2, y2, room_base_z])
        direction = end - start
        length = np.linalg.norm(direction)
        if length >= 1e-6:
            direction /= length
            center = (start + end) / 2
            beam = pv.Cylinder(center=center, direction=direction, radius=beam_radius, height=length)
            plotter.add_mesh(beam, color='blue')  # Optional: use a distinct color for cantilever base beam

    # Place beams for each floor level (from room base upward)
    for floor in range(1, num_floors + 1):
        z = room_base_z + room_height / num_floors * floor
        if z > room_top_z:
            continue

        start = np.array([x1, y1, z])
        end = np.array([x2, y2, z])
        direction = end - start
        length = np.linalg.norm(direction)
        if length < 1e-6:
            continue

        direction /= length
        center = (start + end) / 2
        beam = pv.Cylinder(center=center, direction=direction, radius=beam_radius, height=length)
        color = 'green' if floor == num_floors else 'orange'
        plotter.add_mesh(beam, color=color)


# Actual Brep-based walls visualization
def mesh_brep(brep, mesh_type=rhino3dm.MeshType.Any):
    meshes = []
    for face in brep.Faces:
        try:
            m = face.GetMesh(mesh_type)
            if m: meshes.append(m)
        except:
            continue
    return meshes

for obj in model.Objects:
    geom = obj.Geometry
    layer_idx = obj.Attributes.LayerIndex
    if layer_idx == layers['building'] and isinstance(geom, rhino3dm.Brep):
        meshes = mesh_brep(geom)
        for mesh in meshes:
            pts = [(v.X, v.Y, v.Z) for v in mesh.Vertices]
            faces = []
            for f in mesh.Faces:
                if len(f) == 4:
                    idxs = (f[0], f[1], f[2], f[3])
                else:
                    idxs = (f[0], f[1], f[2])
                faces.append((len(idxs),) + idxs)
            faces_flat = [i for face in faces for i in face]
            pv_mesh = pv.PolyData(pts, faces_flat)
            plotter.add_mesh(pv_mesh, color='lightgray', opacity=0.3)

# Set up the camera and show
plotter.show_grid()
plotter.show()

# %%
# 2. Imports
import rhino3dm
import numpy as np
from shapely.geometry import Polygon, Point
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import os
import pyvista as pv

# File path
rhino_path = r"C:\Users\papad\Documents\GitHub\Octopusie\Reference Files\rectangles3dcantilever - Copychanged2.3dm"
if not os.path.exists(rhino_path):
    raise FileNotFoundError(f"File not found: {rhino_path}")

# Load model
model = rhino3dm.File3dm.Read(rhino_path)
layers = {layer.Name.lower(): layer.Index for layer in model.Layers}
if 'building' not in layers or ('column' not in layers and 'columns' not in layers):
    raise RuntimeError("Missing required layers: 'building' and 'column' or 'columns'.")

column_layer = 'columns' if 'columns' in layers else 'column'

# Extract building volume & height
building_volumes = []
imported_columns = []
max_z = 0.0

wall_breps = []

for obj in model.Objects:
    layer_idx = obj.Attributes.LayerIndex
    geom = obj.Geometry

    if layer_idx == layers['building'] and geom.ObjectType == rhino3dm.ObjectType.Brep:
        bbox = geom.GetBoundingBox()
        base_pts = [
            [bbox.Min.X, bbox.Min.Y],
            [bbox.Max.X, bbox.Min.Y],
            [bbox.Max.X, bbox.Max.Y],
            [bbox.Min.X, bbox.Max.Y]
        ]
        poly = Polygon(base_pts)
        building_volumes.append(poly)
        wall_breps.append({'polygon': poly, 'bbox': bbox})
        max_z = max(max_z, bbox.Max.Z)

    elif layer_idx == layers[column_layer] and geom.ObjectType == rhino3dm.ObjectType.Brep:
        bbox = geom.GetBoundingBox()
        center_x = (bbox.Min.X + bbox.Max.X) / 2
        center_y = (bbox.Min.Y + bbox.Max.Y) / 2
        imported_columns.append((center_x, center_y))

if not building_volumes:
    raise RuntimeError("No valid building geometry found on the 'building' layer.")

# Ask for number of floors
while True:
    try:
        num_floors = int(input("How many floors does the building have? (e.g., 2): "))
        if num_floors < 1:
            raise ValueError
        break
    except ValueError:
        print("Please enter a valid positive integer for the number of floors.")

# Room sorting
detected_rooms = sorted([(poly, poly.area) for poly in building_volumes], key=lambda x: -x[1])

from shapely.geometry import Polygon

# Group rooms by touching
room_polygons = [poly for poly, _ in detected_rooms]
touch_graph = {i: set() for i in range(len(room_polygons))}

# Build graph of which rooms touch
for i, room in enumerate(room_polygons):
    for j, other in enumerate(room_polygons):
        if i != j and room.touches(other):
            touch_graph[i].add(j)
            touch_graph[j].add(i)

# DFS to group rooms
def dfs(start, group, visited):
    visited.add(start)
    group.append(room_polygons[start])
    for neighbor in touch_graph[start]:
        if neighbor not in visited:
            dfs(neighbor, group, visited)

visited = set()
grouped_rooms = []

for i in range(len(room_polygons)):
    if i not in visited:
        group = []
        dfs(i, group, visited)
        grouped_rooms.append(group)


# Structural logic
MaxS = 6.0
MinS = 3.0

columns = []
corrected_columns = []
available_imported = imported_columns.copy()
existing_columns = imported_columns.copy()
beams = []

for room_group in grouped_rooms:
    # Reset state for this group
    existing_columns = []
    available_imported_group = available_imported.copy()  # optional if needed

for room_group in grouped_rooms:
    existing_columns = []
    available_imported_group = available_imported.copy()

    for room_poly in room_group:
        minx, miny, maxx, maxy = room_poly.bounds
        width, height = maxx - minx, maxy - miny
        divisions_x = int(np.ceil(width / MaxS))
        divisions_y = int(np.ceil(height / MaxS))
        x_points = np.linspace(minx, maxx, divisions_x + 1)
        y_points = np.linspace(miny, maxy, divisions_y + 1)
        room_candidates = [(x, y) for x in x_points for y in y_points]

        for col in room_candidates:
            snap = False
            for imp_col in available_imported:
                if np.linalg.norm(np.array(col) - np.array(imp_col)) < MinS:
                    corrected_columns.append(col)
                    existing_columns.append(col)
                    available_imported.remove(imp_col)
                    snap = True
                    break
            if not snap and all(np.linalg.norm(np.array(col) - np.array(exist_col)) >= MinS for exist_col in existing_columns):
                columns.append(col)
                existing_columns.append(col)

        # Interior grid beams
        for x in x_points:
            beams.append(((x, miny), (x, maxy)))
        for y in y_points:
            beams.append(((minx, y), (maxx, y)))

        # Perimeter beams
        for corner1, corner2 in zip(room_poly.exterior.coords, room_poly.exterior.coords[1:] + room_poly.exterior.coords[:1]):
            p1 = np.array(corner1)
            p2 = np.array(corner2)
            if np.linalg.norm(p1 - p2) >= MinS * 0.5:
                beams.append((tuple(p1[:2]), tuple(p2[:2])))

        # Force corner columns
        for corner in list(room_poly.exterior.coords)[:-1]:
            columns.append(corner)
            existing_columns.append(corner)


# Combine all base columns
all_base_columns = columns + corrected_columns

# 8. 2D Visualization (same as before)
fig, ax = plt.subplots(figsize=(10, 10))

# Room outlines
for poly, _ in detected_rooms:
    px, py = poly.exterior.xy
    ax.plot(px, py, 'k-', linewidth=1)

# Generated columns
if columns:
    gx, gy = zip(*columns)
    ax.scatter(gx, gy, c='blue', s=80, label='Generated Columns', zorder=5)

# Snapped imported columns
if corrected_columns:
    cx, cy = zip(*corrected_columns)
    ax.scatter(cx, cy, c='purple', s=80, label='Snapped Imported Columns', zorder=7)

# Original imported columns
if imported_columns:
    ix, iy = zip(*imported_columns)
    ax.scatter(ix, iy, c='red', s=80, label='Original Imported Columns', zorder=10)

intermediate_label_added = False
roof_label_added = False

for (x1, y1), (x2, y2) in beams:
    if num_floors > 1:
        for floor in range(1, num_floors):  # intermediate floors
            ax.plot([x1, x2], [y1, y2], color='orange', linestyle=':', linewidth=1,
                    label='Intermediate Floor Beams' if not intermediate_label_added else "")
            intermediate_label_added = True

    ax.plot([x1, x2], [y1, y2], color='green', linestyle='--', linewidth=1.5,
            label='Roof Beams' if not roof_label_added else "")
    roof_label_added = True

ax.set_aspect('equal', 'box')
ax.legend()
plt.title("2D Column and Beam Grid with Snapped Imported Columns")
ax.grid(True)
plt.show()

def get_wall_height(x, y, wall_data):
    pt = np.array([x, y])
    closest_wall = None
    closest_dist = float('inf')

    for wall in wall_data:
        poly = wall['polygon']
        dist = poly.exterior.distance(Point(x, y))
        if dist < closest_dist:
            closest_dist = dist
            closest_wall = wall

    if closest_wall:
        return closest_wall['bbox'].Max.Z
    else:
        return max_z  # fallback

def get_bbox_from_room(pt, wall_breps):
    point = Point(pt)
    for wall in wall_breps:
        if wall['polygon'].contains(point) or wall['polygon'].distance(point) < 0.1:
            return wall['bbox']
    return None

# PyVista 3D visualization
plotter = pv.Plotter(title="3D Structural System")

# Columns as vertical cylinders
for x, y in all_base_columns:
    wall_height = get_wall_height(x, y, wall_breps)
    cylinder = pv.Cylinder(center=(x, y, wall_height / 2), direction=(0, 0, 1),
                       radius=0.1, height=wall_height)

    plotter.add_mesh(cylinder, color='blue')

# Beams as thinner cylinders
beam_radius = 0.04  # thinner than column radius 0.1

min_wall_z = min(wall['bbox'].Min.Z for wall in wall_breps)

for (x1, y1), (x2, y2) in beams:
    h1 = get_wall_height(x1, y1, wall_breps)
    h2 = get_wall_height(x2, y2, wall_breps)
    max_height = max(h1, h2)

    room_bbox = get_bbox_from_room((x1, y1), wall_breps)
    room_base_z = room_bbox.Min.Z if room_bbox else 0.0
    room_top_z = room_bbox.Max.Z if room_bbox else max_z
    room_height = room_top_z - room_base_z

    # Detect cantilever (room base is significantly above the building's base level)
    if room_base_z - min_wall_z > 0.2:
        # Add a beam at the bottom of the cantilever
        start = np.array([x1, y1, room_base_z])
        end = np.array([x2, y2, room_base_z])
        direction = end - start
        length = np.linalg.norm(direction)
        if length >= 1e-6:
            direction /= length
            center = (start + end) / 2
            beam = pv.Cylinder(center=center, direction=direction, radius=beam_radius, height=length)
            plotter.add_mesh(beam, color='blue')  # Optional: use a distinct color for cantilever base beam

    # Place beams for each floor level (from room base upward)
    for floor in range(1, num_floors + 1):
        z = room_base_z + room_height / num_floors * floor
        if z > room_top_z:
            continue

        start = np.array([x1, y1, z])
        end = np.array([x2, y2, z])
        direction = end - start
        length = np.linalg.norm(direction)
        if length < 1e-6:
            continue

        direction /= length
        center = (start + end) / 2
        beam = pv.Cylinder(center=center, direction=direction, radius=beam_radius, height=length)
        color = 'green' if floor == num_floors else 'orange'
        plotter.add_mesh(beam, color=color)


# Actual Brep-based walls visualization
def mesh_brep(brep, mesh_type=rhino3dm.MeshType.Any):
    meshes = []
    for face in brep.Faces:
        try:
            m = face.GetMesh(mesh_type)
            if m: meshes.append(m)
        except:
            continue
    return meshes

for obj in model.Objects:
    geom = obj.Geometry
    layer_idx = obj.Attributes.LayerIndex
    if layer_idx == layers['building'] and isinstance(geom, rhino3dm.Brep):
        meshes = mesh_brep(geom)
        for mesh in meshes:
            pts = [(v.X, v.Y, v.Z) for v in mesh.Vertices]
            faces = []
            for f in mesh.Faces:
                if len(f) == 4:
                    idxs = (f[0], f[1], f[2], f[3])
                else:
                    idxs = (f[0], f[1], f[2])
                faces.append((len(idxs),) + idxs)
            faces_flat = [i for face in faces for i in face]
            pv_mesh = pv.PolyData(pts, faces_flat)
            plotter.add_mesh(pv_mesh, color='lightgray', opacity=0.3)

# Set up the camera and show
plotter.show_grid()
plotter.show()

# %%
# 2. Imports
import rhino3dm
import numpy as np
from shapely.geometry import Polygon, Point
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import os
import pyvista as pv

# File path
rhino_path = r"C:\Users\papad\Documents\GitHub\Octopusie\Reference Files\rectangles3dcantilever - Copychanged2.3dm"
if not os.path.exists(rhino_path):
    raise FileNotFoundError(f"File not found: {rhino_path}")

# Load model
model = rhino3dm.File3dm.Read(rhino_path)
layers = {layer.Name.lower(): layer.Index for layer in model.Layers}
if 'building' not in layers or ('column' not in layers and 'columns' not in layers):
    raise RuntimeError("Missing required layers: 'building' and 'column' or 'columns'.")

column_layer = 'columns' if 'columns' in layers else 'column'

# Extract building volume & height
building_volumes = []
imported_columns = []
max_z = 0.0

wall_breps = []

for obj in model.Objects:
    layer_idx = obj.Attributes.LayerIndex
    geom = obj.Geometry

    if layer_idx == layers['building'] and geom.ObjectType == rhino3dm.ObjectType.Brep:
        bbox = geom.GetBoundingBox()
        base_pts = [
            [bbox.Min.X, bbox.Min.Y],
            [bbox.Max.X, bbox.Min.Y],
            [bbox.Max.X, bbox.Max.Y],
            [bbox.Min.X, bbox.Max.Y]
        ]
        poly = Polygon(base_pts)
        building_volumes.append(poly)
        wall_breps.append({'polygon': poly, 'bbox': bbox})
        max_z = max(max_z, bbox.Max.Z)

    elif layer_idx == layers[column_layer] and geom.ObjectType == rhino3dm.ObjectType.Brep:
        bbox = geom.GetBoundingBox()
        center_x = (bbox.Min.X + bbox.Max.X) / 2
        center_y = (bbox.Min.Y + bbox.Max.Y) / 2
        imported_columns.append((center_x, center_y))

if not building_volumes:
    raise RuntimeError("No valid building geometry found on the 'building' layer.")

# Ask for number of floors
while True:
    try:
        num_floors = int(input("How many floors does the building have? (e.g., 2): "))
        if num_floors < 1:
            raise ValueError
        break
    except ValueError:
        print("Please enter a valid positive integer for the number of floors.")

# Room sorting
detected_rooms = sorted([(poly, poly.area) for poly in building_volumes], key=lambda x: -x[1])

from shapely.geometry import Polygon

# Group rooms by touching
room_polygons = [poly for poly, _ in detected_rooms]
touch_graph = {i: set() for i in range(len(room_polygons))}

# Build graph of which rooms touch
for i, room in enumerate(room_polygons):
    for j, other in enumerate(room_polygons):
        if i != j and room.touches(other):
            touch_graph[i].add(j)
            touch_graph[j].add(i)

# DFS to group rooms
def dfs(start, group, visited):
    visited.add(start)
    group.append(room_polygons[start])
    for neighbor in touch_graph[start]:
        if neighbor not in visited:
            dfs(neighbor, group, visited)

visited = set()
grouped_rooms = []

for i in range(len(room_polygons)):
    if i not in visited:
        group = []
        dfs(i, group, visited)
        grouped_rooms.append(group)


# Structural logic
MaxS = 6.0
MinS = 3.0

columns = []
corrected_columns = []
available_imported = imported_columns.copy()
existing_columns = imported_columns.copy()
beams = []

for room_group in grouped_rooms:
    # Reset state for this group
    existing_columns = []
    available_imported_group = available_imported.copy()  # optional if needed

for room_group in grouped_rooms:
    existing_columns = []
    available_imported_group = available_imported.copy()

    for room_poly in room_group:
        minx, miny, maxx, maxy = room_poly.bounds
        width, height = maxx - minx, maxy - miny
        divisions_x = int(np.ceil(width / MaxS))
        divisions_y = int(np.ceil(height / MaxS))
        x_points = np.linspace(minx, maxx, divisions_x + 1)
        y_points = np.linspace(miny, maxy, divisions_y + 1)
        room_candidates = [(x, y) for x in x_points for y in y_points]

        for col in room_candidates:
            snap = False
            for imp_col in available_imported:
                if np.linalg.norm(np.array(col) - np.array(imp_col)) < MinS:
                    corrected_columns.append(col)
                    existing_columns.append(col)
                    available_imported.remove(imp_col)
                    snap = True
                    break
            if not snap and all(np.linalg.norm(np.array(col) - np.array(exist_col)) >= MinS for exist_col in existing_columns):
                columns.append(col)
                existing_columns.append(col)

        # Interior grid beams
        for x in x_points:
            beams.append(((x, miny), (x, maxy)))
        for y in y_points:
            beams.append(((minx, y), (maxx, y)))

        # Perimeter beams
        for corner1, corner2 in zip(room_poly.exterior.coords, room_poly.exterior.coords[1:] + room_poly.exterior.coords[:1]):
            p1 = np.array(corner1)
            p2 = np.array(corner2)
            if np.linalg.norm(p1 - p2) >= MinS * 0.5:
                beams.append((tuple(p1[:2]), tuple(p2[:2])))

        # Force corner columns
        for corner in list(room_poly.exterior.coords)[:-1]:
            columns.append(corner)
            existing_columns.append(corner)


# Combine all base columns
all_base_columns = columns + corrected_columns

# 8. 2D Visualization (same as before)
fig, ax = plt.subplots(figsize=(10, 10))

# Room outlines
for poly, _ in detected_rooms:
    px, py = poly.exterior.xy
    ax.plot(px, py, 'k-', linewidth=1)

# Generated columns
if columns:
    gx, gy = zip(*columns)
    ax.scatter(gx, gy, c='blue', s=80, label='Generated Columns', zorder=5)

# Snapped imported columns
if corrected_columns:
    cx, cy = zip(*corrected_columns)
    ax.scatter(cx, cy, c='purple', s=80, label='Snapped Imported Columns', zorder=7)

# Original imported columns
if imported_columns:
    ix, iy = zip(*imported_columns)
    ax.scatter(ix, iy, c='red', s=80, label='Original Imported Columns', zorder=10)

intermediate_label_added = False
roof_label_added = False

for (x1, y1), (x2, y2) in beams:
    if num_floors > 1:
        for floor in range(1, num_floors):  # intermediate floors
            ax.plot([x1, x2], [y1, y2], color='orange', linestyle=':', linewidth=1,
                    label='Intermediate Floor Beams' if not intermediate_label_added else "")
            intermediate_label_added = True

    ax.plot([x1, x2], [y1, y2], color='green', linestyle='--', linewidth=1.5,
            label='Roof Beams' if not roof_label_added else "")
    roof_label_added = True

ax.set_aspect('equal', 'box')
ax.legend()
plt.title("2D Column and Beam Grid with Snapped Imported Columns")
ax.grid(True)
plt.show()

def get_wall_height(x, y, wall_data):
    pt = np.array([x, y])
    closest_wall = None
    closest_dist = float('inf')

    for wall in wall_data:
        poly = wall['polygon']
        dist = poly.exterior.distance(Point(x, y))
        if dist < closest_dist:
            closest_dist = dist
            closest_wall = wall

    if closest_wall:
        return closest_wall['bbox'].Max.Z
    else:
        return max_z  # fallback


# PyVista 3D visualization
plotter = pv.Plotter(title="3D Structural System")

# Columns as vertical cylinders
for x, y in all_base_columns:
    wall_height = get_wall_height(x, y, wall_breps)
    cylinder = pv.Cylinder(center=(x, y, wall_height / 2), direction=(0, 0, 1),
                       radius=0.1, height=wall_height)

    plotter.add_mesh(cylinder, color='blue')

# Beams as thinner cylinders
beam_radius = 0.04  # thinner than column radius 0.1

for (x1, y1), (x2, y2) in beams:
    h1 = get_wall_height(x1, y1, wall_breps)
    h2 = get_wall_height(x2, y2, wall_breps)
    max_height = max(h1, h2)

    for floor in range(1, num_floors + 1):
        z = max_height / num_floors * floor

        if z > max_height:
            continue  # skip only if both ends are too high

        start = np.array([x1, y1, z])
        end = np.array([x2, y2, z])

        direction = end - start
        length = np.linalg.norm(direction)
        if length < 1e-6:
            continue
        direction = direction / length
        center = (start + end) / 2

        beam = pv.Cylinder(center=center, direction=direction, radius=beam_radius, height=length)
        color = 'green' if floor == num_floors else 'orange'
        plotter.add_mesh(beam, color=color)




# Actual Brep-based walls visualization
def mesh_brep(brep, mesh_type=rhino3dm.MeshType.Any):
    meshes = []
    for face in brep.Faces:
        try:
            m = face.GetMesh(mesh_type)
            if m: meshes.append(m)
        except:
            continue
    return meshes

for obj in model.Objects:
    geom = obj.Geometry
    layer_idx = obj.Attributes.LayerIndex
    if layer_idx == layers['building'] and isinstance(geom, rhino3dm.Brep):
        meshes = mesh_brep(geom)
        for mesh in meshes:
            pts = [(v.X, v.Y, v.Z) for v in mesh.Vertices]
            faces = []
            for f in mesh.Faces:
                if len(f) == 4:
                    idxs = (f[0], f[1], f[2], f[3])
                else:
                    idxs = (f[0], f[1], f[2])
                faces.append((len(idxs),) + idxs)
            faces_flat = [i for face in faces for i in face]
            pv_mesh = pv.PolyData(pts, faces_flat)
            plotter.add_mesh(pv_mesh, color='lightgray', opacity=0.3)

# Set up the camera and show
plotter.show_grid()
plotter.show()

# %%
import pandas as pd
from collections import OrderedDict

# --- 1. Collect Unique Nodes ---
node_coords = []
node_dict = OrderedDict()
node_counter = 0

def add_node(pt):
    key = tuple(np.round(pt, 5))  # reduce float precision issues
    if key not in node_dict:
        node_id = f"N{len(node_dict)}"
        node_dict[key] = node_id
        node_coords.append([node_id] + list(key))
    return node_dict[key]

# --- 2. Create Column & Beam Connections ---
column_lines = []
beam_lines = []

for x, y in all_base_columns:
    btm = (x, y, 0)
    top = (x, y, max_z)
    id_btm = add_node(btm)
    id_top = add_node(top)
    column_lines.append((id_btm, id_top))

for (x1, y1), (x2, y2) in beams:
    pt1 = (x1, y1, max_z)
    pt2 = (x2, y2, max_z)
    id1 = add_node(pt1)
    id2 = add_node(pt2)
    beam_lines.append((id1, id2))

# --- 3. Export nodes.csv ---
df_nodes = pd.DataFrame(node_coords, columns=["ID", "X", "Y", "Z"])
df_nodes.to_csv("nodes4.csv", index=False)
print("✅ nodes.csv written.")

# --- 4. Export columns.csv ---
col_data = []
for i, (i_node, j_node) in enumerate(column_lines):
    p1 = df_nodes[df_nodes["ID"] == i_node][["X", "Y", "Z"]].values[0]
    p2 = df_nodes[df_nodes["ID"] == j_node][["X", "Y", "Z"]].values[0]
    length = np.linalg.norm(p2 - p1)
    col_data.append([f"C{i}", i_node, j_node, round(length, 3)])

df_cols = pd.DataFrame(col_data, columns=["ID", "i_node", "j_node", "length"])
df_cols.to_csv("columns4.csv", index=False)
print("✅ columns.csv written.")

# --- 5. Export beams.csv ---
beam_data = []
for i, (i_node, j_node) in enumerate(beam_lines):
    p1 = df_nodes[df_nodes["ID"] == i_node][["X", "Y", "Z"]].values[0]
    p2 = df_nodes[df_nodes["ID"] == j_node][["X", "Y", "Z"]].values[0]
    length = np.linalg.norm(p2 - p1)
    beam_data.append([f"B{i}", i_node, j_node, round(length, 3)])

df_beams = pd.DataFrame(beam_data, columns=["ID", "i_node", "j_node", "length"])
df_beams.to_csv("beams4.csv", index=False)
print("✅ beams.csv written.")
# Out:
# ✅ nodes.csv written.
# ✅ columns.csv written.
# ✅ beams.csv written.
